# %%
from simple_exact_diagonalization_routines.local_matrix_class import *
from scipy.linalg import expm
import matplotlib.pyplot as plt
import time


# System size
L = 7

# Create objects of Pauli operators
X = X_class(L)
Y = Y_class(L)
Z = Z_class(L)
S_plus = S_plus_class(L)
S_minus = S_minus_class(L)

# Trivial initialization of the right size matrix
hamiltonian_name = "TLFIM_L_" +str(L)
H_TLFIM = 0*np.eye( 2**L ) 

for x in range(L-1):
    H_TLFIM = H_TLFIM + 2*X.at(x+1).dot(X.at(x+2)) + Z.at(x+1)+ X.at(x+1)
H_TLFIM = H_TLFIM + Z.at(L)    + X.at(L)

# %%
from class_double_bracket_flow import *


flow = double_bracket_flow( H_TLFIM )

flow.please_be_exhaustively_verbose = False
flow.please_be_verbose = True

flow.nmb_search_points_minimizing_s_search = 10
flow.flow_step_max = 0.2
flow.nmb_flow_steps = 10
flow.please_use_binary_search =  True
flow.please_compute_observables = False

#flow.flow_forwards( )
flow.flow_via_best_Z_search( please_also_check_canonical_bracket = True )

flow.show_flow_forwards_results()
# Out:
# Flow step  0
# Found minimum norm =  61.02085248356292  for s =  0.0833984375
# Flow step output with generator type  single_commutator using string  ZZZZZZZ  gave for s =  0.0833984375   minimal norm  61.02085248356292
# Found minimum norm =  59.90311992765712  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  ZZZZZZ1  gave for s =  0.07285156250000001   minimal norm  59.90311992765712
# Found minimum norm =  59.30242179822068  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZZ1Z  gave for s =  0.0498046875   minimal norm  59.30242179822068
# Found minimum norm =  60.26933917912077  for s =  0.07675781250000001
# Flow step output with generator type  single_commutator using string  ZZZZZ11  gave for s =  0.07675781250000001   minimal norm  60.26933917912077
# Found minimum norm =  59.30242179822068  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZ1ZZ  gave for s =  0.0498046875   minimal norm  59.30242179822068
# Found minimum norm =  57.9271386799706  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZ1Z1  gave for s =  0.0498046875   minimal norm  57.9271386799706
# Found minimum norm =  58.79165843997469  for s =  0.0646484375
# Flow step output with generator type  single_commutator using string  ZZZZ11Z  gave for s =  0.0646484375   minimal norm  58.79165843997469
# Found minimum norm =  60.62284717554087  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  ZZZZ111  gave for s =  0.08144531250000002   minimal norm  60.62284717554087
# Found minimum norm =  59.302421798220664  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1ZZZ  gave for s =  0.0498046875   minimal norm  59.302421798220664
# Found minimum norm =  57.951187167826255  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1ZZ1  gave for s =  0.0498046875   minimal norm  57.951187167826255
# Found minimum norm =  56.46490276318451  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1Z1Z  gave for s =  0.0498046875   minimal norm  56.46490276318451
# Found minimum norm =  58.39539267855518  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1Z11  gave for s =  0.0498046875   minimal norm  58.39539267855518
# Found minimum norm =  58.79165843997469  for s =  0.0646484375
# Flow step output with generator type  single_commutator using string  ZZZ11ZZ  gave for s =  0.0646484375   minimal norm  58.79165843997469
# Found minimum norm =  57.607321369375995  for s =  0.0587890625
# Flow step output with generator type  single_commutator using string  ZZZ11Z1  gave for s =  0.0587890625   minimal norm  57.607321369375995
# Found minimum norm =  59.17364702236818  for s =  0.06699218750000001
# Flow step output with generator type  single_commutator using string  ZZZ111Z  gave for s =  0.06699218750000001   minimal norm  59.17364702236818
# Found minimum norm =  60.95557195483594  for s =  0.0880859375
# Flow step output with generator type  single_commutator using string  ZZZ1111  gave for s =  0.0880859375   minimal norm  60.95557195483594
# Found minimum norm =  59.30242179822068  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZZZ  gave for s =  0.0498046875   minimal norm  59.30242179822068
# Found minimum norm =  57.95118716782624  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZZ1  gave for s =  0.0498046875   minimal norm  57.95118716782624
# Found minimum norm =  56.63003996776743  for s =  0.048242187500000006
# Flow step output with generator type  single_commutator using string  ZZ1ZZ1Z  gave for s =  0.048242187500000006   minimal norm  56.63003996776743
# Found minimum norm =  58.41924840833319  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZ11  gave for s =  0.0498046875   minimal norm  58.41924840833319
# Found minimum norm =  56.464902763184504  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1Z1ZZ  gave for s =  0.0498046875   minimal norm  56.464902763184504
# Found minimum norm =  55.1403854265222  for s =  0.0470703125
# Flow step output with generator type  single_commutator using string  ZZ1Z1Z1  gave for s =  0.0470703125   minimal norm  55.1403854265222
# Found minimum norm =  56.58327536004987  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1Z11Z  gave for s =  0.0498046875   minimal norm  56.58327536004987
# Found minimum norm =  58.8627339237514  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1Z111  gave for s =  0.0498046875   minimal norm  58.8627339237514
# Found minimum norm =  58.79165843997469  for s =  0.0646484375
# Flow step output with generator type  single_commutator using string  ZZ11ZZZ  gave for s =  0.0646484375   minimal norm  58.79165843997469
# Found minimum norm =  57.651420771970784  for s =  0.0583984375
# Flow step output with generator type  single_commutator using string  ZZ11ZZ1  gave for s =  0.0583984375   minimal norm  57.651420771970784
# Found minimum norm =  56.58327536004985  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ11Z1Z  gave for s =  0.0498046875   minimal norm  56.58327536004985
# Found minimum norm =  57.999389037282526  for s =  0.0607421875
# Flow step output with generator type  single_commutator using string  ZZ11Z11  gave for s =  0.0607421875   minimal norm  57.999389037282526
# Found minimum norm =  59.17364702236819  for s =  0.06699218750000001
# Flow step output with generator type  single_commutator using string  ZZ111ZZ  gave for s =  0.06699218750000001   minimal norm  59.17364702236819
# Found minimum norm =  57.99938903728253  for s =  0.0607421875
# Flow step output with generator type  single_commutator using string  ZZ111Z1  gave for s =  0.0607421875   minimal norm  57.99938903728253
# Found minimum norm =  59.547359141927494  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  ZZ1111Z  gave for s =  0.0701171875   minimal norm  59.547359141927494
# Found minimum norm =  61.24619658809556  for s =  0.09824218750000001
# Flow step output with generator type  single_commutator using string  ZZ11111  gave for s =  0.09824218750000001   minimal norm  61.24619658809556
# Found minimum norm =  59.302421798220685  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZZZZ  gave for s =  0.0498046875   minimal norm  59.302421798220685
# Found minimum norm =  57.95118716782625  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZZZ1  gave for s =  0.0498046875   minimal norm  57.95118716782625
# Found minimum norm =  56.630039967767445  for s =  0.048242187500000006
# Flow step output with generator type  single_commutator using string  Z1ZZZ1Z  gave for s =  0.048242187500000006   minimal norm  56.630039967767445
# Found minimum norm =  58.41924840833319  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZZ11  gave for s =  0.0498046875   minimal norm  58.41924840833319
# Found minimum norm =  56.63003996776743  for s =  0.048242187500000006
# Flow step output with generator type  single_commutator using string  Z1ZZ1ZZ  gave for s =  0.048242187500000006   minimal norm  56.63003996776743
# Found minimum norm =  55.27749616988717  for s =  0.046289062500000006
# Flow step output with generator type  single_commutator using string  Z1ZZ1Z1  gave for s =  0.046289062500000006   minimal norm  55.27749616988717
# Found minimum norm =  56.60789475844434  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZ11Z  gave for s =  0.0498046875   minimal norm  56.60789475844434
# Found minimum norm =  58.886400327157354  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZ111  gave for s =  0.0498046875   minimal norm  58.886400327157354
# Found minimum norm =  56.46490276318451  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z1ZZZ  gave for s =  0.0498046875   minimal norm  56.46490276318451
# Found minimum norm =  55.160861156833285  for s =  0.0470703125
# Flow step output with generator type  single_commutator using string  Z1Z1ZZ1  gave for s =  0.0470703125   minimal norm  55.160861156833285
# Found minimum norm =  53.66261141087955  for s =  0.04355468750000001
# Flow step output with generator type  single_commutator using string  Z1Z1Z1Z  gave for s =  0.04355468750000001   minimal norm  53.66261141087955
# Found minimum norm =  55.590960300070144  for s =  0.0478515625
# Flow step output with generator type  single_commutator using string  Z1Z1Z11  gave for s =  0.0478515625   minimal norm  55.590960300070144
# Found minimum norm =  56.58327536004986  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z11ZZ  gave for s =  0.0498046875   minimal norm  56.58327536004986
# Found minimum norm =  55.26926564514319  for s =  0.048242187500000006
# Flow step output with generator type  single_commutator using string  Z1Z11Z1  gave for s =  0.048242187500000006   minimal norm  55.26926564514319
# Found minimum norm =  57.040453012090374  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z111Z  gave for s =  0.0498046875   minimal norm  57.040453012090374
# Found minimum norm =  59.139706837002336  for s =  0.058007812500000006
# Flow step output with generator type  single_commutator using string  Z1Z1111  gave for s =  0.058007812500000006   minimal norm  59.139706837002336
# Found minimum norm =  58.7916584399747  for s =  0.0646484375
# Flow step output with generator type  single_commutator using string  Z11ZZZZ  gave for s =  0.0646484375   minimal norm  58.7916584399747
# Found minimum norm =  57.651420771970784  for s =  0.0583984375
# Flow step output with generator type  single_commutator using string  Z11ZZZ1  gave for s =  0.0583984375   minimal norm  57.651420771970784
# Found minimum norm =  56.60789475844434  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11ZZ1Z  gave for s =  0.0498046875   minimal norm  56.60789475844434
# Found minimum norm =  58.04827190316681  for s =  0.0603515625
# Flow step output with generator type  single_commutator using string  Z11ZZ11  gave for s =  0.0603515625   minimal norm  58.04827190316681
# Found minimum norm =  56.58327536004986  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11Z1ZZ  gave for s =  0.0498046875   minimal norm  56.58327536004986
# Found minimum norm =  55.2692656451432  for s =  0.048242187500000006
# Flow step output with generator type  single_commutator using string  Z11Z1Z1  gave for s =  0.048242187500000006   minimal norm  55.2692656451432
# Found minimum norm =  56.55082662398689  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11Z11Z  gave for s =  0.0498046875   minimal norm  56.55082662398689
# Found minimum norm =  58.38476100950885  for s =  0.0626953125
# Flow step output with generator type  single_commutator using string  Z11Z111  gave for s =  0.0626953125   minimal norm  58.38476100950885
# Found minimum norm =  59.17364702236818  for s =  0.06699218750000001
# Flow step output with generator type  single_commutator using string  Z111ZZZ  gave for s =  0.06699218750000001   minimal norm  59.17364702236818
# Found minimum norm =  58.04827190316681  for s =  0.0603515625
# Flow step output with generator type  single_commutator using string  Z111ZZ1  gave for s =  0.0603515625   minimal norm  58.04827190316681
# Found minimum norm =  57.040453012090374  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z111Z1Z  gave for s =  0.0498046875   minimal norm  57.040453012090374
# Found minimum norm =  58.38476100950885  for s =  0.0626953125
# Flow step output with generator type  single_commutator using string  Z111Z11  gave for s =  0.0626953125   minimal norm  58.38476100950885
# Found minimum norm =  59.547359141927494  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  Z1111ZZ  gave for s =  0.0701171875   minimal norm  59.547359141927494
# Found minimum norm =  58.38476100950885  for s =  0.0626953125
# Flow step output with generator type  single_commutator using string  Z1111Z1  gave for s =  0.0626953125   minimal norm  58.38476100950885
# Found minimum norm =  59.910078782124415  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  Z11111Z  gave for s =  0.07363281250000002   minimal norm  59.910078782124415
# Found minimum norm =  59.35321766227213  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  Z111111  gave for s =  0.0998046875   minimal norm  59.35321766227213
# Found minimum norm =  59.90311992765712  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  1ZZZZZZ  gave for s =  0.07285156250000001   minimal norm  59.90311992765712
# Found minimum norm =  58.7916584399747  for s =  0.0646484375
# Flow step output with generator type  single_commutator using string  1ZZZZZ1  gave for s =  0.0646484375   minimal norm  58.7916584399747
# Found minimum norm =  57.95118716782625  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZZ1Z  gave for s =  0.0498046875   minimal norm  57.95118716782625
# Found minimum norm =  59.1736470223682  for s =  0.06699218750000001
# Flow step output with generator type  single_commutator using string  1ZZZZ11  gave for s =  0.06699218750000001   minimal norm  59.1736470223682
# Found minimum norm =  57.95118716782625  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZ1ZZ  gave for s =  0.0498046875   minimal norm  57.95118716782625
# Found minimum norm =  56.58327536004987  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZ1Z1  gave for s =  0.0498046875   minimal norm  56.58327536004987
# Found minimum norm =  57.65142077197079  for s =  0.0583984375
# Flow step output with generator type  single_commutator using string  1ZZZ11Z  gave for s =  0.0583984375   minimal norm  57.65142077197079
# Found minimum norm =  59.547359141927494  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  1ZZZ111  gave for s =  0.0701171875   minimal norm  59.547359141927494
# Found minimum norm =  57.95118716782625  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1ZZZ  gave for s =  0.0498046875   minimal norm  57.95118716782625
# Found minimum norm =  56.607894758444324  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1ZZ1  gave for s =  0.0498046875   minimal norm  56.607894758444324
# Found minimum norm =  55.16086115683328  for s =  0.0470703125
# Flow step output with generator type  single_commutator using string  1ZZ1Z1Z  gave for s =  0.0470703125   minimal norm  55.16086115683328
# Found minimum norm =  57.040453012090374  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1Z11  gave for s =  0.0498046875   minimal norm  57.040453012090374
# Found minimum norm =  57.651420771970784  for s =  0.0583984375
# Flow step output with generator type  single_commutator using string  1ZZ11ZZ  gave for s =  0.0583984375   minimal norm  57.651420771970784
# Found minimum norm =  56.5508266239869  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ11Z1  gave for s =  0.0498046875   minimal norm  56.5508266239869
# Found minimum norm =  58.04827190316681  for s =  0.0603515625
# Flow step output with generator type  single_commutator using string  1ZZ111Z  gave for s =  0.0603515625   minimal norm  58.04827190316681
# Found minimum norm =  59.91007878212443  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  1ZZ1111  gave for s =  0.07363281250000002   minimal norm  59.91007878212443
# Found minimum norm =  57.92713867997059  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1ZZZZ  gave for s =  0.0498046875   minimal norm  57.92713867997059
# Found minimum norm =  56.58327536004986  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1ZZZ1  gave for s =  0.0498046875   minimal norm  56.58327536004986
# Found minimum norm =  55.27749616988718  for s =  0.046289062500000006
# Flow step output with generator type  single_commutator using string  1Z1ZZ1Z  gave for s =  0.046289062500000006   minimal norm  55.27749616988718
# Found minimum norm =  57.040453012090374  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1ZZ11  gave for s =  0.0498046875   minimal norm  57.040453012090374
# Found minimum norm =  55.1403854265222  for s =  0.0470703125
# Flow step output with generator type  single_commutator using string  1Z1Z1ZZ  gave for s =  0.0470703125   minimal norm  55.1403854265222
# Found minimum norm =  53.79925054370304  for s =  0.04472656250000001
# Flow step output with generator type  single_commutator using string  1Z1Z1Z1  gave for s =  0.04472656250000001   minimal norm  53.79925054370304
# Found minimum norm =  55.2692656451432  for s =  0.048242187500000006
# Flow step output with generator type  single_commutator using string  1Z1Z11Z  gave for s =  0.048242187500000006   minimal norm  55.2692656451432
# Found minimum norm =  57.479348910982324  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1Z111  gave for s =  0.0498046875   minimal norm  57.479348910982324
# Found minimum norm =  57.607321369375995  for s =  0.0587890625
# Flow step output with generator type  single_commutator using string  1Z11ZZZ  gave for s =  0.0587890625   minimal norm  57.607321369375995
# Found minimum norm =  56.55082662398689  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11ZZ1  gave for s =  0.0498046875   minimal norm  56.55082662398689
# Found minimum norm =  55.2692656451432  for s =  0.048242187500000006
# Flow step output with generator type  single_commutator using string  1Z11Z1Z  gave for s =  0.048242187500000006   minimal norm  55.2692656451432
# Found minimum norm =  56.99441819827817  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11Z11  gave for s =  0.0498046875   minimal norm  56.99441819827817
# Found minimum norm =  57.99938903728255  for s =  0.0607421875
# Flow step output with generator type  single_commutator using string  1Z111ZZ  gave for s =  0.0607421875   minimal norm  57.99938903728255
# Found minimum norm =  56.99441819827817  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z111Z1  gave for s =  0.0498046875   minimal norm  56.99441819827817
# Found minimum norm =  58.38476100950885  for s =  0.0626953125
# Flow step output with generator type  single_commutator using string  1Z1111Z  gave for s =  0.0626953125   minimal norm  58.38476100950885
# Found minimum norm =  57.35117920480263  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  1Z11111  gave for s =  0.07285156250000001   minimal norm  57.35117920480263
# Found minimum norm =  60.26933917912078  for s =  0.07675781250000001
# Flow step output with generator type  single_commutator using string  11ZZZZZ  gave for s =  0.07675781250000001   minimal norm  60.26933917912078
# Found minimum norm =  59.17364702236819  for s =  0.06699218750000001
# Flow step output with generator type  single_commutator using string  11ZZZZ1  gave for s =  0.06699218750000001   minimal norm  59.17364702236819
# Found minimum norm =  58.41924840833319  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZZ1Z  gave for s =  0.0498046875   minimal norm  58.41924840833319
# Found minimum norm =  59.54735914192749  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  11ZZZ11  gave for s =  0.0701171875   minimal norm  59.54735914192749
# Found minimum norm =  58.41924840833319  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZ1ZZ  gave for s =  0.0498046875   minimal norm  58.41924840833319
# Found minimum norm =  57.040453012090374  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZ1Z1  gave for s =  0.0498046875   minimal norm  57.040453012090374
# Found minimum norm =  58.048271903166814  for s =  0.0603515625
# Flow step output with generator type  single_commutator using string  11ZZ11Z  gave for s =  0.0603515625   minimal norm  58.048271903166814
# Found minimum norm =  59.91007878212443  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  11ZZ111  gave for s =  0.07363281250000002   minimal norm  59.91007878212443
# Found minimum norm =  58.39539267855518  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11Z1ZZZ  gave for s =  0.0498046875   minimal norm  58.39539267855518
# Found minimum norm =  57.040453012090374  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11Z1ZZ1  gave for s =  0.0498046875   minimal norm  57.040453012090374
# Found minimum norm =  55.59096030007015  for s =  0.0478515625
# Flow step output with generator type  single_commutator using string  11Z1Z1Z  gave for s =  0.0478515625   minimal norm  55.59096030007015
# Found minimum norm =  57.479348910982324  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11Z1Z11  gave for s =  0.0498046875   minimal norm  57.479348910982324
# Found minimum norm =  57.99938903728253  for s =  0.0607421875
# Flow step output with generator type  single_commutator using string  11Z11ZZ  gave for s =  0.0607421875   minimal norm  57.99938903728253
# Found minimum norm =  56.99441819827817  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11Z11Z1  gave for s =  0.0498046875   minimal norm  56.99441819827817
# Found minimum norm =  58.38476100950885  for s =  0.0626953125
# Flow step output with generator type  single_commutator using string  11Z111Z  gave for s =  0.0626953125   minimal norm  58.38476100950885
# Found minimum norm =  57.35117920480263  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  11Z1111  gave for s =  0.07285156250000001   minimal norm  57.35117920480263
# Found minimum norm =  60.622847175540855  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  111ZZZZ  gave for s =  0.08144531250000002   minimal norm  60.622847175540855
# Found minimum norm =  59.54735914192749  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  111ZZZ1  gave for s =  0.0701171875   minimal norm  59.54735914192749
# Found minimum norm =  58.88640032715736  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  111ZZ1Z  gave for s =  0.0498046875   minimal norm  58.88640032715736
# Found minimum norm =  59.91007878212442  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  111ZZ11  gave for s =  0.07363281250000002   minimal norm  59.91007878212442
# Found minimum norm =  58.8627339237514  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  111Z1ZZ  gave for s =  0.0498046875   minimal norm  58.8627339237514
# Found minimum norm =  57.47934891098232  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  111Z1Z1  gave for s =  0.0498046875   minimal norm  57.47934891098232
# Found minimum norm =  58.38476100950885  for s =  0.0626953125
# Flow step output with generator type  single_commutator using string  111Z11Z  gave for s =  0.0626953125   minimal norm  58.38476100950885
# Found minimum norm =  57.35117920480263  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  111Z111  gave for s =  0.07285156250000001   minimal norm  57.35117920480263
# Found minimum norm =  60.955571954835946  for s =  0.0880859375
# Flow step output with generator type  single_commutator using string  1111ZZZ  gave for s =  0.0880859375   minimal norm  60.955571954835946
# Found minimum norm =  59.91007878212442  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  1111ZZ1  gave for s =  0.07363281250000002   minimal norm  59.91007878212442
# Found minimum norm =  59.13970683700234  for s =  0.058007812500000006
# Flow step output with generator type  single_commutator using string  1111Z1Z  gave for s =  0.058007812500000006   minimal norm  59.13970683700234
# Found minimum norm =  57.35117920480263  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  1111Z11  gave for s =  0.07285156250000001   minimal norm  57.35117920480263
# Found minimum norm =  61.24619658809556  for s =  0.09824218750000001
# Flow step output with generator type  single_commutator using string  11111ZZ  gave for s =  0.09824218750000001   minimal norm  61.24619658809556
# Found minimum norm =  57.35117920480263  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  11111Z1  gave for s =  0.07285156250000001   minimal norm  57.35117920480263
# Found minimum norm =  59.353217662272144  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  111111Z  gave for s =  0.0998046875   minimal norm  59.353217662272144
# Found minimum norm =  62.99206299209449  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1111111  gave for s =  0.0001953125   minimal norm  62.99206299209449
# Found minimum norm =  47.7352772712826  for s =  0.03964843750000001
# Found that canonical is better because  47.7352772712826 53.66261141087955
# Found minimum norm =  47.7352772712826  for s =  0.03964843750000001
# Flowing forwards with type  canonical
# []
# Flow step  1
# Found minimum norm =  45.77904288494961  for s =  0.07910156250000001
# Flow step output with generator type  single_commutator using string  ZZZZZZZ  gave for s =  0.07910156250000001   minimal norm  45.77904288494961
# Found minimum norm =  45.579201151616914  for s =  0.06894531250000001
# Flow step output with generator type  single_commutator using string  ZZZZZZ1  gave for s =  0.06894531250000001   minimal norm  45.579201151616914
# Found minimum norm =  45.220179023149655  for s =  0.0666015625
# Flow step output with generator type  single_commutator using string  ZZZZZ1Z  gave for s =  0.0666015625   minimal norm  45.220179023149655
# Found minimum norm =  46.55072566671276  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZZ11  gave for s =  0.0498046875   minimal norm  46.55072566671276
# Found minimum norm =  45.765358743416016  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZ1ZZ  gave for s =  0.0498046875   minimal norm  45.765358743416016
# Found minimum norm =  44.832555954262645  for s =  0.06738281250000001
# Flow step output with generator type  single_commutator using string  ZZZZ1Z1  gave for s =  0.06738281250000001   minimal norm  44.832555954262645
# Found minimum norm =  45.982247589745235  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZ11Z  gave for s =  0.0498046875   minimal norm  45.982247589745235
# Found minimum norm =  46.7147811624073  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZ111  gave for s =  0.0498046875   minimal norm  46.7147811624073
# Found minimum norm =  45.77130638865143  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1ZZZ  gave for s =  0.0498046875   minimal norm  45.77130638865143
# Found minimum norm =  45.28158043840863  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1ZZ1  gave for s =  0.0498046875   minimal norm  45.28158043840863
# Found minimum norm =  44.22573461133002  for s =  0.0646484375
# Flow step output with generator type  single_commutator using string  ZZZ1Z1Z  gave for s =  0.0646484375   minimal norm  44.22573461133002
# Found minimum norm =  45.9603276240148  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1Z11  gave for s =  0.0498046875   minimal norm  45.9603276240148
# Found minimum norm =  46.17445881723275  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ11ZZ  gave for s =  0.0498046875   minimal norm  46.17445881723275
# Found minimum norm =  45.82853674235827  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ11Z1  gave for s =  0.0498046875   minimal norm  45.82853674235827
# Found minimum norm =  46.25445830122092  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ111Z  gave for s =  0.0498046875   minimal norm  46.25445830122092
# Found minimum norm =  46.65867053629414  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1111  gave for s =  0.0498046875   minimal norm  46.65867053629414
# Found minimum norm =  45.76535874341602  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZZZ  gave for s =  0.0498046875   minimal norm  45.76535874341602
# Found minimum norm =  45.22630299260385  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZZ1  gave for s =  0.0498046875   minimal norm  45.22630299260385
# Found minimum norm =  44.75599069726628  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZ1Z  gave for s =  0.0498046875   minimal norm  44.75599069726628
# Found minimum norm =  45.91067201280675  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZ11  gave for s =  0.0498046875   minimal norm  45.91067201280675
# Found minimum norm =  44.84902647452931  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1Z1ZZ  gave for s =  0.0498046875   minimal norm  44.84902647452931
# Found minimum norm =  43.93724029171678  for s =  0.06386718749999999
# Flow step output with generator type  single_commutator using string  ZZ1Z1Z1  gave for s =  0.06386718749999999   minimal norm  43.93724029171678
# Found minimum norm =  45.12711239468043  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1Z11Z  gave for s =  0.0498046875   minimal norm  45.12711239468043
# Found minimum norm =  46.418366650551214  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1Z111  gave for s =  0.0498046875   minimal norm  46.418366650551214
# Found minimum norm =  46.17445881723275  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ11ZZZ  gave for s =  0.0498046875   minimal norm  46.17445881723275
# Found minimum norm =  45.67409805203979  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ11ZZ1  gave for s =  0.0498046875   minimal norm  45.67409805203979
# Found minimum norm =  45.162916628384885  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ11Z1Z  gave for s =  0.0498046875   minimal norm  45.162916628384885
# Found minimum norm =  46.400629955191626  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ11Z11  gave for s =  0.0498046875   minimal norm  46.400629955191626
# Found minimum norm =  46.49167945952621  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ111ZZ  gave for s =  0.0498046875   minimal norm  46.49167945952621
# Found minimum norm =  46.17968998807477  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ111Z1  gave for s =  0.0498046875   minimal norm  46.17968998807477
# Found minimum norm =  46.6562131109623  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1111Z  gave for s =  0.0498046875   minimal norm  46.6562131109623
# Found minimum norm =  46.65335471825567  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ11111  gave for s =  0.0498046875   minimal norm  46.65335471825567
# Found minimum norm =  45.220179023149655  for s =  0.0666015625
# Flow step output with generator type  single_commutator using string  Z1ZZZZZ  gave for s =  0.0666015625   minimal norm  45.220179023149655
# Found minimum norm =  45.10128617915345  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZZZ1  gave for s =  0.0498046875   minimal norm  45.10128617915345
# Found minimum norm =  44.62866474128635  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZZ1Z  gave for s =  0.0498046875   minimal norm  44.62866474128635
# Found minimum norm =  45.777066428877795  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZZ11  gave for s =  0.0498046875   minimal norm  45.777066428877795
# Found minimum norm =  44.755990697266284  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZ1ZZ  gave for s =  0.0498046875   minimal norm  44.755990697266284
# Found minimum norm =  44.28289810917976  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZ1Z1  gave for s =  0.0498046875   minimal norm  44.28289810917976
# Found minimum norm =  44.971284358095076  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZ11Z  gave for s =  0.0498046875   minimal norm  44.971284358095076
# Found minimum norm =  46.25996853285605  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZ111  gave for s =  0.0498046875   minimal norm  46.25996853285605
# Found minimum norm =  44.22573461133002  for s =  0.0646484375
# Flow step output with generator type  single_commutator using string  Z1Z1ZZZ  gave for s =  0.0646484375   minimal norm  44.22573461133002
# Found minimum norm =  44.16773642927599  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z1ZZ1  gave for s =  0.0498046875   minimal norm  44.16773642927599
# Found minimum norm =  42.909399290969844  for s =  0.0654296875
# Flow step output with generator type  single_commutator using string  Z1Z1Z1Z  gave for s =  0.0654296875   minimal norm  42.909399290969844
# Found minimum norm =  44.38064856092418  for s =  0.0658203125
# Flow step output with generator type  single_commutator using string  Z1Z1Z11  gave for s =  0.0658203125   minimal norm  44.38064856092418
# Found minimum norm =  45.162916628384885  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z11ZZ  gave for s =  0.0498046875   minimal norm  45.162916628384885
# Found minimum norm =  44.812111174263634  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z11Z1  gave for s =  0.0498046875   minimal norm  44.812111174263634
# Found minimum norm =  44.983891153815904  for s =  0.0630859375
# Flow step output with generator type  single_commutator using string  Z1Z111Z  gave for s =  0.0630859375   minimal norm  44.983891153815904
# Found minimum norm =  46.158425790251556  for s =  0.07441406250000002
# Flow step output with generator type  single_commutator using string  Z1Z1111  gave for s =  0.07441406250000002   minimal norm  46.158425790251556
# Found minimum norm =  45.98224758974523  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11ZZZZ  gave for s =  0.0498046875   minimal norm  45.98224758974523
# Found minimum norm =  45.431946197896956  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11ZZZ1  gave for s =  0.0498046875   minimal norm  45.431946197896956
# Found minimum norm =  44.971284358095076  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11ZZ1Z  gave for s =  0.0498046875   minimal norm  44.971284358095076
# Found minimum norm =  46.11697662154768  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11ZZ11  gave for s =  0.0498046875   minimal norm  46.11697662154768
# Found minimum norm =  45.12711239468043  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11Z1ZZ  gave for s =  0.0498046875   minimal norm  45.12711239468043
# Found minimum norm =  44.698339790856295  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11Z1Z1  gave for s =  0.0498046875   minimal norm  44.698339790856295
# Found minimum norm =  45.4073060221662  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11Z11Z  gave for s =  0.0498046875   minimal norm  45.4073060221662
# Found minimum norm =  46.629381146346226  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11Z111  gave for s =  0.0498046875   minimal norm  46.629381146346226
# Found minimum norm =  46.254458301220915  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z111ZZZ  gave for s =  0.0498046875   minimal norm  46.254458301220915
# Found minimum norm =  45.789000467671364  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z111ZZ1  gave for s =  0.0498046875   minimal norm  45.789000467671364
# Found minimum norm =  44.98389115381591  for s =  0.0630859375
# Flow step output with generator type  single_commutator using string  Z111Z1Z  gave for s =  0.0630859375   minimal norm  44.98389115381591
# Found minimum norm =  46.509301391239575  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z111Z11  gave for s =  0.0498046875   minimal norm  46.509301391239575
# Found minimum norm =  46.6562131109623  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1111ZZ  gave for s =  0.0498046875   minimal norm  46.6562131109623
# Found minimum norm =  46.06375298572771  for s =  0.0666015625
# Flow step output with generator type  single_commutator using string  Z1111Z1  gave for s =  0.0666015625   minimal norm  46.06375298572771
# Found minimum norm =  46.57514184719504  for s =  0.0677734375
# Flow step output with generator type  single_commutator using string  Z11111Z  gave for s =  0.0677734375   minimal norm  46.57514184719504
# Found minimum norm =  45.985889787151024  for s =  0.07675781250000001
# Flow step output with generator type  single_commutator using string  Z111111  gave for s =  0.07675781250000001   minimal norm  45.985889787151024
# Found minimum norm =  45.579201151616914  for s =  0.06894531250000001
# Flow step output with generator type  single_commutator using string  1ZZZZZZ  gave for s =  0.06894531250000001   minimal norm  45.579201151616914
# Found minimum norm =  45.17655791246252  for s =  0.0623046875
# Flow step output with generator type  single_commutator using string  1ZZZZZ1  gave for s =  0.0623046875   minimal norm  45.17655791246252
# Found minimum norm =  45.10128617915344  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZZ1Z  gave for s =  0.0498046875   minimal norm  45.10128617915344
# Found minimum norm =  45.938749835226666  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZZ11  gave for s =  0.0498046875   minimal norm  45.938749835226666
# Found minimum norm =  45.22630299260385  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZ1ZZ  gave for s =  0.0498046875   minimal norm  45.22630299260385
# Found minimum norm =  44.78437169551557  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZ1Z1  gave for s =  0.0498046875   minimal norm  44.78437169551557
# Found minimum norm =  45.431946197896956  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZ11Z  gave for s =  0.0498046875   minimal norm  45.431946197896956
# Found minimum norm =  46.033960284291574  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZ111  gave for s =  0.0498046875   minimal norm  46.033960284291574
# Found minimum norm =  45.281580438408625  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1ZZZ  gave for s =  0.0498046875   minimal norm  45.281580438408625
# Found minimum norm =  44.75394986400303  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1ZZ1  gave for s =  0.0498046875   minimal norm  44.75394986400303
# Found minimum norm =  44.16773642927599  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1Z1Z  gave for s =  0.0498046875   minimal norm  44.16773642927599
# Found minimum norm =  45.494411128099436  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1Z11  gave for s =  0.0498046875   minimal norm  45.494411128099436
# Found minimum norm =  45.674098052039795  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ11ZZ  gave for s =  0.0498046875   minimal norm  45.674098052039795
# Found minimum norm =  45.3249141266515  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ11Z1  gave for s =  0.0498046875   minimal norm  45.3249141266515
# Found minimum norm =  45.78900046767136  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ111Z  gave for s =  0.0498046875   minimal norm  45.78900046767136
# Found minimum norm =  46.186109702378204  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1111  gave for s =  0.0498046875   minimal norm  46.186109702378204
# Found minimum norm =  44.832555954262645  for s =  0.06738281250000001
# Flow step output with generator type  single_commutator using string  1Z1ZZZZ  gave for s =  0.06738281250000001   minimal norm  44.832555954262645
# Found minimum norm =  44.78437169551557  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1ZZZ1  gave for s =  0.0498046875   minimal norm  44.78437169551557
# Found minimum norm =  44.28289810917977  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1ZZ1Z  gave for s =  0.0498046875   minimal norm  44.28289810917977
# Found minimum norm =  45.497101461139096  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1ZZ11  gave for s =  0.0498046875   minimal norm  45.497101461139096
# Found minimum norm =  43.93724029171678  for s =  0.06386718749999999
# Flow step output with generator type  single_commutator using string  1Z1Z1ZZ  gave for s =  0.06386718749999999   minimal norm  43.93724029171678
# Found minimum norm =  43.200793080800445  for s =  0.0677734375
# Flow step output with generator type  single_commutator using string  1Z1Z1Z1  gave for s =  0.0677734375   minimal norm  43.200793080800445
# Found minimum norm =  44.698339790856295  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1Z11Z  gave for s =  0.0498046875   minimal norm  44.698339790856295
# Found minimum norm =  45.473690277953885  for s =  0.07089843750000001
# Flow step output with generator type  single_commutator using string  1Z1Z111  gave for s =  0.07089843750000001   minimal norm  45.473690277953885
# Found minimum norm =  45.82853674235827  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11ZZZ  gave for s =  0.0498046875   minimal norm  45.82853674235827
# Found minimum norm =  45.32491412665151  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11ZZ1  gave for s =  0.0498046875   minimal norm  45.32491412665151
# Found minimum norm =  44.81211117426364  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11Z1Z  gave for s =  0.0498046875   minimal norm  44.81211117426364
# Found minimum norm =  46.05298149126945  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11Z11  gave for s =  0.0498046875   minimal norm  46.05298149126945
# Found minimum norm =  46.17968998807477  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z111ZZ  gave for s =  0.0498046875   minimal norm  46.17968998807477
# Found minimum norm =  45.590393773834215  for s =  0.06386718749999999
# Flow step output with generator type  single_commutator using string  1Z111Z1  gave for s =  0.06386718749999999   minimal norm  45.590393773834215
# Found minimum norm =  46.06375298572772  for s =  0.0666015625
# Flow step output with generator type  single_commutator using string  1Z1111Z  gave for s =  0.0666015625   minimal norm  46.06375298572772
# Found minimum norm =  45.020261911867294  for s =  0.07128906250000001
# Flow step output with generator type  single_commutator using string  1Z11111  gave for s =  0.07128906250000001   minimal norm  45.020261911867294
# Found minimum norm =  46.55072566671276  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZZZZ  gave for s =  0.0498046875   minimal norm  46.55072566671276
# Found minimum norm =  45.93874983522666  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZZZ1  gave for s =  0.0498046875   minimal norm  45.93874983522666
# Found minimum norm =  45.77706642887779  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZZ1Z  gave for s =  0.0498046875   minimal norm  45.77706642887779
# Found minimum norm =  46.2710207510442  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZZ11  gave for s =  0.0498046875   minimal norm  46.2710207510442
# Found minimum norm =  45.91067201280674  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZ1ZZ  gave for s =  0.0498046875   minimal norm  45.91067201280674
# Found minimum norm =  45.497101461139096  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZ1Z1  gave for s =  0.0498046875   minimal norm  45.497101461139096
# Found minimum norm =  46.11697662154768  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZ11Z  gave for s =  0.0498046875   minimal norm  46.11697662154768
# ...
# Found minimum norm =  25.767159971452244  for s =  0.0173828125
# Flow step output with generator type  single_commutator using string  Z11Z11Z  gave for s =  0.0173828125   minimal norm  25.767159971452244
# Found minimum norm =  25.836000929285007  for s =  0.022851562500000002
# Flow step output with generator type  single_commutator using string  Z11Z111  gave for s =  0.022851562500000002   minimal norm  25.836000929285007
# Found minimum norm =  25.879858417899513  for s =  0.012304687500000001
# Flow step output with generator type  single_commutator using string  Z111ZZZ  gave for s =  0.012304687500000001   minimal norm  25.879858417899513
# Found minimum norm =  25.782053811775224  for s =  0.018945312500000002
# Flow step output with generator type  single_commutator using string  Z111ZZ1  gave for s =  0.018945312500000002   minimal norm  25.782053811775224
# Found minimum norm =  25.751458440380134  for s =  0.019726562500000003
# Flow step output with generator type  single_commutator using string  Z111Z1Z  gave for s =  0.019726562500000003   minimal norm  25.751458440380134
# Found minimum norm =  25.79034964607325  for s =  0.0279296875
# Flow step output with generator type  single_commutator using string  Z111Z11  gave for s =  0.0279296875   minimal norm  25.79034964607325
# Found minimum norm =  25.74281428466682  for s =  0.020117187500000005
# Flow step output with generator type  single_commutator using string  Z1111ZZ  gave for s =  0.020117187500000005   minimal norm  25.74281428466682
# Found minimum norm =  25.771655653994582  for s =  0.024804687500000002
# Flow step output with generator type  single_commutator using string  Z1111Z1  gave for s =  0.024804687500000002   minimal norm  25.771655653994582
# Found minimum norm =  25.81915958114934  for s =  0.022460937500000003
# Flow step output with generator type  single_commutator using string  Z11111Z  gave for s =  0.022460937500000003   minimal norm  25.81915958114934
# Found minimum norm =  25.32424487306821  for s =  0.0306640625
# Flow step output with generator type  single_commutator using string  Z111111  gave for s =  0.0306640625   minimal norm  25.32424487306821
# Found minimum norm =  25.561077600020926  for s =  0.028710937500000002
# Flow step output with generator type  single_commutator using string  1ZZZZZZ  gave for s =  0.028710937500000002   minimal norm  25.561077600020926
# Found minimum norm =  25.63925099038835  for s =  0.0283203125
# Flow step output with generator type  single_commutator using string  1ZZZZZ1  gave for s =  0.0283203125   minimal norm  25.63925099038835
# Found minimum norm =  25.796092976062585  for s =  0.019726562500000003
# Flow step output with generator type  single_commutator using string  1ZZZZ1Z  gave for s =  0.019726562500000003   minimal norm  25.796092976062585
# Found minimum norm =  25.678828745274494  for s =  0.026757812500000002
# Flow step output with generator type  single_commutator using string  1ZZZZ11  gave for s =  0.026757812500000002   minimal norm  25.678828745274494
# Found minimum norm =  25.80989739485318  for s =  0.020117187500000005
# Flow step output with generator type  single_commutator using string  1ZZZ1ZZ  gave for s =  0.020117187500000005   minimal norm  25.80989739485318
# Found minimum norm =  25.919910242404388  for s =  0.004882812500000001
# Flow step output with generator type  single_commutator using string  1ZZZ1Z1  gave for s =  0.004882812500000001   minimal norm  25.919910242404388
# Found minimum norm =  25.736619944731903  for s =  0.024804687500000002
# Flow step output with generator type  single_commutator using string  1ZZZ11Z  gave for s =  0.024804687500000002   minimal norm  25.736619944731903
# Found minimum norm =  25.6283746638399  for s =  0.024804687500000002
# Flow step output with generator type  single_commutator using string  1ZZZ111  gave for s =  0.024804687500000002   minimal norm  25.6283746638399
# Found minimum norm =  25.905846091621072  for s =  0.008398437500000001
# Flow step output with generator type  single_commutator using string  1ZZ1ZZZ  gave for s =  0.008398437500000001   minimal norm  25.905846091621072
# Found minimum norm =  25.908799901552435  for s =  0.0072265625
# Flow step output with generator type  single_commutator using string  1ZZ1ZZ1  gave for s =  0.0072265625   minimal norm  25.908799901552435
# Found minimum norm =  25.887150815836804  for s =  0.012304687500000001
# Flow step output with generator type  single_commutator using string  1ZZ1Z1Z  gave for s =  0.012304687500000001   minimal norm  25.887150815836804
# Found minimum norm =  25.85667963898248  for s =  0.013085937500000002
# Flow step output with generator type  single_commutator using string  1ZZ1Z11  gave for s =  0.013085937500000002   minimal norm  25.85667963898248
# Found minimum norm =  25.833460536872604  for s =  0.016992187500000002
# Flow step output with generator type  single_commutator using string  1ZZ11ZZ  gave for s =  0.016992187500000002   minimal norm  25.833460536872604
# Found minimum norm =  25.92527180411145  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZ11Z1  gave for s =  0.0001953125   minimal norm  25.92527180411145
# Found minimum norm =  25.828757229187215  for s =  0.0158203125
# Flow step output with generator type  single_commutator using string  1ZZ111Z  gave for s =  0.0158203125   minimal norm  25.828757229187215
# Found minimum norm =  25.620798130885223  for s =  0.0306640625
# Flow step output with generator type  single_commutator using string  1ZZ1111  gave for s =  0.0306640625   minimal norm  25.620798130885223
# Found minimum norm =  25.700294063887434  for s =  0.022460937500000003
# Flow step output with generator type  single_commutator using string  1Z1ZZZZ  gave for s =  0.022460937500000003   minimal norm  25.700294063887434
# Found minimum norm =  25.925976554713976  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z1ZZZ1  gave for s =  0.0001953125   minimal norm  25.925976554713976
# Found minimum norm =  25.7221993246501  for s =  0.03886718750000001
# Flow step output with generator type  single_commutator using string  1Z1ZZ1Z  gave for s =  0.03886718750000001   minimal norm  25.7221993246501
# Found minimum norm =  25.773130910119203  for s =  0.0166015625
# Flow step output with generator type  single_commutator using string  1Z1ZZ11  gave for s =  0.0166015625   minimal norm  25.773130910119203
# Found minimum norm =  25.925183143965246  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z1Z1ZZ  gave for s =  0.0001953125   minimal norm  25.925183143965246
# Found minimum norm =  25.650743710254137  for s =  0.022851562500000002
# Flow step output with generator type  single_commutator using string  1Z1Z1Z1  gave for s =  0.022851562500000002   minimal norm  25.650743710254137
# Found minimum norm =  25.84906087612354  for s =  0.012304687500000001
# Flow step output with generator type  single_commutator using string  1Z1Z11Z  gave for s =  0.012304687500000001   minimal norm  25.84906087612354
# Found minimum norm =  25.919781584352734  for s =  0.020117187500000005
# Flow step output with generator type  single_commutator using string  1Z1Z111  gave for s =  0.020117187500000005   minimal norm  25.919781584352734
# Found minimum norm =  25.913218852226848  for s =  0.009179687500000002
# Flow step output with generator type  single_commutator using string  1Z11ZZZ  gave for s =  0.009179687500000002   minimal norm  25.913218852226848
# Found minimum norm =  25.84292673252889  for s =  0.0134765625
# Flow step output with generator type  single_commutator using string  1Z11ZZ1  gave for s =  0.0134765625   minimal norm  25.84292673252889
# Found minimum norm =  25.687596111361355  for s =  0.0212890625
# Flow step output with generator type  single_commutator using string  1Z11Z1Z  gave for s =  0.0212890625   minimal norm  25.687596111361355
# Found minimum norm =  25.690498859449384  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11Z11  gave for s =  0.0498046875   minimal norm  25.690498859449384
# Found minimum norm =  25.72746300929977  for s =  0.020898437500000002
# Flow step output with generator type  single_commutator using string  1Z111ZZ  gave for s =  0.020898437500000002   minimal norm  25.72746300929977
# Found minimum norm =  25.924501944242888  for s =  0.0021484375
# Flow step output with generator type  single_commutator using string  1Z111Z1  gave for s =  0.0021484375   minimal norm  25.924501944242888
# Found minimum norm =  25.810872900564853  for s =  0.032617187500000006
# Flow step output with generator type  single_commutator using string  1Z1111Z  gave for s =  0.032617187500000006   minimal norm  25.810872900564853
# Found minimum norm =  25.370135027836483  for s =  0.0279296875
# Flow step output with generator type  single_commutator using string  1Z11111  gave for s =  0.0279296875   minimal norm  25.370135027836483
# Found minimum norm =  25.77680246810241  for s =  0.018945312500000002
# Flow step output with generator type  single_commutator using string  11ZZZZZ  gave for s =  0.018945312500000002   minimal norm  25.77680246810241
# Found minimum norm =  25.840271198123762  for s =  0.0146484375
# Flow step output with generator type  single_commutator using string  11ZZZZ1  gave for s =  0.0146484375   minimal norm  25.840271198123762
# Found minimum norm =  25.88444093380275  for s =  0.0115234375
# Flow step output with generator type  single_commutator using string  11ZZZ1Z  gave for s =  0.0115234375   minimal norm  25.88444093380275
# Found minimum norm =  25.791241610179966  for s =  0.0166015625
# Flow step output with generator type  single_commutator using string  11ZZZ11  gave for s =  0.0166015625   minimal norm  25.791241610179966
# Found minimum norm =  25.86774614242938  for s =  0.012304687500000001
# Flow step output with generator type  single_commutator using string  11ZZ1ZZ  gave for s =  0.012304687500000001   minimal norm  25.86774614242938
# Found minimum norm =  25.925177769100767  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11ZZ1Z1  gave for s =  0.0001953125   minimal norm  25.925177769100767
# Found minimum norm =  25.71399839800094  for s =  0.021679687500000003
# Flow step output with generator type  single_commutator using string  11ZZ11Z  gave for s =  0.021679687500000003   minimal norm  25.71399839800094
# Found minimum norm =  25.783444004220833  for s =  0.021679687500000003
# Flow step output with generator type  single_commutator using string  11ZZ111  gave for s =  0.021679687500000003   minimal norm  25.783444004220833
# Found minimum norm =  25.851553089085122  for s =  0.0134765625
# Flow step output with generator type  single_commutator using string  11Z1ZZZ  gave for s =  0.0134765625   minimal norm  25.851553089085122
# Found minimum norm =  25.924872783059683  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11Z1ZZ1  gave for s =  0.0001953125   minimal norm  25.924872783059683
# Found minimum norm =  25.773698108564016  for s =  0.018945312500000002
# Flow step output with generator type  single_commutator using string  11Z1Z1Z  gave for s =  0.018945312500000002   minimal norm  25.773698108564016
# Found minimum norm =  25.83262435803524  for s =  0.019335937500000004
# Flow step output with generator type  single_commutator using string  11Z1Z11  gave for s =  0.019335937500000004   minimal norm  25.83262435803524
# Found minimum norm =  25.923085450091406  for s =  0.0021484375
# Flow step output with generator type  single_commutator using string  11Z11ZZ  gave for s =  0.0021484375   minimal norm  25.923085450091406
# Found minimum norm =  25.861657630279066  for s =  0.013085937500000002
# Flow step output with generator type  single_commutator using string  11Z11Z1  gave for s =  0.013085937500000002   minimal norm  25.861657630279066
# Found minimum norm =  25.865022368614994  for s =  0.0138671875
# Flow step output with generator type  single_commutator using string  11Z111Z  gave for s =  0.0138671875   minimal norm  25.865022368614994
# Found minimum norm =  25.44893082640924  for s =  0.0291015625
# Flow step output with generator type  single_commutator using string  11Z1111  gave for s =  0.0291015625   minimal norm  25.44893082640924
# Found minimum norm =  25.74280951021812  for s =  0.024804687500000002
# Flow step output with generator type  single_commutator using string  111ZZZZ  gave for s =  0.024804687500000002   minimal norm  25.74280951021812
# Found minimum norm =  25.7255805539483  for s =  0.018554687500000003
# Flow step output with generator type  single_commutator using string  111ZZZ1  gave for s =  0.018554687500000003   minimal norm  25.7255805539483
# Found minimum norm =  25.714655827665585  for s =  0.018554687500000003
# Flow step output with generator type  single_commutator using string  111ZZ1Z  gave for s =  0.018554687500000003   minimal norm  25.714655827665585
# Found minimum norm =  25.723221239308643  for s =  0.0427734375
# Flow step output with generator type  single_commutator using string  111ZZ11  gave for s =  0.0427734375   minimal norm  25.723221239308643
# Found minimum norm =  25.761441433771793  for s =  0.0181640625
# Flow step output with generator type  single_commutator using string  111Z1ZZ  gave for s =  0.0181640625   minimal norm  25.761441433771793
# Found minimum norm =  25.90068650433818  for s =  0.0166015625
# Flow step output with generator type  single_commutator using string  111Z1Z1  gave for s =  0.0166015625   minimal norm  25.90068650433818
# Found minimum norm =  25.846685920901262  for s =  0.024804687500000002
# Flow step output with generator type  single_commutator using string  111Z11Z  gave for s =  0.024804687500000002   minimal norm  25.846685920901262
# Found minimum norm =  25.501237439106514  for s =  0.0244140625
# Flow step output with generator type  single_commutator using string  111Z111  gave for s =  0.0244140625   minimal norm  25.501237439106514
# Found minimum norm =  25.601357693548646  for s =  0.022851562500000002
# Flow step output with generator type  single_commutator using string  1111ZZZ  gave for s =  0.022851562500000002   minimal norm  25.601357693548646
# Found minimum norm =  25.781511070201685  for s =  0.026367187500000003
# Flow step output with generator type  single_commutator using string  1111ZZ1  gave for s =  0.026367187500000003   minimal norm  25.781511070201685
# Found minimum norm =  25.70902857682333  for s =  0.040429687500000006
# Flow step output with generator type  single_commutator using string  1111Z1Z  gave for s =  0.040429687500000006   minimal norm  25.70902857682333
# Found minimum norm =  25.267041784523297  for s =  0.0294921875
# Flow step output with generator type  single_commutator using string  1111Z11  gave for s =  0.0294921875   minimal norm  25.267041784523297
# Found minimum norm =  25.41111432618843  for s =  0.0392578125
# Flow step output with generator type  single_commutator using string  11111ZZ  gave for s =  0.0392578125   minimal norm  25.41111432618843
# Found minimum norm =  25.37420122800835  for s =  0.0302734375
# Flow step output with generator type  single_commutator using string  11111Z1  gave for s =  0.0302734375   minimal norm  25.37420122800835
# Found minimum norm =  25.342701056029377  for s =  0.0291015625
# Flow step output with generator type  single_commutator using string  111111Z  gave for s =  0.0291015625   minimal norm  25.342701056029377
# Found minimum norm =  25.924697839797204  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1111111  gave for s =  0.0001953125   minimal norm  25.924697839797204
# Found minimum norm =  25.261673515467788  for s =  0.0021484375
# Found that canonical is better because  25.261673515467788 25.267041784523297
# Found minimum norm =  25.261673515467788  for s =  0.0021484375
# Flowing forwards with type  canonical
# []

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

def plot_iteration_results(  ):
    flow.run_param_rc(fontsize=18)
    flow_results = flow.flow_outputs

    f=plt.figure(figsize = ( 8,7 ))
    n=1
    ax_a = f.add_subplot(1,n,1)
    norms = flow_results['minimal_norm_sigma_H_s']
    x_axis = [sum(flow_results['minimizing_flow_step'][:k])for k in range( 1, len(flow_results['minimizing_flow_step'])+1)]

    plt.plot( x_axis, norms, '-o')   
    N = 10
    k=0
    for xy in zip([x+.01 for x in x_axis[0:N]], 
                  [n - 0.03 for n in norms[0:N]]):  
        if k == 0 or k == 9 or k == 8 or k== 7 or k ==6:
            a=1
        else:
            plt.annotate('k = ' + str(k) + ': ' + flow_results['strs_of_minimizer_Z'][k-1], xy=xy, textcoords='data', fontsize=16)
        k=k+1
    #10
    plt.annotate('k = ' + str(k) + ': ' + flow_results['strs_of_minimizer_Z'][k-1], 
                 xy=(x_axis[-1]-.062,norms[-1]-1.5), textcoords='data', fontsize=16)
#8
    plt.annotate('k = ' + str(k-2) + ': ' + flow_results['strs_of_minimizer_Z'][k-3], 
                 xy=(x_axis[k-2]-.071,norms[k-2]-1.66), textcoords='data', fontsize=17)
#9
    plt.annotate('k = ' + str(k-1) + ': ' + flow_results['strs_of_minimizer_Z'][k-2], 
                  xy=(x_axis[k-1]-.03,norms[k-1]+0.5), textcoords='data', fontsize=17)
#7
    plt.annotate('k = ' + str(k-3) + ': ' + flow_results['strs_of_minimizer_Z'][k-4], 
                  xy=(x_axis[k-3]-.072,norms[k-3]-.7), textcoords='data', fontsize=17)
    plt.annotate('k = ' + str(k-4) + ': ' + flow_results['strs_of_minimizer_Z'][k-5], 
                  xy=(x_axis[k-4]+.0051,norms[k-4]-.7), textcoords='data', fontsize=17)
    plt.annotate('a)', xy = (-.1,1.02),
                 xycoords='axes fraction')
    x_labels_rounded = [ round(x, 2 ) for x in x_axis ]
    x_labels_rounded = [0] + x_labels_rounded[1:9]  + [max(x_labels_rounded)]
    x_labels_rounded.pop(2)
    x_labels_rounded.pop(2)
    x_labels_rounded.pop(4)

    x_labels_rounded.pop(-2)
#     x_labels_rounded.pop(4)
    
    plt.xticks(x_labels_rounded)
    y_labels_rounded = [ round(y, 1 ) for y in norms ]
    y_labels_rounded = y_labels_rounded[0:5] + [min(y_labels_rounded)]
    plt.yticks(y_labels_rounded)
    plt.grid()
    plt.xlabel(r'Total flow duration $\ell$')
    plt.title(r'Norm off-diagonal $\vert\vert\sigma(\hat H_k)\vert\vert$')
    a =-.1
    b = 1.05
 
    axin1 = ax_a.inset_axes([0.2,.7, 0.31, 0.27])
    inset1 = axin1.imshow( H_TLFIM, cmap='RdBu' )
    divider1 = make_axes_locatable(axin1)
    div_ax = divider1.append_axes("right", size="10%", pad=0.05)
    cbar1 = plt.colorbar(inset1, cax = div_ax )
    range_plot = np.max( np.abs( H_TLFIM ) )
#     cbar1.set_clim( -range_plot, range_plot )
    axin1.set_yticks(range(2**L))  
    axin1.set_xticklabels([1]+['']*(2**L-2)+[2**L])
    axin1.set_yticklabels([1]+['']*(2**L-2)+[2**L])
    axin1.set_xticks(range(2**L))
    ax_a.annotate(' ',
            xy=(x_axis[0]+.01, norms[0]),  # theta, radius
            xytext=(0.24, 0.81),    # fraction, fraction
            textcoords='figure fraction',
            arrowprops=dict(facecolor='gray', shrink=0.01),
            horizontalalignment='left',
            verticalalignment='bottom')
#     axin1.set_xlabel(r'$j$')
#     axin1.set_title(r'$k$')
#     axin1.grid()
    axin2 = ax_a.inset_axes([0.65,.32, 0.31, 0.27])
    inset2 = axin2.imshow(flow_results['optimally_flowed_H'][-1], cmap='RdBu')

    divider2 = make_axes_locatable(axin2)
    div_ax2 = divider2.append_axes("right", size="10%", pad=0.05)
    cbar2 = plt.colorbar(inset2, cax = div_ax2 )
    ax_a.annotate(' ',
        xy=(x_axis[-1], 11.4),  # theta, radius
        xytext=(.95, .3),    # fraction, fraction
        textcoords='axes fraction',
        arrowprops=dict(facecolor='gray', shrink=0.05),
        horizontalalignment='left',
        verticalalignment='bottom')
    
    axin3 = ax_a.inset_axes([0.65,.7, 0.31, 0.27])
    inset3 = axin3.imshow(flow_results['optimally_flowed_H'][2], cmap='RdBu')

    divider3 = make_axes_locatable(axin3)
    div_ax3 = divider3.append_axes("right", size="10%", pad=0.05)
    cbar2 = plt.colorbar(inset3, cax = div_ax3 )
    ax_a.annotate(' ',
        xy=(x_axis[2]+.01, norms[2]+.6),  # theta, radius
        xytext=(0.65, 0.67),    # fraction, fraction
        textcoords='axes fraction',
        arrowprops=dict(facecolor='gray', shrink=0.05),
        horizontalalignment='left',
        verticalalignment='bottom')
    axin2.set_yticks(range(2**L))  
    axin2.set_xticklabels([1]+['']*(2**L-2)+[2**L])
    axin2.set_yticklabels([1]+['']*(2**L-2)+[2**L])
    axin2.set_xticks(range(2**L))    
    axin3.set_yticks(range(2**L))  
    axin3.set_xticklabels([1]+['']*(2**L-2)+[2**L])
    axin3.set_yticklabels([1]+['']*(2**L-2)+[2**L])
    axin3.set_xticks(range(2**L))
    chosen_steps = [1,2]
    plt.savefig( 'figs/variational_norm_'+hamiltonian_name+'.pdf')
    
plot_iteration_results()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:66: UserWarning: FixedFormatter should only be used together with FixedLocator
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:107: UserWarning: FixedFormatter should only be used together with FixedLocator
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:111: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# #### Simple plot for debugging

# %%
H = flow.flow_outputs['final_flowed_H'][-1]

plt.figure()
plt.subplot(121)
plt.imshow(abs(H_TLFIM), cmap='RdBu')
plt.colorbar()
plt.subplot(122)
plt.imshow(abs(H), cmap='RdBu')
plt.colorbar()
plt.tight_layout()

# %% [markdown]
# This variable stores or strings that have been tested in each step

# %%
print(flow.flow_outputs['all_Z_names'])
# Out:
# ['ZZZZZZZ', 'ZZZZZZ1', 'ZZZZZ1Z', 'ZZZZZ11', 'ZZZZ1ZZ', 'ZZZZ1Z1', 'ZZZZ11Z', 'ZZZZ111', 'ZZZ1ZZZ', 'ZZZ1ZZ1', 'ZZZ1Z1Z', 'ZZZ1Z11', 'ZZZ11ZZ', 'ZZZ11Z1', 'ZZZ111Z', 'ZZZ1111', 'ZZ1ZZZZ', 'ZZ1ZZZ1', 'ZZ1ZZ1Z', 'ZZ1ZZ11', 'ZZ1Z1ZZ', 'ZZ1Z1Z1', 'ZZ1Z11Z', 'ZZ1Z111', 'ZZ11ZZZ', 'ZZ11ZZ1', 'ZZ11Z1Z', 'ZZ11Z11', 'ZZ111ZZ', 'ZZ111Z1', 'ZZ1111Z', 'ZZ11111', 'Z1ZZZZZ', 'Z1ZZZZ1', 'Z1ZZZ1Z', 'Z1ZZZ11', 'Z1ZZ1ZZ', 'Z1ZZ1Z1', 'Z1ZZ11Z', 'Z1ZZ111', 'Z1Z1ZZZ', 'Z1Z1ZZ1', 'Z1Z1Z1Z', 'Z1Z1Z11', 'Z1Z11ZZ', 'Z1Z11Z1', 'Z1Z111Z', 'Z1Z1111', 'Z11ZZZZ', 'Z11ZZZ1', 'Z11ZZ1Z', 'Z11ZZ11', 'Z11Z1ZZ', 'Z11Z1Z1', 'Z11Z11Z', 'Z11Z111', 'Z111ZZZ', 'Z111ZZ1', 'Z111Z1Z', 'Z111Z11', 'Z1111ZZ', 'Z1111Z1', 'Z11111Z', 'Z111111', '1ZZZZZZ', '1ZZZZZ1', '1ZZZZ1Z', '1ZZZZ11', '1ZZZ1ZZ', '1ZZZ1Z1', '1ZZZ11Z', '1ZZZ111', '1ZZ1ZZZ', '1ZZ1ZZ1', '1ZZ1Z1Z', '1ZZ1Z11', '1ZZ11ZZ', '1ZZ11Z1', '1ZZ111Z', '1ZZ1111', '1Z1ZZZZ', '1Z1ZZZ1', '1Z1ZZ1Z', '1Z1ZZ11', '1Z1Z1ZZ', '1Z1Z1Z1', '1Z1Z11Z', '1Z1Z111', '1Z11ZZZ', '1Z11ZZ1', '1Z11Z1Z', '1Z11Z11', '1Z111ZZ', '1Z111Z1', '1Z1111Z', '1Z11111', '11ZZZZZ', '11ZZZZ1', '11ZZZ1Z', '11ZZZ11', '11ZZ1ZZ', '11ZZ1Z1', '11ZZ11Z', '11ZZ111', '11Z1ZZZ', '11Z1ZZ1', '11Z1Z1Z', '11Z1Z11', '11Z11ZZ', '11Z11Z1', '11Z111Z', '11Z1111', '111ZZZZ', '111ZZZ1', '111ZZ1Z', '111ZZ11', '111Z1ZZ', '111Z1Z1', '111Z11Z', '111Z111', '1111ZZZ', '1111ZZ1', '1111Z1Z', '1111Z11', '11111ZZ', '11111Z1', '111111Z', '1111111']

# %% [markdown]
# and these are the strings that gave the optimal generator to decrease the norm of the off-diagonal restriction

# %%
flow.flow_outputs['strs_of_minimizer_Z']
# Out:
# ['Canonical',
#  'Canonical',
#  'Canonical',
#  'Canonical',
#  'Canonical',
#  '1Z1Z1Z1',
#  'Canonical',
#  '111Z111',
#  '11Z11Z1',
#  'Canonical']

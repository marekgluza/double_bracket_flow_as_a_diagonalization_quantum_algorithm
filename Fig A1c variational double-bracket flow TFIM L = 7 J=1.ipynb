# %%
from simple_exact_diagonalization_routines.local_matrix_class import *
from scipy.linalg import expm
import matplotlib.pyplot as plt
import time


# System size
L = 7

# Create objects of Pauli operators
X = X_class(L)
Y = Y_class(L)
Z = Z_class(L)
S_plus = S_plus_class(L)
S_minus = S_minus_class(L)

# Trivial initialization of the right size matrix
hamiltonian_name = "TFIM_J_1_L_" +str(L)
H_TFIM = 0*np.eye( 2**L ) 

for x in range(L-1):
    H_TFIM = H_TFIM + X.at(x+1).dot(X.at(x+2)) + Z.at(x+1)
H_TFIM = H_TFIM + Z.at(L)

# %%
from class_double_bracket_flow import *


flow = double_bracket_flow( H_TFIM )

flow.please_be_exhaustively_verbose = False
flow.please_be_verbose = True

flow.nmb_search_points_minimizing_s_search = 10
flow.flow_step_max = 0.2
flow.nmb_flow_steps = 10
flow.please_use_binary_search =  True
flow.please_compute_observables = False

#flow.flow_forwards( )
flow.flow_via_best_Z_search( please_also_check_canonical_bracket = True )

flow.show_flow_forwards_results()
# Out:
# Flow step  0
#     Found minimum norm =  27.712812921102035  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZZZZZZ  gave for s =  0.0001953125   minimal norm  27.712812921102035
#     Found minimum norm =  27.71281433064827  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZZZZZ1  gave for s =  0.0001953125   minimal norm  27.71281433064827
#     Found minimum norm =  27.71281292110462  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZZZZ1Z  gave for s =  0.0001953125   minimal norm  27.71281292110462
#     Found minimum norm =  27.71281433064827  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZZZZ11  gave for s =  0.0001953125   minimal norm  27.71281433064827
#     Found minimum norm =  27.71281292110462  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZZZ1ZZ  gave for s =  0.0001953125   minimal norm  27.71281292110462
#     Found minimum norm =  27.36633446762481  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  ZZZZ1Z1  gave for s =  0.08144531250000002   minimal norm  27.36633446762481
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZZZ11Z  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.71281433064827  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZZZ111  gave for s =  0.0001953125   minimal norm  27.71281433064827
#     Found minimum norm =  27.71281292110462  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZZ1ZZZ  gave for s =  0.0001953125   minimal norm  27.71281292110462
#     Found minimum norm =  27.389242694532044  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  ZZZ1ZZ1  gave for s =  0.07871093750000001   minimal norm  27.389242694532044
#     Found minimum norm =  26.779031117172952  for s =  0.08300781250000001
# Flow step output with generator type  single_commutator using string  ZZZ1Z1Z  gave for s =  0.08300781250000001   minimal norm  26.779031117172952
#     Found minimum norm =  27.366334467624814  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  ZZZ1Z11  gave for s =  0.08144531250000002   minimal norm  27.366334467624814
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZZ11ZZ  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.389242694532044  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  ZZZ11Z1  gave for s =  0.07871093750000001   minimal norm  27.389242694532044
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZZ111Z  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.71281433064827  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZZ1111  gave for s =  0.0001953125   minimal norm  27.71281433064827
#     Found minimum norm =  27.71281292110462  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ1ZZZZ  gave for s =  0.0001953125   minimal norm  27.71281292110462
#     Found minimum norm =  27.389242694532044  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  ZZ1ZZZ1  gave for s =  0.07871093750000001   minimal norm  27.389242694532044
#     Found minimum norm =  26.805047791067818  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  ZZ1ZZ1Z  gave for s =  0.08144531250000002   minimal norm  26.805047791067818
#     Found minimum norm =  27.389242694532044  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  ZZ1ZZ11  gave for s =  0.07871093750000001   minimal norm  27.389242694532044
#     Found minimum norm =  26.779031117172956  for s =  0.08300781250000001
# Flow step output with generator type  single_commutator using string  ZZ1Z1ZZ  gave for s =  0.08300781250000001   minimal norm  26.779031117172956
#     Found minimum norm =  26.094534239031546  for s =  0.08027343750000002
# Flow step output with generator type  single_commutator using string  ZZ1Z1Z1  gave for s =  0.08027343750000002   minimal norm  26.094534239031546
#     Found minimum norm =  26.805047791067818  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  ZZ1Z11Z  gave for s =  0.08144531250000002   minimal norm  26.805047791067818
#     Found minimum norm =  27.366334467624814  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  ZZ1Z111  gave for s =  0.08144531250000002   minimal norm  27.366334467624814
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ11ZZZ  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.409367165846536  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  ZZ11ZZ1  gave for s =  0.07480468750000001   minimal norm  27.409367165846536
#     Found minimum norm =  26.805047791067814  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  ZZ11Z1Z  gave for s =  0.08144531250000002   minimal norm  26.805047791067814
#     Found minimum norm =  27.389242694532044  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  ZZ11Z11  gave for s =  0.07871093750000001   minimal norm  27.389242694532044
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ111ZZ  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.389242694532044  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  ZZ111Z1  gave for s =  0.07871093750000001   minimal norm  27.389242694532044
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ1111Z  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.71281433064827  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ11111  gave for s =  0.0001953125   minimal norm  27.71281433064827
#     Found minimum norm =  27.71281292110462  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z1ZZZZZ  gave for s =  0.0001953125   minimal norm  27.71281292110462
#     Found minimum norm =  27.38924269453204  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  Z1ZZZZ1  gave for s =  0.07871093750000001   minimal norm  27.38924269453204
#     Found minimum norm =  26.805047791067818  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  Z1ZZZ1Z  gave for s =  0.08144531250000002   minimal norm  26.805047791067818
#     Found minimum norm =  27.389242694532044  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  Z1ZZZ11  gave for s =  0.07871093750000001   minimal norm  27.389242694532044
#     Found minimum norm =  26.805047791067818  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  Z1ZZ1ZZ  gave for s =  0.08144531250000002   minimal norm  26.805047791067818
#     Found minimum norm =  26.118245757995066  for s =  0.07949218750000002
# Flow step output with generator type  single_commutator using string  Z1ZZ1Z1  gave for s =  0.07949218750000002   minimal norm  26.118245757995066
#     Found minimum norm =  26.829466202654253  for s =  0.08027343750000002
# Flow step output with generator type  single_commutator using string  Z1ZZ11Z  gave for s =  0.08027343750000002   minimal norm  26.829466202654253
#     Found minimum norm =  27.389242694532044  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  Z1ZZ111  gave for s =  0.07871093750000001   minimal norm  27.389242694532044
#     Found minimum norm =  26.779031117172952  for s =  0.08300781250000001
# Flow step output with generator type  single_commutator using string  Z1Z1ZZZ  gave for s =  0.08300781250000001   minimal norm  26.779031117172952
#     Found minimum norm =  26.118245757995066  for s =  0.07949218750000002
# Flow step output with generator type  single_commutator using string  Z1Z1ZZ1  gave for s =  0.07949218750000002   minimal norm  26.118245757995066
#     Found minimum norm =  25.347119668007988  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  Z1Z1Z1Z  gave for s =  0.07480468750000001   minimal norm  25.347119668007988
#     Found minimum norm =  26.094534239031546  for s =  0.08027343750000002
# Flow step output with generator type  single_commutator using string  Z1Z1Z11  gave for s =  0.08027343750000002   minimal norm  26.094534239031546
#     Found minimum norm =  26.805047791067818  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  Z1Z11ZZ  gave for s =  0.08144531250000002   minimal norm  26.805047791067818
#     Found minimum norm =  26.118245757995073  for s =  0.07949218750000002
# Flow step output with generator type  single_commutator using string  Z1Z11Z1  gave for s =  0.07949218750000002   minimal norm  26.118245757995073
#     Found minimum norm =  26.805047791067818  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  Z1Z111Z  gave for s =  0.08144531250000002   minimal norm  26.805047791067818
#     Found minimum norm =  27.366334467624814  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  Z1Z1111  gave for s =  0.08144531250000002   minimal norm  27.366334467624814
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z11ZZZZ  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.409367165846536  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  Z11ZZZ1  gave for s =  0.07480468750000001   minimal norm  27.409367165846536
#     Found minimum norm =  26.82946620265425  for s =  0.08027343750000002
# Flow step output with generator type  single_commutator using string  Z11ZZ1Z  gave for s =  0.08027343750000002   minimal norm  26.82946620265425
#     Found minimum norm =  27.409367165846536  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  Z11ZZ11  gave for s =  0.07480468750000001   minimal norm  27.409367165846536
#     Found minimum norm =  26.805047791067818  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  Z11Z1ZZ  gave for s =  0.08144531250000002   minimal norm  26.805047791067818
#     Found minimum norm =  26.118245757995073  for s =  0.07949218750000002
# Flow step output with generator type  single_commutator using string  Z11Z1Z1  gave for s =  0.07949218750000002   minimal norm  26.118245757995073
#     Found minimum norm =  26.829466202654253  for s =  0.08027343750000002
# Flow step output with generator type  single_commutator using string  Z11Z11Z  gave for s =  0.08027343750000002   minimal norm  26.829466202654253
#     Found minimum norm =  27.389242694532044  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  Z11Z111  gave for s =  0.07871093750000001   minimal norm  27.389242694532044
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z111ZZZ  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.409367165846536  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  Z111ZZ1  gave for s =  0.07480468750000001   minimal norm  27.409367165846536
#     Found minimum norm =  26.805047791067818  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  Z111Z1Z  gave for s =  0.08144531250000002   minimal norm  26.805047791067818
#     Found minimum norm =  27.389242694532044  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  Z111Z11  gave for s =  0.07871093750000001   minimal norm  27.389242694532044
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z1111ZZ  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.38924269453204  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  Z1111Z1  gave for s =  0.07871093750000001   minimal norm  27.38924269453204
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z11111Z  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  26.246746102465153  for s =  0.1384765625
# Flow step output with generator type  single_commutator using string  Z111111  gave for s =  0.1384765625   minimal norm  26.246746102465153
#     Found minimum norm =  27.712814330648275  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZZZZZ  gave for s =  0.0001953125   minimal norm  27.712814330648275
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZZZZ1  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.38924269453204  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  1ZZZZ1Z  gave for s =  0.07871093750000001   minimal norm  27.38924269453204
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZZZ11  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.389242694532044  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  1ZZZ1ZZ  gave for s =  0.07871093750000001   minimal norm  27.389242694532044
#     Found minimum norm =  26.805047791067814  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  1ZZZ1Z1  gave for s =  0.08144531250000002   minimal norm  26.805047791067814
#     Found minimum norm =  27.409367165846536  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  1ZZZ11Z  gave for s =  0.07480468750000001   minimal norm  27.409367165846536
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZZ111  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.389242694532044  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  1ZZ1ZZZ  gave for s =  0.07871093750000001   minimal norm  27.389242694532044
#     Found minimum norm =  26.829466202654253  for s =  0.08027343750000002
# Flow step output with generator type  single_commutator using string  1ZZ1ZZ1  gave for s =  0.08027343750000002   minimal norm  26.829466202654253
#     Found minimum norm =  26.11824575799507  for s =  0.07949218750000002
# Flow step output with generator type  single_commutator using string  1ZZ1Z1Z  gave for s =  0.07949218750000002   minimal norm  26.11824575799507
#     Found minimum norm =  26.805047791067818  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  1ZZ1Z11  gave for s =  0.08144531250000002   minimal norm  26.805047791067818
#     Found minimum norm =  27.409367165846536  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  1ZZ11ZZ  gave for s =  0.07480468750000001   minimal norm  27.409367165846536
#     Found minimum norm =  26.82946620265425  for s =  0.08027343750000002
# Flow step output with generator type  single_commutator using string  1ZZ11Z1  gave for s =  0.08027343750000002   minimal norm  26.82946620265425
#     Found minimum norm =  27.40936716584654  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  1ZZ111Z  gave for s =  0.07480468750000001   minimal norm  27.40936716584654
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZ1111  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.366334467624814  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  1Z1ZZZZ  gave for s =  0.08144531250000002   minimal norm  27.366334467624814
#     Found minimum norm =  26.805047791067818  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  1Z1ZZZ1  gave for s =  0.08144531250000002   minimal norm  26.805047791067818
#     Found minimum norm =  26.118245757995066  for s =  0.07949218750000002
# Flow step output with generator type  single_commutator using string  1Z1ZZ1Z  gave for s =  0.07949218750000002   minimal norm  26.118245757995066
#     Found minimum norm =  26.805047791067818  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  1Z1ZZ11  gave for s =  0.08144531250000002   minimal norm  26.805047791067818
#     Found minimum norm =  26.094534239031546  for s =  0.08027343750000002
# Flow step output with generator type  single_commutator using string  1Z1Z1ZZ  gave for s =  0.08027343750000002   minimal norm  26.094534239031546
#     Found minimum norm =  25.347119668007988  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  1Z1Z1Z1  gave for s =  0.07480468750000001   minimal norm  25.347119668007988
#     Found minimum norm =  26.118245757995066  for s =  0.07949218750000002
# Flow step output with generator type  single_commutator using string  1Z1Z11Z  gave for s =  0.07949218750000002   minimal norm  26.118245757995066
#     Found minimum norm =  26.779031117172952  for s =  0.08300781250000001
# Flow step output with generator type  single_commutator using string  1Z1Z111  gave for s =  0.08300781250000001   minimal norm  26.779031117172952
#     Found minimum norm =  27.389242694532044  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  1Z11ZZZ  gave for s =  0.07871093750000001   minimal norm  27.389242694532044
#     Found minimum norm =  26.829466202654253  for s =  0.08027343750000002
# Flow step output with generator type  single_commutator using string  1Z11ZZ1  gave for s =  0.08027343750000002   minimal norm  26.829466202654253
#     Found minimum norm =  26.118245757995073  for s =  0.07949218750000002
# Flow step output with generator type  single_commutator using string  1Z11Z1Z  gave for s =  0.07949218750000002   minimal norm  26.118245757995073
#     Found minimum norm =  26.805047791067818  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  1Z11Z11  gave for s =  0.08144531250000002   minimal norm  26.805047791067818
#     Found minimum norm =  27.389242694532044  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  1Z111ZZ  gave for s =  0.07871093750000001   minimal norm  27.389242694532044
#     Found minimum norm =  26.805047791067818  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  1Z111Z1  gave for s =  0.08144531250000002   minimal norm  26.805047791067818
#     Found minimum norm =  27.38924269453204  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  1Z1111Z  gave for s =  0.07871093750000001   minimal norm  27.38924269453204
#     Found minimum norm =  24.881988031138306  for s =  0.11074218749999999
# Flow step output with generator type  single_commutator using string  1Z11111  gave for s =  0.11074218749999999   minimal norm  24.881988031138306
#     Found minimum norm =  27.71281433064827  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11ZZZZZ  gave for s =  0.0001953125   minimal norm  27.71281433064827
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11ZZZZ1  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.38924269453204  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  11ZZZ1Z  gave for s =  0.07871093750000001   minimal norm  27.38924269453204
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11ZZZ11  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.389242694532044  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  11ZZ1ZZ  gave for s =  0.07871093750000001   minimal norm  27.389242694532044
#     Found minimum norm =  26.805047791067814  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  11ZZ1Z1  gave for s =  0.08144531250000002   minimal norm  26.805047791067814
#     Found minimum norm =  27.409367165846536  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  11ZZ11Z  gave for s =  0.07480468750000001   minimal norm  27.409367165846536
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11ZZ111  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.366334467624814  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  11Z1ZZZ  gave for s =  0.08144531250000002   minimal norm  27.366334467624814
#     Found minimum norm =  26.805047791067818  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  11Z1ZZ1  gave for s =  0.08144531250000002   minimal norm  26.805047791067818
#     Found minimum norm =  26.094534239031542  for s =  0.08027343750000002
# Flow step output with generator type  single_commutator using string  11Z1Z1Z  gave for s =  0.08027343750000002   minimal norm  26.094534239031542
#     Found minimum norm =  26.779031117172952  for s =  0.08300781250000001
# Flow step output with generator type  single_commutator using string  11Z1Z11  gave for s =  0.08300781250000001   minimal norm  26.779031117172952
#     Found minimum norm =  27.389242694532044  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  11Z11ZZ  gave for s =  0.07871093750000001   minimal norm  27.389242694532044
#     Found minimum norm =  26.805047791067814  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  11Z11Z1  gave for s =  0.08144531250000002   minimal norm  26.805047791067814
#     Found minimum norm =  27.38924269453204  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  11Z111Z  gave for s =  0.07871093750000001   minimal norm  27.38924269453204
#     Found minimum norm =  24.881988031138306  for s =  0.11074218749999999
# Flow step output with generator type  single_commutator using string  11Z1111  gave for s =  0.11074218749999999   minimal norm  24.881988031138306
#     Found minimum norm =  27.71281433064827  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  111ZZZZ  gave for s =  0.0001953125   minimal norm  27.71281433064827
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  111ZZZ1  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.389242694532044  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  111ZZ1Z  gave for s =  0.07871093750000001   minimal norm  27.389242694532044
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  111ZZ11  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.366334467624814  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  111Z1ZZ  gave for s =  0.08144531250000002   minimal norm  27.366334467624814
#     Found minimum norm =  26.779031117172956  for s =  0.08300781250000001
# Flow step output with generator type  single_commutator using string  111Z1Z1  gave for s =  0.08300781250000001   minimal norm  26.779031117172956
#     Found minimum norm =  27.38924269453204  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  111Z11Z  gave for s =  0.07871093750000001   minimal norm  27.38924269453204
#     Found minimum norm =  24.881988031138306  for s =  0.11074218749999999
# Flow step output with generator type  single_commutator using string  111Z111  gave for s =  0.11074218749999999   minimal norm  24.881988031138306
#     Found minimum norm =  27.71281433064827  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1111ZZZ  gave for s =  0.0001953125   minimal norm  27.71281433064827
#     Found minimum norm =  27.71281292110548  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1111ZZ1  gave for s =  0.0001953125   minimal norm  27.71281292110548
#     Found minimum norm =  27.36633446762481  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  1111Z1Z  gave for s =  0.08144531250000002   minimal norm  27.36633446762481
#     Found minimum norm =  24.881988031138306  for s =  0.11074218749999999
# Flow step output with generator type  single_commutator using string  1111Z11  gave for s =  0.11074218749999999   minimal norm  24.881988031138306
#     Found minimum norm =  27.71281433064827  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111ZZ  gave for s =  0.0001953125   minimal norm  27.71281433064827
#     Found minimum norm =  24.881988031138306  for s =  0.11074218749999999
# Flow step output with generator type  single_commutator using string  11111Z1  gave for s =  0.11074218749999999   minimal norm  24.881988031138306
#     Found minimum norm =  26.246746102465153  for s =  0.1384765625
# Flow step output with generator type  single_commutator using string  111111Z  gave for s =  0.1384765625   minimal norm  26.246746102465153
#     Found minimum norm =  27.712812921102035  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1111111  gave for s =  0.0001953125   minimal norm  27.712812921102035
#     Found minimum norm =  19.981559829257154  for s =  0.05253906250000001
# Found that canonical is better because  19.981559829257154 24.881988031138306
#     Found minimum norm =  19.981559829257154  for s =  0.05253906250000001
# Flowing forwards with type  canonical
# []
# Flow step  1
#     Found minimum norm =  19.981559829257154  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZZZZZZ  gave for s =  0.0001953125   minimal norm  19.981559829257154
#     Found minimum norm =  19.908402249154115  for s =  0.14980468750000003
# Flow step output with generator type  single_commutator using string  ZZZZZZ1  gave for s =  0.14980468750000003   minimal norm  19.908402249154115
#     Found minimum norm =  19.094520042860225  for s =  0.19980468750000002
# Flow step output with generator type  single_commutator using string  ZZZZZ1Z  gave for s =  0.19980468750000002   minimal norm  19.094520042860225
#     Found minimum norm =  19.981560431266086  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZZZZ11  gave for s =  0.0001953125   minimal norm  19.981560431266086
#     Found minimum norm =  19.703356402224834  for s =  0.14980468750000003
# Flow step output with generator type  single_commutator using string  ZZZZ1ZZ  gave for s =  0.14980468750000003   minimal norm  19.703356402224834
#     Found minimum norm =  18.387420000121487  for s =  0.18691406249999998
# Flow step output with generator type  single_commutator using string  ZZZZ1Z1  gave for s =  0.18691406249999998   minimal norm  18.387420000121487
#     Found minimum norm =  19.87645164813304  for s =  0.0958984375
# Flow step output with generator type  single_commutator using string  ZZZZ11Z  gave for s =  0.0958984375   minimal norm  19.87645164813304
#     Found minimum norm =  19.981560421278765  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZZZ111  gave for s =  0.0001953125   minimal norm  19.981560421278765
#     Found minimum norm =  19.702438137778195  for s =  0.14980468750000003
# Flow step output with generator type  single_commutator using string  ZZZ1ZZZ  gave for s =  0.14980468750000003   minimal norm  19.702438137778195
#     Found minimum norm =  19.39284891809555  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  ZZZ1ZZ1  gave for s =  0.0998046875   minimal norm  19.39284891809555
#     Found minimum norm =  17.740791248461967  for s =  0.1689453125
# Flow step output with generator type  single_commutator using string  ZZZ1Z1Z  gave for s =  0.1689453125   minimal norm  17.740791248461967
#     Found minimum norm =  18.999202613303606  for s =  0.15683593750000002
# Flow step output with generator type  single_commutator using string  ZZZ1Z11  gave for s =  0.15683593750000002   minimal norm  18.999202613303606
#     Found minimum norm =  19.97536164089473  for s =  0.04472656250000001
# Flow step output with generator type  single_commutator using string  ZZZ11ZZ  gave for s =  0.04472656250000001   minimal norm  19.97536164089473
#     Found minimum norm =  19.408285239215925  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  ZZZ11Z1  gave for s =  0.0998046875   minimal norm  19.408285239215925
#     Found minimum norm =  19.85597654504264  for s =  0.09824218750000001
# Flow step output with generator type  single_commutator using string  ZZZ111Z  gave for s =  0.09824218750000001   minimal norm  19.85597654504264
#     Found minimum norm =  19.981560421278765  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZZ1111  gave for s =  0.0001953125   minimal norm  19.981560421278765
#     Found minimum norm =  19.703356402224834  for s =  0.14980468750000003
# Flow step output with generator type  single_commutator using string  ZZ1ZZZZ  gave for s =  0.14980468750000003   minimal norm  19.703356402224834
#     Found minimum norm =  19.370008401940638  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZZ1  gave for s =  0.0998046875   minimal norm  19.370008401940638
#     Found minimum norm =  18.618012484271087  for s =  0.1337890625
# Flow step output with generator type  single_commutator using string  ZZ1ZZ1Z  gave for s =  0.1337890625   minimal norm  18.618012484271087
#     Found minimum norm =  19.571211283536726  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZ11  gave for s =  0.0998046875   minimal norm  19.571211283536726
#     Found minimum norm =  18.281974244589165  for s =  0.14980468750000003
# Flow step output with generator type  single_commutator using string  ZZ1Z1ZZ  gave for s =  0.14980468750000003   minimal norm  18.281974244589165
#     Found minimum norm =  17.112602125787696  for s =  0.15488281250000002
# Flow step output with generator type  single_commutator using string  ZZ1Z1Z1  gave for s =  0.15488281250000002   minimal norm  17.112602125787696
#     Found minimum norm =  18.587306108448438  for s =  0.1330078125
# Flow step output with generator type  single_commutator using string  ZZ1Z11Z  gave for s =  0.1330078125   minimal norm  18.587306108448438
#     Found minimum norm =  18.999202613303602  for s =  0.15683593750000002
# Flow step output with generator type  single_commutator using string  ZZ1Z111  gave for s =  0.15683593750000002   minimal norm  18.999202613303602
#     Found minimum norm =  19.97536164089473  for s =  0.04472656250000001
# Flow step output with generator type  single_commutator using string  ZZ11ZZZ  gave for s =  0.04472656250000001   minimal norm  19.97536164089473
#     Found minimum norm =  19.622393964591257  for s =  0.0970703125
# Flow step output with generator type  single_commutator using string  ZZ11ZZ1  gave for s =  0.0970703125   minimal norm  19.622393964591257
#     Found minimum norm =  18.604552717430316  for s =  0.1326171875
# Flow step output with generator type  single_commutator using string  ZZ11Z1Z  gave for s =  0.1326171875   minimal norm  18.604552717430316
#     Found minimum norm =  19.571211283536726  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  ZZ11Z11  gave for s =  0.0998046875   minimal norm  19.571211283536726
#     Found minimum norm =  19.969427917491338  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ111ZZ  gave for s =  0.0498046875   minimal norm  19.969427917491338
#     Found minimum norm =  19.39283926755569  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  ZZ111Z1  gave for s =  0.0998046875   minimal norm  19.39283926755569
#     Found minimum norm =  19.85586863679028  for s =  0.0978515625
# Flow step output with generator type  single_commutator using string  ZZ1111Z  gave for s =  0.0978515625   minimal norm  19.85586863679028
#     Found minimum norm =  19.981560431266082  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ11111  gave for s =  0.0001953125   minimal norm  19.981560431266082
#     Found minimum norm =  19.094520042860225  for s =  0.19980468750000002
# Flow step output with generator type  single_commutator using string  Z1ZZZZZ  gave for s =  0.19980468750000002   minimal norm  19.094520042860225
#     Found minimum norm =  18.8961842492976  for s =  0.14980468750000003
# Flow step output with generator type  single_commutator using string  Z1ZZZZ1  gave for s =  0.14980468750000003   minimal norm  18.8961842492976
#     Found minimum norm =  18.237404657045328  for s =  0.14667968750000004
# Flow step output with generator type  single_commutator using string  Z1ZZZ1Z  gave for s =  0.14667968750000004   minimal norm  18.237404657045328
#     Found minimum norm =  19.39283926755569  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  Z1ZZZ11  gave for s =  0.0998046875   minimal norm  19.39283926755569
#     Found minimum norm =  18.618012484271087  for s =  0.1337890625
# Flow step output with generator type  single_commutator using string  Z1ZZ1ZZ  gave for s =  0.1337890625   minimal norm  18.618012484271087
#     Found minimum norm =  17.5513258607741  for s =  0.14003906249999998
# Flow step output with generator type  single_commutator using string  Z1ZZ1Z1  gave for s =  0.14003906249999998   minimal norm  17.5513258607741
#     Found minimum norm =  18.889429976931375  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  Z1ZZ11Z  gave for s =  0.0998046875   minimal norm  18.889429976931375
#     Found minimum norm =  19.408285239215925  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  Z1ZZ111  gave for s =  0.0998046875   minimal norm  19.408285239215925
#     Found minimum norm =  17.740791248461964  for s =  0.1689453125
# Flow step output with generator type  single_commutator using string  Z1Z1ZZZ  gave for s =  0.1689453125   minimal norm  17.740791248461964
#     Found minimum norm =  17.498142035113823  for s =  0.1404296875
# Flow step output with generator type  single_commutator using string  Z1Z1ZZ1  gave for s =  0.1404296875   minimal norm  17.498142035113823
#     Found minimum norm =  15.950693225873263  for s =  0.15449218750000004
# Flow step output with generator type  single_commutator using string  Z1Z1Z1Z  gave for s =  0.15449218750000004   minimal norm  15.950693225873263
#     Found minimum norm =  17.112602125787696  for s =  0.15488281250000002
# Flow step output with generator type  single_commutator using string  Z1Z1Z11  gave for s =  0.15488281250000002   minimal norm  17.112602125787696
#     Found minimum norm =  18.604552717430312  for s =  0.1326171875
# Flow step output with generator type  single_commutator using string  Z1Z11ZZ  gave for s =  0.1326171875   minimal norm  18.604552717430312
#     Found minimum norm =  17.5513258607741  for s =  0.14003906249999998
# Flow step output with generator type  single_commutator using string  Z1Z11Z1  gave for s =  0.14003906249999998   minimal norm  17.5513258607741
#     Found minimum norm =  18.172840277922205  for s =  0.14707031250000002
# Flow step output with generator type  single_commutator using string  Z1Z111Z  gave for s =  0.14707031250000002   minimal norm  18.172840277922205
#     Found minimum norm =  18.387420000121487  for s =  0.18691406249999998
# Flow step output with generator type  single_commutator using string  Z1Z1111  gave for s =  0.18691406249999998   minimal norm  18.387420000121487
#     Found minimum norm =  19.876451648133038  for s =  0.0958984375
# Flow step output with generator type  single_commutator using string  Z11ZZZZ  gave for s =  0.0958984375   minimal norm  19.876451648133038
#     Found minimum norm =  19.42589394895181  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  Z11ZZZ1  gave for s =  0.0998046875   minimal norm  19.42589394895181
#     Found minimum norm =  18.889429976931375  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  Z11ZZ1Z  gave for s =  0.0998046875   minimal norm  18.889429976931375
#     Found minimum norm =  19.622393964591257  for s =  0.0970703125
# Flow step output with generator type  single_commutator using string  Z11ZZ11  gave for s =  0.0970703125   minimal norm  19.622393964591257
#     Found minimum norm =  18.587306108448438  for s =  0.1330078125
# Flow step output with generator type  single_commutator using string  Z11Z1ZZ  gave for s =  0.1330078125   minimal norm  18.587306108448438
#     Found minimum norm =  17.49814203511382  for s =  0.1404296875
# Flow step output with generator type  single_commutator using string  Z11Z1Z1  gave for s =  0.1404296875   minimal norm  17.49814203511382
#     Found minimum norm =  18.87234933781123  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  Z11Z11Z  gave for s =  0.0998046875   minimal norm  18.87234933781123
#     Found minimum norm =  19.39284891809555  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  Z11Z111  gave for s =  0.0998046875   minimal norm  19.39284891809555
#     Found minimum norm =  19.855976545042637  for s =  0.09824218750000001
# Flow step output with generator type  single_commutator using string  Z111ZZZ  gave for s =  0.09824218750000001   minimal norm  19.855976545042637
#     Found minimum norm =  19.42589394895181  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  Z111ZZ1  gave for s =  0.0998046875   minimal norm  19.42589394895181
#     Found minimum norm =  18.172840277922205  for s =  0.14707031250000002
# Flow step output with generator type  single_commutator using string  Z111Z1Z  gave for s =  0.14707031250000002   minimal norm  18.172840277922205
#     Found minimum norm =  19.370008401940634  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  Z111Z11  gave for s =  0.0998046875   minimal norm  19.370008401940634
#     Found minimum norm =  19.85586863679028  for s =  0.0978515625
# Flow step output with generator type  single_commutator using string  Z1111ZZ  gave for s =  0.0978515625   minimal norm  19.85586863679028
#     Found minimum norm =  18.8961842492976  for s =  0.14980468750000003
# Flow step output with generator type  single_commutator using string  Z1111Z1  gave for s =  0.14980468750000003   minimal norm  18.8961842492976
#     Found minimum norm =  19.56514510897345  for s =  0.1408203125
# Flow step output with generator type  single_commutator using string  Z11111Z  gave for s =  0.1408203125   minimal norm  19.56514510897345
#     Found minimum norm =  19.44881303247274  for s =  0.17832031250000002
# Flow step output with generator type  single_commutator using string  Z111111  gave for s =  0.17832031250000002   minimal norm  19.44881303247274
#     Found minimum norm =  19.908402249154115  for s =  0.14980468750000003
# Flow step output with generator type  single_commutator using string  1ZZZZZZ  gave for s =  0.14980468750000003   minimal norm  19.908402249154115
#     Found minimum norm =  19.56514510897345  for s =  0.1408203125
# Flow step output with generator type  single_commutator using string  1ZZZZZ1  gave for s =  0.1408203125   minimal norm  19.56514510897345
#     Found minimum norm =  18.8961842492976  for s =  0.14980468750000003
# Flow step output with generator type  single_commutator using string  1ZZZZ1Z  gave for s =  0.14980468750000003   minimal norm  18.8961842492976
#     Found minimum norm =  19.85586863679028  for s =  0.0978515625
# Flow step output with generator type  single_commutator using string  1ZZZZ11  gave for s =  0.0978515625   minimal norm  19.85586863679028
#     Found minimum norm =  19.370008401940634  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  1ZZZ1ZZ  gave for s =  0.0998046875   minimal norm  19.370008401940634
#     Found minimum norm =  18.1728402779222  for s =  0.14707031250000002
# Flow step output with generator type  single_commutator using string  1ZZZ1Z1  gave for s =  0.14707031250000002   minimal norm  18.1728402779222
#     Found minimum norm =  19.42589394895181  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  1ZZZ11Z  gave for s =  0.0998046875   minimal norm  19.42589394895181
#     Found minimum norm =  19.85597654504264  for s =  0.09824218750000001
# Flow step output with generator type  single_commutator using string  1ZZZ111  gave for s =  0.09824218750000001   minimal norm  19.85597654504264
#     Found minimum norm =  19.39284891809555  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  1ZZ1ZZZ  gave for s =  0.0998046875   minimal norm  19.39284891809555
#     Found minimum norm =  18.87234933781123  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  1ZZ1ZZ1  gave for s =  0.0998046875   minimal norm  18.87234933781123
#     Found minimum norm =  17.49814203511382  for s =  0.1404296875
# Flow step output with generator type  single_commutator using string  1ZZ1Z1Z  gave for s =  0.1404296875   minimal norm  17.49814203511382
#     Found minimum norm =  18.587306108448438  for s =  0.1330078125
# Flow step output with generator type  single_commutator using string  1ZZ1Z11  gave for s =  0.1330078125   minimal norm  18.587306108448438
#     Found minimum norm =  19.622393964591257  for s =  0.0970703125
# Flow step output with generator type  single_commutator using string  1ZZ11ZZ  gave for s =  0.0970703125   minimal norm  19.622393964591257
#     Found minimum norm =  18.88942997693138  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  1ZZ11Z1  gave for s =  0.0998046875   minimal norm  18.88942997693138
#     Found minimum norm =  19.42589394895181  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  1ZZ111Z  gave for s =  0.0998046875   minimal norm  19.42589394895181
#     Found minimum norm =  19.876451648133038  for s =  0.0958984375
# Flow step output with generator type  single_commutator using string  1ZZ1111  gave for s =  0.0958984375   minimal norm  19.876451648133038
#     Found minimum norm =  18.387420000121487  for s =  0.18691406249999998
# Flow step output with generator type  single_commutator using string  1Z1ZZZZ  gave for s =  0.18691406249999998   minimal norm  18.387420000121487
#     Found minimum norm =  18.172840277922205  for s =  0.14707031250000002
# Flow step output with generator type  single_commutator using string  1Z1ZZZ1  gave for s =  0.14707031250000002   minimal norm  18.172840277922205
#     Found minimum norm =  17.5513258607741  for s =  0.14003906249999998
# Flow step output with generator type  single_commutator using string  1Z1ZZ1Z  gave for s =  0.14003906249999998   minimal norm  17.5513258607741
#     Found minimum norm =  18.604552717430312  for s =  0.1326171875
# Flow step output with generator type  single_commutator using string  1Z1ZZ11  gave for s =  0.1326171875   minimal norm  18.604552717430312
#     Found minimum norm =  17.112602125787696  for s =  0.15488281250000002
# Flow step output with generator type  single_commutator using string  1Z1Z1ZZ  gave for s =  0.15488281250000002   minimal norm  17.112602125787696
#     Found minimum norm =  15.950693225873263  for s =  0.15449218750000004
# Flow step output with generator type  single_commutator using string  1Z1Z1Z1  gave for s =  0.15449218750000004   minimal norm  15.950693225873263
#     Found minimum norm =  17.49814203511382  for s =  0.1404296875
# Flow step output with generator type  single_commutator using string  1Z1Z11Z  gave for s =  0.1404296875   minimal norm  17.49814203511382
#     Found minimum norm =  17.740791248461964  for s =  0.1689453125
# Flow step output with generator type  single_commutator using string  1Z1Z111  gave for s =  0.1689453125   minimal norm  17.740791248461964
#     Found minimum norm =  19.408285239215925  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  1Z11ZZZ  gave for s =  0.0998046875   minimal norm  19.408285239215925
#     Found minimum norm =  18.889429976931375  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  1Z11ZZ1  gave for s =  0.0998046875   minimal norm  18.889429976931375
#     Found minimum norm =  17.5513258607741  for s =  0.14003906249999998
# Flow step output with generator type  single_commutator using string  1Z11Z1Z  gave for s =  0.14003906249999998   minimal norm  17.5513258607741
#     Found minimum norm =  18.618012484271087  for s =  0.1337890625
# Flow step output with generator type  single_commutator using string  1Z11Z11  gave for s =  0.1337890625   minimal norm  18.618012484271087
#     Found minimum norm =  19.39283926755569  for s =  0.0998046875
# ...
#     Found minimum norm =  10.632072404870064  for s =  0.020898437500000002
# Flow step output with generator type  single_commutator using string  Z11Z111  gave for s =  0.020898437500000002   minimal norm  10.632072404870064
#     Found minimum norm =  10.618745791631035  for s =  0.0271484375
# Flow step output with generator type  single_commutator using string  Z111ZZZ  gave for s =  0.0271484375   minimal norm  10.618745791631035
#     Found minimum norm =  10.633739014974969  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z111ZZ1  gave for s =  0.0001953125   minimal norm  10.633739014974969
#     Found minimum norm =  10.612995127619849  for s =  0.0646484375
# Flow step output with generator type  single_commutator using string  Z111Z1Z  gave for s =  0.0646484375   minimal norm  10.612995127619849
#     Found minimum norm =  10.585993101172793  for s =  0.0654296875
# Flow step output with generator type  single_commutator using string  Z111Z11  gave for s =  0.0654296875   minimal norm  10.585993101172793
#     Found minimum norm =  10.617680900992047  for s =  0.04082031250000001
# Flow step output with generator type  single_commutator using string  Z1111ZZ  gave for s =  0.04082031250000001   minimal norm  10.617680900992047
#     Found minimum norm =  10.633745663018315  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z1111Z1  gave for s =  0.0001953125   minimal norm  10.633745663018315
#     Found minimum norm =  10.632871474300485  for s =  0.0072265625
# Flow step output with generator type  single_commutator using string  Z11111Z  gave for s =  0.0072265625   minimal norm  10.632871474300485
#     Found minimum norm =  10.453680176006795  for s =  0.0833984375
# Flow step output with generator type  single_commutator using string  Z111111  gave for s =  0.0833984375   minimal norm  10.453680176006795
#     Found minimum norm =  10.629724288607836  for s =  0.0134765625
# Flow step output with generator type  single_commutator using string  1ZZZZZZ  gave for s =  0.0134765625   minimal norm  10.629724288607836
#     Found minimum norm =  10.598216903380564  for s =  0.047460937499999994
# Flow step output with generator type  single_commutator using string  1ZZZZZ1  gave for s =  0.047460937499999994   minimal norm  10.598216903380564
#     Found minimum norm =  10.632962520953514  for s =  0.0126953125
# Flow step output with generator type  single_commutator using string  1ZZZZ1Z  gave for s =  0.0126953125   minimal norm  10.632962520953514
#     Found minimum norm =  10.633776480710997  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZZZ11  gave for s =  0.0001953125   minimal norm  10.633776480710997
#     Found minimum norm =  10.614127003281583  for s =  0.046289062500000006
# Flow step output with generator type  single_commutator using string  1ZZZ1ZZ  gave for s =  0.046289062500000006   minimal norm  10.614127003281583
#     Found minimum norm =  10.633673393721217  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZZ1Z1  gave for s =  0.0001953125   minimal norm  10.633673393721217
#     Found minimum norm =  10.632659842951655  for s =  0.009179687500000002
# Flow step output with generator type  single_commutator using string  1ZZZ11Z  gave for s =  0.009179687500000002   minimal norm  10.632659842951655
#     Found minimum norm =  10.627135483274163  for s =  0.0181640625
# Flow step output with generator type  single_commutator using string  1ZZZ111  gave for s =  0.0181640625   minimal norm  10.627135483274163
#     Found minimum norm =  10.632446927227846  for s =  0.0181640625
# Flow step output with generator type  single_commutator using string  1ZZ1ZZZ  gave for s =  0.0181640625   minimal norm  10.632446927227846
#     Found minimum norm =  10.597247402752664  for s =  0.05996093749999999
# Flow step output with generator type  single_commutator using string  1ZZ1ZZ1  gave for s =  0.05996093749999999   minimal norm  10.597247402752664
#     Found minimum norm =  10.63429973574891  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZ1Z1Z  gave for s =  0.0001953125   minimal norm  10.63429973574891
#     Found minimum norm =  10.614760609540097  for s =  0.03574218750000001
# Flow step output with generator type  single_commutator using string  1ZZ1Z11  gave for s =  0.03574218750000001   minimal norm  10.614760609540097
#     Found minimum norm =  10.591228930055784  for s =  0.0544921875
# Flow step output with generator type  single_commutator using string  1ZZ11ZZ  gave for s =  0.0544921875   minimal norm  10.591228930055784
#     Found minimum norm =  10.604222443079811  for s =  0.034570312500000006
# Flow step output with generator type  single_commutator using string  1ZZ11Z1  gave for s =  0.034570312500000006   minimal norm  10.604222443079811
#     Found minimum norm =  10.633716035449014  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZ111Z  gave for s =  0.0001953125   minimal norm  10.633716035449014
#     Found minimum norm =  10.633685804054156  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZ1111  gave for s =  0.0001953125   minimal norm  10.633685804054156
#     Found minimum norm =  10.629901165556909  for s =  0.0162109375
# Flow step output with generator type  single_commutator using string  1Z1ZZZZ  gave for s =  0.0162109375   minimal norm  10.629901165556909
#     Found minimum norm =  10.633814961629206  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z1ZZZ1  gave for s =  0.0001953125   minimal norm  10.633814961629206
#     Found minimum norm =  10.626825784327853  for s =  0.0158203125
# Flow step output with generator type  single_commutator using string  1Z1ZZ1Z  gave for s =  0.0158203125   minimal norm  10.626825784327853
#     Found minimum norm =  10.623874102277792  for s =  0.024804687500000002
# Flow step output with generator type  single_commutator using string  1Z1ZZ11  gave for s =  0.024804687500000002   minimal norm  10.623874102277792
#     Found minimum norm =  10.63033413535633  for s =  0.0134765625
# Flow step output with generator type  single_commutator using string  1Z1Z1ZZ  gave for s =  0.0134765625   minimal norm  10.63033413535633
#     Found minimum norm =  10.629708249196023  for s =  0.009179687500000002
# Flow step output with generator type  single_commutator using string  1Z1Z1Z1  gave for s =  0.009179687500000002   minimal norm  10.629708249196023
#     Found minimum norm =  10.628649426857566  for s =  0.020117187500000005
# Flow step output with generator type  single_commutator using string  1Z1Z11Z  gave for s =  0.020117187500000005   minimal norm  10.628649426857566
#     Found minimum norm =  10.633710667558287  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z1Z111  gave for s =  0.0001953125   minimal norm  10.633710667558287
#     Found minimum norm =  10.633752034497817  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z11ZZZ  gave for s =  0.0001953125   minimal norm  10.633752034497817
#     Found minimum norm =  10.627946154807622  for s =  0.020117187500000005
# Flow step output with generator type  single_commutator using string  1Z11ZZ1  gave for s =  0.020117187500000005   minimal norm  10.627946154807622
#     Found minimum norm =  10.627788728766314  for s =  0.0232421875
# Flow step output with generator type  single_commutator using string  1Z11Z1Z  gave for s =  0.0232421875   minimal norm  10.627788728766314
#     Found minimum norm =  10.633194099275055  for s =  0.009960937500000003
# Flow step output with generator type  single_commutator using string  1Z11Z11  gave for s =  0.009960937500000003   minimal norm  10.633194099275055
#     Found minimum norm =  10.633652140837087  for s =  0.0009765625
# Flow step output with generator type  single_commutator using string  1Z111ZZ  gave for s =  0.0009765625   minimal norm  10.633652140837087
#     Found minimum norm =  10.633709433951282  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z111Z1  gave for s =  0.0001953125   minimal norm  10.633709433951282
#     Found minimum norm =  10.63334445220006  for s =  0.0052734375
# Flow step output with generator type  single_commutator using string  1Z1111Z  gave for s =  0.0052734375   minimal norm  10.63334445220006
#     Found minimum norm =  10.607592101594964  for s =  0.0322265625
# Flow step output with generator type  single_commutator using string  1Z11111  gave for s =  0.0322265625   minimal norm  10.607592101594964
#     Found minimum norm =  10.633663012819191  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11ZZZZZ  gave for s =  0.0001953125   minimal norm  10.633663012819191
#     Found minimum norm =  10.633123475847482  for s =  0.0087890625
# Flow step output with generator type  single_commutator using string  11ZZZZ1  gave for s =  0.0087890625   minimal norm  10.633123475847482
#     Found minimum norm =  10.601538914699836  for s =  0.0353515625
# Flow step output with generator type  single_commutator using string  11ZZZ1Z  gave for s =  0.0353515625   minimal norm  10.601538914699836
#     Found minimum norm =  10.619408262925019  for s =  0.029882812499999998
# Flow step output with generator type  single_commutator using string  11ZZZ11  gave for s =  0.029882812499999998   minimal norm  10.619408262925019
#     Found minimum norm =  10.632121850672672  for s =  0.0115234375
# Flow step output with generator type  single_commutator using string  11ZZ1ZZ  gave for s =  0.0115234375   minimal norm  10.632121850672672
#     Found minimum norm =  10.619897659463275  for s =  0.0244140625
# Flow step output with generator type  single_commutator using string  11ZZ1Z1  gave for s =  0.0244140625   minimal norm  10.619897659463275
#     Found minimum norm =  10.591824591539037  for s =  0.0595703125
# Flow step output with generator type  single_commutator using string  11ZZ11Z  gave for s =  0.0595703125   minimal norm  10.591824591539037
#     Found minimum norm =  10.633710702400965  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11ZZ111  gave for s =  0.0001953125   minimal norm  10.633710702400965
#     Found minimum norm =  10.619072934665022  for s =  0.026367187500000003
# Flow step output with generator type  single_commutator using string  11Z1ZZZ  gave for s =  0.026367187500000003   minimal norm  10.619072934665022
#     Found minimum norm =  10.63019464735158  for s =  0.0158203125
# Flow step output with generator type  single_commutator using string  11Z1ZZ1  gave for s =  0.0158203125   minimal norm  10.63019464735158
#     Found minimum norm =  10.630662252304818  for s =  0.017773437500000003
# Flow step output with generator type  single_commutator using string  11Z1Z1Z  gave for s =  0.017773437500000003   minimal norm  10.630662252304818
#     Found minimum norm =  10.630978932821563  for s =  0.0154296875
# Flow step output with generator type  single_commutator using string  11Z1Z11  gave for s =  0.0154296875   minimal norm  10.630978932821563
#     Found minimum norm =  10.624031065652186  for s =  0.038476562500000006
# Flow step output with generator type  single_commutator using string  11Z11ZZ  gave for s =  0.038476562500000006   minimal norm  10.624031065652186
#     Found minimum norm =  10.633767325118738  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11Z11Z1  gave for s =  0.0001953125   minimal norm  10.633767325118738
#     Found minimum norm =  10.633729514497613  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11Z111Z  gave for s =  0.0001953125   minimal norm  10.633729514497613
#     Found minimum norm =  10.460599643954978  for s =  0.07988281250000002
# Flow step output with generator type  single_commutator using string  11Z1111  gave for s =  0.07988281250000002   minimal norm  10.460599643954978
#     Found minimum norm =  10.624754800020037  for s =  0.018945312500000002
# Flow step output with generator type  single_commutator using string  111ZZZZ  gave for s =  0.018945312500000002   minimal norm  10.624754800020037
#     Found minimum norm =  10.615422620659828  for s =  0.03886718750000001
# Flow step output with generator type  single_commutator using string  111ZZZ1  gave for s =  0.03886718750000001   minimal norm  10.615422620659828
#     Found minimum norm =  10.624883701519625  for s =  0.03886718750000001
# Flow step output with generator type  single_commutator using string  111ZZ1Z  gave for s =  0.03886718750000001   minimal norm  10.624883701519625
#     Found minimum norm =  10.616981159251377  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  111ZZ11  gave for s =  0.0498046875   minimal norm  10.616981159251377
#     Found minimum norm =  10.633687001128834  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  111Z1ZZ  gave for s =  0.0001953125   minimal norm  10.633687001128834
#     Found minimum norm =  10.633860489298355  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  111Z1Z1  gave for s =  0.0001953125   minimal norm  10.633860489298355
#     Found minimum norm =  10.621445696245475  for s =  0.0341796875
# Flow step output with generator type  single_commutator using string  111Z11Z  gave for s =  0.0341796875   minimal norm  10.621445696245475
#     Found minimum norm =  10.482008465721195  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  111Z111  gave for s =  0.07285156250000001   minimal norm  10.482008465721195
#     Found minimum norm =  10.631686409244107  for s =  0.016992187500000002
# Flow step output with generator type  single_commutator using string  1111ZZZ  gave for s =  0.016992187500000002   minimal norm  10.631686409244107
#     Found minimum norm =  10.634041707624807  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1111ZZ1  gave for s =  0.0001953125   minimal norm  10.634041707624807
#     Found minimum norm =  10.605521496231164  for s =  0.0302734375
# Flow step output with generator type  single_commutator using string  1111Z1Z  gave for s =  0.0302734375   minimal norm  10.605521496231164
#     Found minimum norm =  10.364356019783783  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  1111Z11  gave for s =  0.0998046875   minimal norm  10.364356019783783
#     Found minimum norm =  10.634064121174934  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111ZZ  gave for s =  0.0001953125   minimal norm  10.634064121174934
#     Found minimum norm =  10.585720976484641  for s =  0.0439453125
# Flow step output with generator type  single_commutator using string  11111Z1  gave for s =  0.0439453125   minimal norm  10.585720976484641
#     Found minimum norm =  10.369163703072203  for s =  0.1244140625
# Flow step output with generator type  single_commutator using string  111111Z  gave for s =  0.1244140625   minimal norm  10.369163703072203
#     Found minimum norm =  10.633663263935862  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1111111  gave for s =  0.0001953125   minimal norm  10.633663263935862
#     Found minimum norm =  10.418222517804411  for s =  0.0119140625
# Found that canonical is worse because  10.418222517804411 10.364356019783783
#     Found minimum norm =  10.364356019783783  for s =  0.0998046875
# Flowing forwards with type  single_commutator
# []

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

def plot_iteration_results(  ):
    flow.run_param_rc(fontsize=18)
    flow_results = flow.flow_outputs

    f=plt.figure(figsize = ( 8,7 ))
    n=1
    ax_a = f.add_subplot(1,n,1)
    norms = flow_results['minimal_norm_sigma_H_s']
    x_axis = [sum(flow_results['minimizing_flow_step'][:k])for k in range( 1, len(flow_results['minimizing_flow_step'])+1)]

    plt.plot( x_axis, norms, '-o')   
    N = 10
    k=0
    for xy in zip([x+.01 for x in x_axis[0:N]], 
                  [n - 0.07 for n in norms[0:N]]):  
        if k == 0 or k == 9 or k == 8 or k== 7 or k ==6:
            a=1
        else:
            plt.annotate('k = ' + str(k) + ': ' + flow_results['strs_of_minimizer_Z'][k-1], xy=xy, textcoords='data', fontsize=16)
        k=k+1
    #10
    plt.annotate('k = ' + str(k) + ': ' + flow_results['strs_of_minimizer_Z'][k-1], 
                 xy=(x_axis[-1]-.08,norms[-1]-.7), textcoords='data', fontsize=16)
#9
    plt.annotate('k = ' + str(k-1) + ': ' + flow_results['strs_of_minimizer_Z'][k-2], 
                 xy=(x_axis[k-1]-.2,norms[k-1]-.7), textcoords='data', fontsize=17)
#8
    plt.annotate('k = ' + str(k-2) + ': ' + flow_results['strs_of_minimizer_Z'][k-3], 
                  xy=(x_axis[k-2]+.01,norms[k-2]-0.15), textcoords='data', fontsize=17)
#7
    plt.annotate('k = ' + str(k-3) + ': ' + flow_results['strs_of_minimizer_Z'][k-4], 
                  xy=(x_axis[k-3]-.09,norms[k-3]-.9), textcoords='data', fontsize=17)
#6
    plt.annotate('k = ' + str(k-4) + ': ' + flow_results['strs_of_minimizer_Z'][k-5], 
                  xy=(x_axis[k-4]+.021,norms[k-4]-.4), textcoords='data', fontsize=17)
    plt.annotate('c)', xy = (-.1,1.02),
                 xycoords='axes fraction')
    x_labels_rounded = [ round(x, 2 ) for x in x_axis ]
    x_labels_rounded = [0] + x_labels_rounded[1:9]  + [max(x_labels_rounded)]
    x_labels_rounded.pop(3)
    x_labels_rounded.pop(2)
    x_labels_rounded.pop(-2)
    x_labels_rounded.pop(1)
    x_labels_rounded.pop(-2)

#     x_labels_rounded.pop(4)
    
    plt.xticks(x_labels_rounded)
    y_labels_rounded = [ round(y, 1 ) for y in norms ]
    y_labels_rounded = y_labels_rounded[0:5] + [min(y_labels_rounded)]
    plt.yticks(y_labels_rounded)
    plt.grid()
    plt.xlabel(r'Total DBI duration $\ell$')
    plt.title(r'Norm off-diagonal $\vert\vert\sigma(\hat H_k)\vert\vert$')
    a =-.1
    b = 1.05
 
    axin1 = ax_a.inset_axes([0.2,.7, 0.31, 0.27])
    inset1 = axin1.imshow( H_TFIM, cmap='RdBu' )
    divider1 = make_axes_locatable(axin1)
    div_ax = divider1.append_axes("right", size="10%", pad=0.05)
    cbar1 = plt.colorbar(inset1, cax = div_ax )
    range_plot = np.max( np.abs( H_TFIM ) )
#     cbar1.set_clim( -range_plot, range_plot )
    axin1.set_yticks(range(2**L))  
    axin1.set_xticklabels([1]+['']*(2**L-2)+[2**L])
    axin1.set_yticklabels([1]+['']*(2**L-2)+[2**L])
    axin1.set_xticks(range(2**L))
    ax_a.annotate(' ',
            xy=(x_axis[0]+.01, norms[0]),  # theta, radius
            xytext=(0.24, 0.81),    # fraction, fraction
            textcoords='figure fraction',
            arrowprops=dict(facecolor='gray', shrink=0.01),
            horizontalalignment='left',
            verticalalignment='bottom')
#     axin1.set_xlabel(r'$j$')
#     axin1.set_title(r'$k$')
#     axin1.grid()
    axin2 = ax_a.inset_axes([0.65,.32, 0.31, 0.27])
    inset2 = axin2.imshow(flow_results['optimally_flowed_H'][-1], cmap='RdBu')

    divider2 = make_axes_locatable(axin2)
    div_ax2 = divider2.append_axes("right", size="10%", pad=0.05)
    cbar2 = plt.colorbar(inset2, cax = div_ax2 )
    ax_a.annotate(' ',
        xy=(x_axis[-1], 11.4),  # theta, radius
        xytext=(.95, .3),    # fraction, fraction
        textcoords='axes fraction',
        arrowprops=dict(facecolor='gray', shrink=0.05),
        horizontalalignment='left',
        verticalalignment='bottom')
    
    axin3 = ax_a.inset_axes([0.65,.7, 0.31, 0.27])
    inset3 = axin3.imshow(flow_results['optimally_flowed_H'][2], cmap='RdBu')

    divider3 = make_axes_locatable(axin3)
    div_ax3 = divider3.append_axes("right", size="10%", pad=0.05)
    cbar2 = plt.colorbar(inset3, cax = div_ax3 )
    ax_a.annotate(' ',
        xy=(x_axis[2]+.01, norms[2]+.6),  # theta, radius
        xytext=(0.65, 0.67),    # fraction, fraction
        textcoords='axes fraction',
        arrowprops=dict(facecolor='gray', shrink=0.05),
        horizontalalignment='left',
        verticalalignment='bottom')
    axin2.set_yticks(range(2**L))  
    axin2.set_xticklabels([1]+['']*(2**L-2)+[2**L])
    axin2.set_yticklabels([1]+['']*(2**L-2)+[2**L])
    axin2.set_xticks(range(2**L))    
    axin3.set_yticks(range(2**L))  
    axin3.set_xticklabels([1]+['']*(2**L-2)+[2**L])
    axin3.set_yticklabels([1]+['']*(2**L-2)+[2**L])
    axin3.set_xticks(range(2**L))
    chosen_steps = [1,2]
    plt.savefig( 'figs/variational_norm_'+hamiltonian_name+'.pdf')
    
plot_iteration_results()
# Out:
# /tmp/ipykernel_76556/2508838526.py:68: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axin1.set_xticklabels([1]+['']*(2**L-2)+[2**L])
# /tmp/ipykernel_76556/2508838526.py:109: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axin2.set_xticklabels([1]+['']*(2**L-2)+[2**L])
# /tmp/ipykernel_76556/2508838526.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axin3.set_xticklabels([1]+['']*(2**L-2)+[2**L])

# %% [markdown]
# #### Simple plot for debugging

# %%
H = flow.flow_outputs['final_flowed_H'][-1]

plt.figure()
plt.subplot(121)
plt.imshow(abs(H_TLFIM), cmap='RdBu')
plt.colorbar()
plt.subplot(122)
plt.imshow(abs(H), cmap='RdBu')
plt.colorbar()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_76556/3008398530.py in <module>
#       3 plt.figure()
#       4 plt.subplot(121)
# ----> 5 plt.imshow(abs(H_TLFIM), cmap='RdBu')
#       6 plt.colorbar()
#       7 plt.subplot(122)
#
# NameError: name 'H_TLFIM' is not defined

# %% [markdown]
# This variable stores or strings that have been tested in each step

# %%
print(flow.flow_outputs['all_Z_names'])

# %% [markdown]
# and these are the strings that gave the optimal generator to decrease the norm of the off-diagonal restriction

# %%
flow.flow_outputs['strs_of_minimizer_Z']

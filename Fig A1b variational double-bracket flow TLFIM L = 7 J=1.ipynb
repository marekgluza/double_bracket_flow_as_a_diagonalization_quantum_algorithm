# %%
from simple_exact_diagonalization_routines.local_matrix_class import *
from scipy.linalg import expm
import matplotlib.pyplot as plt
import time


# System size
L = 7

# Create objects of Pauli operators
X = X_class(L)
Y = Y_class(L)
Z = Z_class(L)
S_plus = S_plus_class(L)
S_minus = S_minus_class(L)

# Trivial initialization of the right size matrix
hamiltonian_name = "TLFIM_J_1_L_" +str(L)
H_TLFIM = 0*np.eye( 2**L ) 

for x in range(L-1):
    H_TLFIM = H_TLFIM + X.at(x+1).dot(X.at(x+2)) + Z.at(x+1)+ X.at(x+1)
H_TLFIM = H_TLFIM + Z.at(L)    + X.at(L)

# %%
from class_double_bracket_flow import *


flow = double_bracket_flow( H_TLFIM )

flow.please_be_exhaustively_verbose = False
flow.please_be_verbose = True

flow.nmb_search_points_minimizing_s_search = 10
flow.flow_step_max = 0.2
flow.nmb_flow_steps = 20
flow.please_use_binary_search =  True
flow.please_compute_observables = False

#flow.flow_forwards( )
flow.flow_via_best_Z_search( please_also_check_canonical_bracket = True )

flow.show_flow_forwards_results()
# Out:
# Flow step  0
# Found minimum norm =  37.67684219544857  for s =  0.0833984375
# Flow step output with generator type  single_commutator using string  ZZZZZZZ  gave for s =  0.0833984375   minimal norm  37.67684219544857
# Found minimum norm =  37.83648045367142  for s =  0.08183593750000001
# Flow step output with generator type  single_commutator using string  ZZZZZZ1  gave for s =  0.08183593750000001   minimal norm  37.83648045367142
# Found minimum norm =  37.77199779411732  for s =  0.0724609375
# Flow step output with generator type  single_commutator using string  ZZZZZ1Z  gave for s =  0.0724609375   minimal norm  37.77199779411732
# Found minimum norm =  38.44028197459413  for s =  0.08652343750000001
# Flow step output with generator type  single_commutator using string  ZZZZZ11  gave for s =  0.08652343750000001   minimal norm  38.44028197459413
# Found minimum norm =  37.77199779411732  for s =  0.0724609375
# Flow step output with generator type  single_commutator using string  ZZZZ1ZZ  gave for s =  0.0724609375   minimal norm  37.77199779411732
# Found minimum norm =  37.88758515279914  for s =  0.0716796875
# Flow step output with generator type  single_commutator using string  ZZZZ1Z1  gave for s =  0.0716796875   minimal norm  37.88758515279914
# Found minimum norm =  37.991042178232256  for s =  0.08066406250000002
# Flow step output with generator type  single_commutator using string  ZZZZ11Z  gave for s =  0.08066406250000002   minimal norm  37.991042178232256
# Found minimum norm =  39.030134887388634  for s =  0.09238281250000001
# Flow step output with generator type  single_commutator using string  ZZZZ111  gave for s =  0.09238281250000001   minimal norm  39.030134887388634
# Found minimum norm =  37.771997794117325  for s =  0.0724609375
# Flow step output with generator type  single_commutator using string  ZZZ1ZZZ  gave for s =  0.0724609375   minimal norm  37.771997794117325
# Found minimum norm =  37.89752502626433  for s =  0.0716796875
# Flow step output with generator type  single_commutator using string  ZZZ1ZZ1  gave for s =  0.0716796875   minimal norm  37.89752502626433
# Found minimum norm =  37.615925307731835  for s =  0.0666015625
# Flow step output with generator type  single_commutator using string  ZZZ1Z1Z  gave for s =  0.0666015625   minimal norm  37.615925307731835
# Found minimum norm =  38.54213300323051  for s =  0.07324218750000001
# Flow step output with generator type  single_commutator using string  ZZZ1Z11  gave for s =  0.07324218750000001   minimal norm  38.54213300323051
# Found minimum norm =  37.991042178232256  for s =  0.08066406250000002
# Flow step output with generator type  single_commutator using string  ZZZ11ZZ  gave for s =  0.08066406250000002   minimal norm  37.991042178232256
# Found minimum norm =  38.126228725617004  for s =  0.07949218750000002
# Flow step output with generator type  single_commutator using string  ZZZ11Z1  gave for s =  0.07949218750000002   minimal norm  38.126228725617004
# Found minimum norm =  38.60691250585305  for s =  0.0849609375
# Flow step output with generator type  single_commutator using string  ZZZ111Z  gave for s =  0.0849609375   minimal norm  38.60691250585305
# Found minimum norm =  39.60371565793421  for s =  0.0990234375
# Flow step output with generator type  single_commutator using string  ZZZ1111  gave for s =  0.0990234375   minimal norm  39.60371565793421
# Found minimum norm =  37.77199779411731  for s =  0.0724609375
# Flow step output with generator type  single_commutator using string  ZZ1ZZZZ  gave for s =  0.0724609375   minimal norm  37.77199779411731
# Found minimum norm =  37.897525026264326  for s =  0.0716796875
# Flow step output with generator type  single_commutator using string  ZZ1ZZZ1  gave for s =  0.0716796875   minimal norm  37.897525026264326
# Found minimum norm =  37.66183872399395  for s =  0.0658203125
# Flow step output with generator type  single_commutator using string  ZZ1ZZ1Z  gave for s =  0.0658203125   minimal norm  37.66183872399395
# Found minimum norm =  38.552718864676315  for s =  0.07324218750000001
# Flow step output with generator type  single_commutator using string  ZZ1ZZ11  gave for s =  0.07324218750000001   minimal norm  38.552718864676315
# Found minimum norm =  37.615925307731814  for s =  0.0666015625
# Flow step output with generator type  single_commutator using string  ZZ1Z1ZZ  gave for s =  0.0666015625   minimal norm  37.615925307731814
# Found minimum norm =  37.717162033948426  for s =  0.0658203125
# Flow step output with generator type  single_commutator using string  ZZ1Z1Z1  gave for s =  0.0658203125   minimal norm  37.717162033948426
# Found minimum norm =  38.01015991378071  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  ZZ1Z11Z  gave for s =  0.0705078125   minimal norm  38.01015991378071
# Found minimum norm =  39.1785262424346  for s =  0.07402343750000001
# Flow step output with generator type  single_commutator using string  ZZ1Z111  gave for s =  0.07402343750000001   minimal norm  39.1785262424346
# Found minimum norm =  37.991042178232235  for s =  0.08066406250000002
# Flow step output with generator type  single_commutator using string  ZZ11ZZZ  gave for s =  0.08066406250000002   minimal norm  37.991042178232235
# Found minimum norm =  38.14062610611227  for s =  0.07910156250000001
# Flow step output with generator type  single_commutator using string  ZZ11ZZ1  gave for s =  0.07910156250000001   minimal norm  38.14062610611227
# Found minimum norm =  38.01015991378072  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  ZZ11Z1Z  gave for s =  0.0705078125   minimal norm  38.01015991378072
# Found minimum norm =  38.74999135442724  for s =  0.0833984375
# Flow step output with generator type  single_commutator using string  ZZ11Z11  gave for s =  0.0833984375   minimal norm  38.74999135442724
# Found minimum norm =  38.60691250585305  for s =  0.0849609375
# Flow step output with generator type  single_commutator using string  ZZ111ZZ  gave for s =  0.0849609375   minimal norm  38.60691250585305
# Found minimum norm =  38.74999135442724  for s =  0.0833984375
# Flow step output with generator type  single_commutator using string  ZZ111Z1  gave for s =  0.0833984375   minimal norm  38.74999135442724
# Found minimum norm =  39.21093885006844  for s =  0.08964843750000001
# Flow step output with generator type  single_commutator using string  ZZ1111Z  gave for s =  0.08964843750000001   minimal norm  39.21093885006844
# Found minimum norm =  40.16221318457787  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  ZZ11111  gave for s =  0.0998046875   minimal norm  40.16221318457787
# Found minimum norm =  37.77199779411731  for s =  0.0724609375
# Flow step output with generator type  single_commutator using string  Z1ZZZZZ  gave for s =  0.0724609375   minimal norm  37.77199779411731
# Found minimum norm =  37.89752502626433  for s =  0.0716796875
# Flow step output with generator type  single_commutator using string  Z1ZZZZ1  gave for s =  0.0716796875   minimal norm  37.89752502626433
# Found minimum norm =  37.66183872399395  for s =  0.0658203125
# Flow step output with generator type  single_commutator using string  Z1ZZZ1Z  gave for s =  0.0658203125   minimal norm  37.66183872399395
# Found minimum norm =  38.55271886467632  for s =  0.07324218750000001
# Flow step output with generator type  single_commutator using string  Z1ZZZ11  gave for s =  0.07324218750000001   minimal norm  38.55271886467632
# Found minimum norm =  37.66183872399395  for s =  0.0658203125
# Flow step output with generator type  single_commutator using string  Z1ZZ1ZZ  gave for s =  0.0658203125   minimal norm  37.66183872399395
# Found minimum norm =  37.760748027313106  for s =  0.06503906250000001
# Flow step output with generator type  single_commutator using string  Z1ZZ1Z1  gave for s =  0.06503906250000001   minimal norm  37.760748027313106
# Found minimum norm =  38.01947769588084  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  Z1ZZ11Z  gave for s =  0.0705078125   minimal norm  38.01947769588084
# Found minimum norm =  39.18935767112594  for s =  0.07402343750000001
# Flow step output with generator type  single_commutator using string  Z1ZZ111  gave for s =  0.07402343750000001   minimal norm  39.18935767112594
# Found minimum norm =  37.61592530773182  for s =  0.0666015625
# Flow step output with generator type  single_commutator using string  Z1Z1ZZZ  gave for s =  0.0666015625   minimal norm  37.61592530773182
# Found minimum norm =  37.72441815731783  for s =  0.0658203125
# Flow step output with generator type  single_commutator using string  Z1Z1ZZ1  gave for s =  0.0658203125   minimal norm  37.72441815731783
# Found minimum norm =  37.378217477710535  for s =  0.0623046875
# Flow step output with generator type  single_commutator using string  Z1Z1Z1Z  gave for s =  0.0623046875   minimal norm  37.378217477710535
# Found minimum norm =  38.38718289909952  for s =  0.0666015625
# Flow step output with generator type  single_commutator using string  Z1Z1Z11  gave for s =  0.0666015625   minimal norm  38.38718289909952
# Found minimum norm =  38.01015991378071  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  Z1Z11ZZ  gave for s =  0.0705078125   minimal norm  38.01015991378071
# Found minimum norm =  38.12031447294629  for s =  0.0697265625
# Flow step output with generator type  single_commutator using string  Z1Z11Z1  gave for s =  0.0697265625   minimal norm  38.12031447294629
# Found minimum norm =  38.66709920931766  for s =  0.07207031250000001
# Flow step output with generator type  single_commutator using string  Z1Z111Z  gave for s =  0.07207031250000001   minimal norm  38.66709920931766
# Found minimum norm =  39.780543235651066  for s =  0.07324218750000001
# Flow step output with generator type  single_commutator using string  Z1Z1111  gave for s =  0.07324218750000001   minimal norm  39.780543235651066
# Found minimum norm =  37.991042178232235  for s =  0.08066406250000002
# Flow step output with generator type  single_commutator using string  Z11ZZZZ  gave for s =  0.08066406250000002   minimal norm  37.991042178232235
# Found minimum norm =  38.140626106112265  for s =  0.07910156250000001
# Flow step output with generator type  single_commutator using string  Z11ZZZ1  gave for s =  0.07910156250000001   minimal norm  38.140626106112265
# Found minimum norm =  38.01947769588084  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  Z11ZZ1Z  gave for s =  0.0705078125   minimal norm  38.01947769588084
# Found minimum norm =  38.76675097639218  for s =  0.08300781250000001
# Flow step output with generator type  single_commutator using string  Z11ZZ11  gave for s =  0.08300781250000001   minimal norm  38.76675097639218
# Found minimum norm =  38.010159913780704  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  Z11Z1ZZ  gave for s =  0.0705078125   minimal norm  38.010159913780704
# Found minimum norm =  38.12031447294628  for s =  0.0697265625
# Flow step output with generator type  single_commutator using string  Z11Z1Z1  gave for s =  0.0697265625   minimal norm  38.12031447294628
# Found minimum norm =  38.2718798645793  for s =  0.07832031250000002
# Flow step output with generator type  single_commutator using string  Z11Z11Z  gave for s =  0.07832031250000002   minimal norm  38.2718798645793
# Found minimum norm =  39.362425694977624  for s =  0.0873046875
# Flow step output with generator type  single_commutator using string  Z11Z111  gave for s =  0.0873046875   minimal norm  39.362425694977624
# Found minimum norm =  38.60691250585304  for s =  0.0849609375
# Flow step output with generator type  single_commutator using string  Z111ZZZ  gave for s =  0.0849609375   minimal norm  38.60691250585304
# Found minimum norm =  38.76675097639219  for s =  0.08300781250000001
# Flow step output with generator type  single_commutator using string  Z111ZZ1  gave for s =  0.08300781250000001   minimal norm  38.76675097639219
# Found minimum norm =  38.66709920931767  for s =  0.07207031250000001
# Flow step output with generator type  single_commutator using string  Z111Z1Z  gave for s =  0.07207031250000001   minimal norm  38.66709920931767
# Found minimum norm =  39.362425694977624  for s =  0.0873046875
# Flow step output with generator type  single_commutator using string  Z111Z11  gave for s =  0.0873046875   minimal norm  39.362425694977624
# Found minimum norm =  39.21093885006844  for s =  0.08964843750000001
# Flow step output with generator type  single_commutator using string  Z1111ZZ  gave for s =  0.08964843750000001   minimal norm  39.21093885006844
# Found minimum norm =  39.362425694977624  for s =  0.0873046875
# Flow step output with generator type  single_commutator using string  Z1111Z1  gave for s =  0.0873046875   minimal norm  39.362425694977624
# Found minimum norm =  39.80037721946124  for s =  0.0943359375
# Flow step output with generator type  single_commutator using string  Z11111Z  gave for s =  0.0943359375   minimal norm  39.80037721946124
# Found minimum norm =  38.58681801731143  for s =  0.1240234375
# Flow step output with generator type  single_commutator using string  Z111111  gave for s =  0.1240234375   minimal norm  38.58681801731143
# Found minimum norm =  37.83648045367142  for s =  0.08183593750000001
# Flow step output with generator type  single_commutator using string  1ZZZZZZ  gave for s =  0.08183593750000001   minimal norm  37.83648045367142
# Found minimum norm =  37.991042178232256  for s =  0.08066406250000002
# Flow step output with generator type  single_commutator using string  1ZZZZZ1  gave for s =  0.08066406250000002   minimal norm  37.991042178232256
# Found minimum norm =  37.89752502626433  for s =  0.0716796875
# Flow step output with generator type  single_commutator using string  1ZZZZ1Z  gave for s =  0.0716796875   minimal norm  37.89752502626433
# Found minimum norm =  38.606912505853046  for s =  0.0849609375
# Flow step output with generator type  single_commutator using string  1ZZZZ11  gave for s =  0.0849609375   minimal norm  38.606912505853046
# Found minimum norm =  37.897525026264326  for s =  0.0716796875
# Flow step output with generator type  single_commutator using string  1ZZZ1ZZ  gave for s =  0.0716796875   minimal norm  37.897525026264326
# Found minimum norm =  38.01015991378071  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  1ZZZ1Z1  gave for s =  0.0705078125   minimal norm  38.01015991378071
# Found minimum norm =  38.14062610611227  for s =  0.07910156250000001
# Flow step output with generator type  single_commutator using string  1ZZZ11Z  gave for s =  0.07910156250000001   minimal norm  38.14062610611227
# Found minimum norm =  39.210938850068445  for s =  0.08964843750000001
# Flow step output with generator type  single_commutator using string  1ZZZ111  gave for s =  0.08964843750000001   minimal norm  39.210938850068445
# Found minimum norm =  37.89752502626433  for s =  0.0716796875
# Flow step output with generator type  single_commutator using string  1ZZ1ZZZ  gave for s =  0.0716796875   minimal norm  37.89752502626433
# Found minimum norm =  38.019477695880845  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  1ZZ1ZZ1  gave for s =  0.0705078125   minimal norm  38.019477695880845
# Found minimum norm =  37.72441815731783  for s =  0.0658203125
# Flow step output with generator type  single_commutator using string  1ZZ1Z1Z  gave for s =  0.0658203125   minimal norm  37.72441815731783
# Found minimum norm =  38.66709920931767  for s =  0.07207031250000001
# Flow step output with generator type  single_commutator using string  1ZZ1Z11  gave for s =  0.07207031250000001   minimal norm  38.66709920931767
# Found minimum norm =  38.14062610611227  for s =  0.07910156250000001
# Flow step output with generator type  single_commutator using string  1ZZ11ZZ  gave for s =  0.07910156250000001   minimal norm  38.14062610611227
# Found minimum norm =  38.27187986457928  for s =  0.07832031250000002
# Flow step output with generator type  single_commutator using string  1ZZ11Z1  gave for s =  0.07832031250000002   minimal norm  38.27187986457928
# Found minimum norm =  38.76675097639218  for s =  0.08300781250000001
# Flow step output with generator type  single_commutator using string  1ZZ111Z  gave for s =  0.08300781250000001   minimal norm  38.76675097639218
# Found minimum norm =  39.80037721946124  for s =  0.0943359375
# Flow step output with generator type  single_commutator using string  1ZZ1111  gave for s =  0.0943359375   minimal norm  39.80037721946124
# Found minimum norm =  37.88758515279913  for s =  0.0716796875
# Flow step output with generator type  single_commutator using string  1Z1ZZZZ  gave for s =  0.0716796875   minimal norm  37.88758515279913
# Found minimum norm =  38.01015991378071  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  1Z1ZZZ1  gave for s =  0.0705078125   minimal norm  38.01015991378071
# Found minimum norm =  37.7607480273131  for s =  0.06503906250000001
# Flow step output with generator type  single_commutator using string  1Z1ZZ1Z  gave for s =  0.06503906250000001   minimal norm  37.7607480273131
# Found minimum norm =  38.66709920931767  for s =  0.07207031250000001
# Flow step output with generator type  single_commutator using string  1Z1ZZ11  gave for s =  0.07207031250000001   minimal norm  38.66709920931767
# Found minimum norm =  37.717162033948426  for s =  0.0658203125
# Flow step output with generator type  single_commutator using string  1Z1Z1ZZ  gave for s =  0.0658203125   minimal norm  37.717162033948426
# Found minimum norm =  37.81639673210904  for s =  0.0654296875
# Flow step output with generator type  single_commutator using string  1Z1Z1Z1  gave for s =  0.0654296875   minimal norm  37.81639673210904
# Found minimum norm =  38.12031447294628  for s =  0.0697265625
# Flow step output with generator type  single_commutator using string  1Z1Z11Z  gave for s =  0.0697265625   minimal norm  38.12031447294628
# Found minimum norm =  39.293335372991606  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  1Z1Z111  gave for s =  0.07285156250000001   minimal norm  39.293335372991606
# Found minimum norm =  38.12622872561699  for s =  0.07949218750000002
# Flow step output with generator type  single_commutator using string  1Z11ZZZ  gave for s =  0.07949218750000002   minimal norm  38.12622872561699
# Found minimum norm =  38.2718798645793  for s =  0.07832031250000002
# Flow step output with generator type  single_commutator using string  1Z11ZZ1  gave for s =  0.07832031250000002   minimal norm  38.2718798645793
# Found minimum norm =  38.120314472946276  for s =  0.0697265625
# Flow step output with generator type  single_commutator using string  1Z11Z1Z  gave for s =  0.0697265625   minimal norm  38.120314472946276
# Found minimum norm =  38.88893375745819  for s =  0.08183593750000001
# Flow step output with generator type  single_commutator using string  1Z11Z11  gave for s =  0.08183593750000001   minimal norm  38.88893375745819
# Found minimum norm =  38.74999135442724  for s =  0.0833984375
# Flow step output with generator type  single_commutator using string  1Z111ZZ  gave for s =  0.0833984375   minimal norm  38.74999135442724
# Found minimum norm =  38.88893375745819  for s =  0.08183593750000001
# Flow step output with generator type  single_commutator using string  1Z111Z1  gave for s =  0.08183593750000001   minimal norm  38.88893375745819
# Found minimum norm =  39.36242569497762  for s =  0.0873046875
# Flow step output with generator type  single_commutator using string  1Z1111Z  gave for s =  0.0873046875   minimal norm  39.36242569497762
# Found minimum norm =  37.7985041082535  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  1Z11111  gave for s =  0.0998046875   minimal norm  37.7985041082535
# Found minimum norm =  38.44028197459413  for s =  0.08652343750000001
# Flow step output with generator type  single_commutator using string  11ZZZZZ  gave for s =  0.08652343750000001   minimal norm  38.44028197459413
# Found minimum norm =  38.606912505853046  for s =  0.0849609375
# Flow step output with generator type  single_commutator using string  11ZZZZ1  gave for s =  0.0849609375   minimal norm  38.606912505853046
# Found minimum norm =  38.55271886467632  for s =  0.07324218750000001
# Flow step output with generator type  single_commutator using string  11ZZZ1Z  gave for s =  0.07324218750000001   minimal norm  38.55271886467632
# Found minimum norm =  39.210938850068445  for s =  0.08964843750000001
# Flow step output with generator type  single_commutator using string  11ZZZ11  gave for s =  0.08964843750000001   minimal norm  39.210938850068445
# Found minimum norm =  38.55271886467632  for s =  0.07324218750000001
# Flow step output with generator type  single_commutator using string  11ZZ1ZZ  gave for s =  0.07324218750000001   minimal norm  38.55271886467632
# Found minimum norm =  38.66709920931767  for s =  0.07207031250000001
# Flow step output with generator type  single_commutator using string  11ZZ1Z1  gave for s =  0.07207031250000001   minimal norm  38.66709920931767
# Found minimum norm =  38.76675097639218  for s =  0.08300781250000001
# Flow step output with generator type  single_commutator using string  11ZZ11Z  gave for s =  0.08300781250000001   minimal norm  38.76675097639218
# Found minimum norm =  39.80037721946124  for s =  0.0943359375
# Flow step output with generator type  single_commutator using string  11ZZ111  gave for s =  0.0943359375   minimal norm  39.80037721946124
# Found minimum norm =  38.54213300323051  for s =  0.07324218750000001
# Flow step output with generator type  single_commutator using string  11Z1ZZZ  gave for s =  0.07324218750000001   minimal norm  38.54213300323051
# Found minimum norm =  38.66709920931767  for s =  0.07207031250000001
# Flow step output with generator type  single_commutator using string  11Z1ZZ1  gave for s =  0.07207031250000001   minimal norm  38.66709920931767
# Found minimum norm =  38.38718289909952  for s =  0.0666015625
# Flow step output with generator type  single_commutator using string  11Z1Z1Z  gave for s =  0.0666015625   minimal norm  38.38718289909952
# Found minimum norm =  39.293335372991606  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  11Z1Z11  gave for s =  0.07285156250000001   minimal norm  39.293335372991606
# Found minimum norm =  38.749991354427245  for s =  0.0833984375
# Flow step output with generator type  single_commutator using string  11Z11ZZ  gave for s =  0.0833984375   minimal norm  38.749991354427245
# Found minimum norm =  38.88893375745819  for s =  0.08183593750000001
# Flow step output with generator type  single_commutator using string  11Z11Z1  gave for s =  0.08183593750000001   minimal norm  38.88893375745819
# Found minimum norm =  39.36242569497762  for s =  0.0873046875
# Flow step output with generator type  single_commutator using string  11Z111Z  gave for s =  0.0873046875   minimal norm  39.36242569497762
# Found minimum norm =  37.7985041082535  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  11Z1111  gave for s =  0.0998046875   minimal norm  37.7985041082535
# Found minimum norm =  39.030134887388634  for s =  0.09238281250000001
# Flow step output with generator type  single_commutator using string  111ZZZZ  gave for s =  0.09238281250000001   minimal norm  39.030134887388634
# Found minimum norm =  39.21093885006844  for s =  0.08964843750000001
# Flow step output with generator type  single_commutator using string  111ZZZ1  gave for s =  0.08964843750000001   minimal norm  39.21093885006844
# Found minimum norm =  39.18935767112594  for s =  0.07402343750000001
# Flow step output with generator type  single_commutator using string  111ZZ1Z  gave for s =  0.07402343750000001   minimal norm  39.18935767112594
# Found minimum norm =  39.80037721946124  for s =  0.0943359375
# Flow step output with generator type  single_commutator using string  111ZZ11  gave for s =  0.0943359375   minimal norm  39.80037721946124
# Found minimum norm =  39.17852624243459  for s =  0.07402343750000001
# Flow step output with generator type  single_commutator using string  111Z1ZZ  gave for s =  0.07402343750000001   minimal norm  39.17852624243459
# Found minimum norm =  39.2933353729916  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  111Z1Z1  gave for s =  0.07285156250000001   minimal norm  39.2933353729916
# Found minimum norm =  39.362425694977624  for s =  0.0873046875
# Flow step output with generator type  single_commutator using string  111Z11Z  gave for s =  0.0873046875   minimal norm  39.362425694977624
# Found minimum norm =  37.798504108253496  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  111Z111  gave for s =  0.0998046875   minimal norm  37.798504108253496
# Found minimum norm =  39.60371565793421  for s =  0.0990234375
# Flow step output with generator type  single_commutator using string  1111ZZZ  gave for s =  0.0990234375   minimal norm  39.60371565793421
# Found minimum norm =  39.80037721946124  for s =  0.0943359375
# Flow step output with generator type  single_commutator using string  1111ZZ1  gave for s =  0.0943359375   minimal norm  39.80037721946124
# Found minimum norm =  39.780543235651066  for s =  0.07324218750000001
# Flow step output with generator type  single_commutator using string  1111Z1Z  gave for s =  0.07324218750000001   minimal norm  39.780543235651066
# Found minimum norm =  37.7985041082535  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  1111Z11  gave for s =  0.0998046875   minimal norm  37.7985041082535
# Found minimum norm =  40.162213184577865  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  11111ZZ  gave for s =  0.0998046875   minimal norm  40.162213184577865
# Found minimum norm =  37.7985041082535  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  11111Z1  gave for s =  0.0998046875   minimal norm  37.7985041082535
# Found minimum norm =  38.58681801731143  for s =  0.1240234375
# Flow step output with generator type  single_commutator using string  111111Z  gave for s =  0.1240234375   minimal norm  38.58681801731143
# Found minimum norm =  40.792156108742276  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1111111  gave for s =  0.0001953125   minimal norm  40.792156108742276
# Found minimum norm =  30.100024767682704  for s =  0.0615234375
# Found that canonical is better because  30.100024767682704 37.378217477710535
# Found minimum norm =  30.100024767682704  for s =  0.0615234375
# Flowing forwards with type  canonical
# []
# Flow step  1
# Found minimum norm =  28.309856303521162  for s =  0.0873046875
# Flow step output with generator type  single_commutator using string  ZZZZZZZ  gave for s =  0.0873046875   minimal norm  28.309856303521162
# Found minimum norm =  28.619677678724578  for s =  0.0841796875
# Flow step output with generator type  single_commutator using string  ZZZZZZ1  gave for s =  0.0841796875   minimal norm  28.619677678724578
# Found minimum norm =  28.517899952332108  for s =  0.08183593750000001
# Flow step output with generator type  single_commutator using string  ZZZZZ1Z  gave for s =  0.08183593750000001   minimal norm  28.517899952332108
# Found minimum norm =  29.20558094046746  for s =  0.07910156250000001
# Flow step output with generator type  single_commutator using string  ZZZZZ11  gave for s =  0.07910156250000001   minimal norm  29.20558094046746
# Found minimum norm =  28.67058641881244  for s =  0.07910156250000001
# Flow step output with generator type  single_commutator using string  ZZZZ1ZZ  gave for s =  0.07910156250000001   minimal norm  28.67058641881244
# Found minimum norm =  28.788925735011752  for s =  0.08066406250000002
# Flow step output with generator type  single_commutator using string  ZZZZ1Z1  gave for s =  0.08066406250000002   minimal norm  28.788925735011752
# Found minimum norm =  29.254635136865595  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  ZZZZ11Z  gave for s =  0.07363281250000002   minimal norm  29.254635136865595
# Found minimum norm =  29.41832832589333  for s =  0.07832031250000002
# Flow step output with generator type  single_commutator using string  ZZZZ111  gave for s =  0.07832031250000002   minimal norm  29.41832832589333
# Found minimum norm =  28.66639080414624  for s =  0.07910156250000001
# Flow step output with generator type  single_commutator using string  ZZZ1ZZZ  gave for s =  0.07910156250000001   minimal norm  28.66639080414624
# Found minimum norm =  28.92644717082991  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  ZZZ1ZZ1  gave for s =  0.07480468750000001   minimal norm  28.92644717082991
# Found minimum norm =  28.66220367462793  for s =  0.07910156250000001
# Flow step output with generator type  single_commutator using string  ZZZ1Z1Z  gave for s =  0.07910156250000001   minimal norm  28.66220367462793
# Found minimum norm =  29.419932251267486  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  ZZZ1Z11  gave for s =  0.07480468750000001   minimal norm  29.419932251267486
# Found minimum norm =  29.386736140612964  for s =  0.0697265625
# Flow step output with generator type  single_commutator using string  ZZZ11ZZ  gave for s =  0.0697265625   minimal norm  29.386736140612964
# Found minimum norm =  29.492482319297686  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  ZZZ11Z1  gave for s =  0.0705078125   minimal norm  29.492482319297686
# Found minimum norm =  29.670516997385615  for s =  0.0697265625
# Flow step output with generator type  single_commutator using string  ZZZ111Z  gave for s =  0.0697265625   minimal norm  29.670516997385615
# Found minimum norm =  29.243277530487067  for s =  0.07988281250000002
# Flow step output with generator type  single_commutator using string  ZZZ1111  gave for s =  0.07988281250000002   minimal norm  29.243277530487067
# Found minimum norm =  28.67058641881244  for s =  0.07910156250000001
# Flow step output with generator type  single_commutator using string  ZZ1ZZZZ  gave for s =  0.07910156250000001   minimal norm  28.67058641881244
# Found minimum norm =  28.948884185934627  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  ZZ1ZZZ1  gave for s =  0.07480468750000001   minimal norm  28.948884185934627
# Found minimum norm =  28.782102214683423  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  ZZ1ZZ1Z  gave for s =  0.07480468750000001   minimal norm  28.782102214683423
# Found minimum norm =  29.527453802784876  for s =  0.06894531250000001
# Flow step output with generator type  single_commutator using string  ZZ1ZZ11  gave for s =  0.06894531250000001   minimal norm  29.527453802784876
# Found minimum norm =  28.80485225295942  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  ZZ1Z1ZZ  gave for s =  0.07480468750000001   minimal norm  28.80485225295942
# Found minimum norm =  28.933483109266312  for s =  0.07753906250000002
# Flow step output with generator type  single_commutator using string  ZZ1Z1Z1  gave for s =  0.07753906250000002   minimal norm  28.933483109266312
# Found minimum norm =  29.359934805726773  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  ZZ1Z11Z  gave for s =  0.0705078125   minimal norm  29.359934805726773
# Found minimum norm =  29.879212967338248  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1Z111  gave for s =  0.0498046875   minimal norm  29.879212967338248
# Found minimum norm =  29.386736140612964  for s =  0.0697265625
# Flow step output with generator type  single_commutator using string  ZZ11ZZZ  gave for s =  0.0697265625   minimal norm  29.386736140612964
# Found minimum norm =  29.676884140678393  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ11ZZ1  gave for s =  0.0498046875   minimal norm  29.676884140678393
# Found minimum norm =  29.371515087225273  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  ZZ11Z1Z  gave for s =  0.0701171875   minimal norm  29.371515087225273
# Found minimum norm =  29.971567175580496  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ11Z11  gave for s =  0.0498046875   minimal norm  29.971567175580496
# Found minimum norm =  29.834780085427454  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ111ZZ  gave for s =  0.0498046875   minimal norm  29.834780085427454
# Found minimum norm =  29.9135618170417  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ111Z1  gave for s =  0.0498046875   minimal norm  29.9135618170417
# Found minimum norm =  30.01381921188974  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1111Z  gave for s =  0.0498046875   minimal norm  30.01381921188974
# Found minimum norm =  28.747825751983985  for s =  0.0873046875
# Flow step output with generator type  single_commutator using string  ZZ11111  gave for s =  0.0873046875   minimal norm  28.747825751983985
# Found minimum norm =  28.51789995233211  for s =  0.08183593750000001
# Flow step output with generator type  single_commutator using string  Z1ZZZZZ  gave for s =  0.08183593750000001   minimal norm  28.51789995233211
# Found minimum norm =  28.81242853149123  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  Z1ZZZZ1  gave for s =  0.07871093750000001   minimal norm  28.81242853149123
# Found minimum norm =  28.66998087306494  for s =  0.07753906250000002
# Flow step output with generator type  single_commutator using string  Z1ZZZ1Z  gave for s =  0.07753906250000002   minimal norm  28.66998087306494
# Found minimum norm =  29.43447885269457  for s =  0.0724609375
# Flow step output with generator type  single_commutator using string  Z1ZZZ11  gave for s =  0.0724609375   minimal norm  29.43447885269457
# Found minimum norm =  28.782102214683423  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  Z1ZZ1ZZ  gave for s =  0.07480468750000001   minimal norm  28.782102214683423
# Found minimum norm =  28.90879969817756  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  Z1ZZ1Z1  gave for s =  0.07480468750000001   minimal norm  28.90879969817756
# Found minimum norm =  29.349857335762287  for s =  0.0693359375
# Flow step output with generator type  single_commutator using string  Z1ZZ11Z  gave for s =  0.0693359375   minimal norm  29.349857335762287
# Found minimum norm =  29.865558689734776  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZ111  gave for s =  0.0498046875   minimal norm  29.865558689734776
# Found minimum norm =  28.662203674627925  for s =  0.07910156250000001
# Flow step output with generator type  single_commutator using string  Z1Z1ZZZ  gave for s =  0.07910156250000001   minimal norm  28.662203674627925
# Found minimum norm =  28.92051101538583  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  Z1Z1ZZ1  gave for s =  0.07480468750000001   minimal norm  28.92051101538583
# Found minimum norm =  28.657535346090437  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  Z1Z1Z1Z  gave for s =  0.07871093750000001   minimal norm  28.657535346090437
# Found minimum norm =  29.419791537757973  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  Z1Z1Z11  gave for s =  0.07480468750000001   minimal norm  29.419791537757973
# Found minimum norm =  29.37151508722527  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  Z1Z11ZZ  gave for s =  0.0701171875   minimal norm  29.37151508722527
# Found minimum norm =  29.481244333014253  for s =  0.07128906250000001
# Flow step output with generator type  single_commutator using string  Z1Z11Z1  gave for s =  0.07128906250000001   minimal norm  29.481244333014253
# Found minimum norm =  29.673559541608  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  Z1Z111Z  gave for s =  0.0701171875   minimal norm  29.673559541608
# Found minimum norm =  29.937293057977104  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z1111  gave for s =  0.0498046875   minimal norm  29.937293057977104
# Found minimum norm =  29.2546351368656  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  Z11ZZZZ  gave for s =  0.07363281250000002   minimal norm  29.2546351368656
# Found minimum norm =  29.49905366771608  for s =  0.0685546875
# Flow step output with generator type  single_commutator using string  Z11ZZZ1  gave for s =  0.0685546875   minimal norm  29.49905366771608
# Found minimum norm =  29.34985733576229  for s =  0.0693359375
# Flow step output with generator type  single_commutator using string  Z11ZZ1Z  gave for s =  0.0693359375   minimal norm  29.34985733576229
# Found minimum norm =  29.957694627902754  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11ZZ11  gave for s =  0.0498046875   minimal norm  29.957694627902754
# Found minimum norm =  29.359934805726777  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  Z11Z1ZZ  gave for s =  0.0705078125   minimal norm  29.359934805726777
# Found minimum norm =  29.489159143028886  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  Z11Z1Z1  gave for s =  0.0705078125   minimal norm  29.489159143028886
# Found minimum norm =  29.85058676445933  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11Z11Z  gave for s =  0.0498046875   minimal norm  29.85058676445933
# Found minimum norm =  30.097059193127762  for s =  0.018554687500000003
# Flow step output with generator type  single_commutator using string  Z11Z111  gave for s =  0.018554687500000003   minimal norm  30.097059193127762
# Found minimum norm =  29.670516997385615  for s =  0.0697265625
# Flow step output with generator type  single_commutator using string  Z111ZZZ  gave for s =  0.0697265625   minimal norm  29.670516997385615
# Found minimum norm =  29.8962503105593  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z111ZZ1  gave for s =  0.0498046875   minimal norm  29.8962503105593
# Found minimum norm =  29.673559541608004  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  Z111Z1Z  gave for s =  0.0701171875   minimal norm  29.673559541608004
# Found minimum norm =  30.100030894849404  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z111Z11  gave for s =  0.0001953125   minimal norm  30.100030894849404
# Found minimum norm =  30.013819211889732  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1111ZZ  gave for s =  0.0498046875   minimal norm  30.013819211889732
# Found minimum norm =  30.07458280855921  for s =  0.04355468750000001
# Flow step output with generator type  single_commutator using string  Z1111Z1  gave for s =  0.04355468750000001   minimal norm  30.07458280855921
# Found minimum norm =  30.100025069213387  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z11111Z  gave for s =  0.0001953125   minimal norm  30.100025069213387
# Found minimum norm =  28.87610093931158  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  Z111111  gave for s =  0.0998046875   minimal norm  28.87610093931158
# Found minimum norm =  28.619677678724578  for s =  0.0841796875
# Flow step output with generator type  single_commutator using string  1ZZZZZZ  gave for s =  0.0841796875   minimal norm  28.619677678724578
# Found minimum norm =  28.88146267449072  for s =  0.08027343750000002
# Flow step output with generator type  single_commutator using string  1ZZZZZ1  gave for s =  0.08027343750000002   minimal norm  28.88146267449072
# Found minimum norm =  28.81242853149123  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  1ZZZZ1Z  gave for s =  0.07871093750000001   minimal norm  28.81242853149123
# Found minimum norm =  29.32638040402549  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  1ZZZZ11  gave for s =  0.07363281250000002   minimal norm  29.32638040402549
# Found minimum norm =  28.948884185934627  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  1ZZZ1ZZ  gave for s =  0.07480468750000001   minimal norm  28.948884185934627
# Found minimum norm =  29.087578533592076  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  1ZZZ1Z1  gave for s =  0.07480468750000001   minimal norm  29.087578533592076
# Found minimum norm =  29.499053667716083  for s =  0.0685546875
# Flow step output with generator type  single_commutator using string  1ZZZ11Z  gave for s =  0.0685546875   minimal norm  29.499053667716083
# Found minimum norm =  29.24319149743434  for s =  0.07324218750000001
# Flow step output with generator type  single_commutator using string  1ZZZ111  gave for s =  0.07324218750000001   minimal norm  29.24319149743434
# Found minimum norm =  28.92644717082991  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  1ZZ1ZZZ  gave for s =  0.07480468750000001   minimal norm  28.92644717082991
# Found minimum norm =  29.175027420107675  for s =  0.07324218750000001
# Flow step output with generator type  single_commutator using string  1ZZ1ZZ1  gave for s =  0.07324218750000001   minimal norm  29.175027420107675
# Found minimum norm =  28.920511015385834  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  1ZZ1Z1Z  gave for s =  0.07480468750000001   minimal norm  28.920511015385834
# Found minimum norm =  29.665886345923333  for s =  0.06738281250000001
# Flow step output with generator type  single_commutator using string  1ZZ1Z11  gave for s =  0.06738281250000001   minimal norm  29.665886345923333
# Found minimum norm =  29.676884140678396  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ11ZZ  gave for s =  0.0498046875   minimal norm  29.676884140678396
# Found minimum norm =  29.76512101287424  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ11Z1  gave for s =  0.0498046875   minimal norm  29.76512101287424
# Found minimum norm =  29.896250310559296  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ111Z  gave for s =  0.0498046875   minimal norm  29.896250310559296
# Found minimum norm =  28.84020818745107  for s =  0.0763671875
# Flow step output with generator type  single_commutator using string  1ZZ1111  gave for s =  0.0763671875   minimal norm  28.84020818745107
# Found minimum norm =  28.788925735011755  for s =  0.08066406250000002
# Flow step output with generator type  single_commutator using string  1Z1ZZZZ  gave for s =  0.08066406250000002   minimal norm  28.788925735011755
# Found minimum norm =  29.087578533592076  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  1Z1ZZZ1  gave for s =  0.07480468750000001   minimal norm  29.087578533592076
# Found minimum norm =  28.908799698177564  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  1Z1ZZ1Z  gave for s =  0.07480468750000001   minimal norm  28.908799698177564
# Found minimum norm =  29.7473578956417  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1ZZ11  gave for s =  0.0498046875   minimal norm  29.7473578956417
# Found minimum norm =  28.933483109266312  for s =  0.07753906250000002
# Flow step output with generator type  single_commutator using string  1Z1Z1ZZ  gave for s =  0.07753906250000002   minimal norm  28.933483109266312
# Found minimum norm =  29.065169205764604  for s =  0.07871093750000001
# Flow step output with generator type  single_commutator using string  1Z1Z1Z1  gave for s =  0.07871093750000001   minimal norm  29.065169205764604
# Found minimum norm =  29.489159143028886  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  1Z1Z11Z  gave for s =  0.0705078125   minimal norm  29.489159143028886
# Found minimum norm =  29.863833180645447  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1Z111  gave for s =  0.0498046875   minimal norm  29.863833180645447
# Found minimum norm =  29.492482319297686  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  1Z11ZZZ  gave for s =  0.0705078125   minimal norm  29.492482319297686
# Found minimum norm =  29.765121012874232  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11ZZ1  gave for s =  0.0498046875   minimal norm  29.765121012874232
# Found minimum norm =  29.481244333014253  for s =  0.07128906250000001
# Flow step output with generator type  single_commutator using string  1Z11Z1Z  gave for s =  0.07128906250000001   minimal norm  29.481244333014253
# Found minimum norm =  30.042913322516426  for s =  0.04550781250000001
# Flow step output with generator type  single_commutator using string  1Z11Z11  gave for s =  0.04550781250000001   minimal norm  30.042913322516426
# Found minimum norm =  29.913561817041696  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z111ZZ  gave for s =  0.0498046875   minimal norm  29.913561817041696
# Found minimum norm =  29.988519838139503  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z111Z1  gave for s =  0.0498046875   minimal norm  29.988519838139503
# Found minimum norm =  30.074582808559203  for s =  0.04355468750000001
# Flow step output with generator type  single_commutator using string  1Z1111Z  gave for s =  0.04355468750000001   minimal norm  30.074582808559203
# Found minimum norm =  28.434660387583932  for s =  0.0947265625
# Flow step output with generator type  single_commutator using string  1Z11111  gave for s =  0.0947265625   minimal norm  28.434660387583932
# Found minimum norm =  29.205580940467463  for s =  0.07910156250000001
# Flow step output with generator type  single_commutator using string  11ZZZZZ  gave for s =  0.07910156250000001   minimal norm  29.205580940467463
# Found minimum norm =  29.326380404025485  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  11ZZZZ1  gave for s =  0.07363281250000002   minimal norm  29.326380404025485
# Found minimum norm =  29.43447885269457  for s =  0.0724609375
# ...
# Found minimum norm =  8.941935076836707  for s =  0.026367187500000003
# Flow step output with generator type  single_commutator using string  Z11Z1ZZ  gave for s =  0.026367187500000003   minimal norm  8.941935076836707
# Found minimum norm =  8.957052321142145  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z11Z1Z1  gave for s =  0.0001953125   minimal norm  8.957052321142145
# Found minimum norm =  8.957298296822193  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z11Z11Z  gave for s =  0.0001953125   minimal norm  8.957298296822193
# Found minimum norm =  8.879613721610601  for s =  0.08457031250000001
# Flow step output with generator type  single_commutator using string  Z11Z111  gave for s =  0.08457031250000001   minimal norm  8.879613721610601
# Found minimum norm =  8.954151104911565  for s =  0.0076171875
# Flow step output with generator type  single_commutator using string  Z111ZZZ  gave for s =  0.0076171875   minimal norm  8.954151104911565
# Found minimum norm =  8.957286678902527  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z111ZZ1  gave for s =  0.0001953125   minimal norm  8.957286678902527
# Found minimum norm =  8.957226201311586  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z111Z1Z  gave for s =  0.0001953125   minimal norm  8.957226201311586
# Found minimum norm =  8.952684840895152  for s =  0.012304687500000001
# Flow step output with generator type  single_commutator using string  Z111Z11  gave for s =  0.012304687500000001   minimal norm  8.952684840895152
# Found minimum norm =  8.957267117244177  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z1111ZZ  gave for s =  0.0001953125   minimal norm  8.957267117244177
# Found minimum norm =  8.954817589038866  for s =  0.0181640625
# Flow step output with generator type  single_commutator using string  Z1111Z1  gave for s =  0.0181640625   minimal norm  8.954817589038866
# Found minimum norm =  8.954173442563986  for s =  0.013085937500000002
# Flow step output with generator type  single_commutator using string  Z11111Z  gave for s =  0.013085937500000002   minimal norm  8.954173442563986
# Found minimum norm =  8.954768810564666  for s =  0.0080078125
# Flow step output with generator type  single_commutator using string  Z111111  gave for s =  0.0080078125   minimal norm  8.954768810564666
# Found minimum norm =  8.912679875591378  for s =  0.017773437500000003
# Flow step output with generator type  single_commutator using string  1ZZZZZZ  gave for s =  0.017773437500000003   minimal norm  8.912679875591378
# Found minimum norm =  8.958248977954275  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZZZZ1  gave for s =  0.0001953125   minimal norm  8.958248977954275
# Found minimum norm =  8.958194206356824  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZZZ1Z  gave for s =  0.0001953125   minimal norm  8.958194206356824
# Found minimum norm =  8.918035316452427  for s =  0.0166015625
# Flow step output with generator type  single_commutator using string  1ZZZZ11  gave for s =  0.0166015625   minimal norm  8.918035316452427
# Found minimum norm =  8.958226712596487  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZZ1ZZ  gave for s =  0.0001953125   minimal norm  8.958226712596487
# Found minimum norm =  8.934271141670068  for s =  0.014257812500000001
# Flow step output with generator type  single_commutator using string  1ZZZ1Z1  gave for s =  0.014257812500000001   minimal norm  8.934271141670068
# Found minimum norm =  8.913388966284426  for s =  0.019726562500000003
# Flow step output with generator type  single_commutator using string  1ZZZ11Z  gave for s =  0.019726562500000003   minimal norm  8.913388966284426
# Found minimum norm =  8.95776633470803  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZZ111  gave for s =  0.0001953125   minimal norm  8.95776633470803
# Found minimum norm =  8.95801433090279  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZ1ZZZ  gave for s =  0.0001953125   minimal norm  8.95801433090279
# Found minimum norm =  8.920778410456162  for s =  0.0162109375
# Flow step output with generator type  single_commutator using string  1ZZ1ZZ1  gave for s =  0.0162109375   minimal norm  8.920778410456162
# Found minimum norm =  8.922769693050691  for s =  0.0166015625
# Flow step output with generator type  single_commutator using string  1ZZ1Z1Z  gave for s =  0.0166015625   minimal norm  8.922769693050691
# Found minimum norm =  8.958524881990678  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZ1Z11  gave for s =  0.0001953125   minimal norm  8.958524881990678
# Found minimum norm =  8.927113864028946  for s =  0.0166015625
# Flow step output with generator type  single_commutator using string  1ZZ11ZZ  gave for s =  0.0166015625   minimal norm  8.927113864028946
# Found minimum norm =  8.958192178963142  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZ11Z1  gave for s =  0.0001953125   minimal norm  8.958192178963142
# Found minimum norm =  8.958022130977419  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZ111Z  gave for s =  0.0001953125   minimal norm  8.958022130977419
# Found minimum norm =  8.923864305611861  for s =  0.016992187500000002
# Flow step output with generator type  single_commutator using string  1ZZ1111  gave for s =  0.016992187500000002   minimal norm  8.923864305611861
# Found minimum norm =  8.958278948482796  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z1ZZZZ  gave for s =  0.0001953125   minimal norm  8.958278948482796
# Found minimum norm =  8.940611882556288  for s =  0.011132812500000002
# Flow step output with generator type  single_commutator using string  1Z1ZZZ1  gave for s =  0.011132812500000002   minimal norm  8.940611882556288
# Found minimum norm =  8.902519367667004  for s =  0.020898437500000002
# Flow step output with generator type  single_commutator using string  1Z1ZZ1Z  gave for s =  0.020898437500000002   minimal norm  8.902519367667004
# Found minimum norm =  8.959000253033249  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z1ZZ11  gave for s =  0.0001953125   minimal norm  8.959000253033249
# Found minimum norm =  8.936114489477871  for s =  0.0138671875
# Flow step output with generator type  single_commutator using string  1Z1Z1ZZ  gave for s =  0.0138671875   minimal norm  8.936114489477871
# Found minimum norm =  8.957623970245939  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z1Z1Z1  gave for s =  0.0001953125   minimal norm  8.957623970245939
# Found minimum norm =  8.958195324102704  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z1Z11Z  gave for s =  0.0001953125   minimal norm  8.958195324102704
# Found minimum norm =  8.949085158496674  for s =  0.008398437500000001
# Flow step output with generator type  single_commutator using string  1Z1Z111  gave for s =  0.008398437500000001   minimal norm  8.949085158496674
# Found minimum norm =  8.936987035647684  for s =  0.012304687500000001
# Flow step output with generator type  single_commutator using string  1Z11ZZZ  gave for s =  0.012304687500000001   minimal norm  8.936987035647684
# Found minimum norm =  8.958736377092848  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z11ZZ1  gave for s =  0.0001953125   minimal norm  8.958736377092848
# Found minimum norm =  8.95834911154979  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z11Z1Z  gave for s =  0.0001953125   minimal norm  8.95834911154979
# Found minimum norm =  8.937717713117314  for s =  0.0119140625
# Flow step output with generator type  single_commutator using string  1Z11Z11  gave for s =  0.0119140625   minimal norm  8.937717713117314
# Found minimum norm =  8.957694660184787  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z111ZZ  gave for s =  0.0001953125   minimal norm  8.957694660184787
# Found minimum norm =  8.936044080628093  for s =  0.0138671875
# Flow step output with generator type  single_commutator using string  1Z111Z1  gave for s =  0.0138671875   minimal norm  8.936044080628093
# Found minimum norm =  8.923915193299417  for s =  0.017773437500000003
# Flow step output with generator type  single_commutator using string  1Z1111Z  gave for s =  0.017773437500000003   minimal norm  8.923915193299417
# Found minimum norm =  8.957861651826432  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z11111  gave for s =  0.0001953125   minimal norm  8.957861651826432
# Found minimum norm =  8.957495526901516  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11ZZZZZ  gave for s =  0.0001953125   minimal norm  8.957495526901516
# Found minimum norm =  8.942439973195746  for s =  0.018945312500000002
# Flow step output with generator type  single_commutator using string  11ZZZZ1  gave for s =  0.018945312500000002   minimal norm  8.942439973195746
# Found minimum norm =  8.949093452067546  for s =  0.0138671875
# Flow step output with generator type  single_commutator using string  11ZZZ1Z  gave for s =  0.0138671875   minimal norm  8.949093452067546
# Found minimum norm =  8.95693665992021  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11ZZZ11  gave for s =  0.0001953125   minimal norm  8.95693665992021
# Found minimum norm =  8.95692502611663  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11ZZ1ZZ  gave for s =  0.0001953125   minimal norm  8.95692502611663
# Found minimum norm =  8.95717794815564  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11ZZ1Z1  gave for s =  0.0001953125   minimal norm  8.95717794815564
# Found minimum norm =  8.957184279880995  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11ZZ11Z  gave for s =  0.0001953125   minimal norm  8.957184279880995
# Found minimum norm =  8.955043866850898  for s =  0.0115234375
# Flow step output with generator type  single_commutator using string  11ZZ111  gave for s =  0.0115234375   minimal norm  8.955043866850898
# Found minimum norm =  8.947549950116251  for s =  0.015039062499999999
# Flow step output with generator type  single_commutator using string  11Z1ZZZ  gave for s =  0.015039062499999999   minimal norm  8.947549950116251
# Found minimum norm =  8.957146645673895  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11Z1ZZ1  gave for s =  0.0001953125   minimal norm  8.957146645673895
# Found minimum norm =  8.95750728912437  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11Z1Z1Z  gave for s =  0.0001953125   minimal norm  8.95750728912437
# Found minimum norm =  8.952908112886785  for s =  0.013085937500000002
# Flow step output with generator type  single_commutator using string  11Z1Z11  gave for s =  0.013085937500000002   minimal norm  8.952908112886785
# Found minimum norm =  8.957220836802177  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11Z11ZZ  gave for s =  0.0001953125   minimal norm  8.957220836802177
# Found minimum norm =  8.956915296174538  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11Z11Z1  gave for s =  0.0001953125   minimal norm  8.956915296174538
# Found minimum norm =  8.955751392025828  for s =  0.0119140625
# Flow step output with generator type  single_commutator using string  11Z111Z  gave for s =  0.0119140625   minimal norm  8.955751392025828
# Found minimum norm =  8.956995788439672  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11Z1111  gave for s =  0.0001953125   minimal norm  8.956995788439672
# Found minimum norm =  8.919467908396197  for s =  0.0275390625
# Flow step output with generator type  single_commutator using string  111ZZZZ  gave for s =  0.0275390625   minimal norm  8.919467908396197
# Found minimum norm =  8.956815573331927  for s =  0.0005859375000000001
# Flow step output with generator type  single_commutator using string  111ZZZ1  gave for s =  0.0005859375000000001   minimal norm  8.956815573331927
# Found minimum norm =  8.957419543140265  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  111ZZ1Z  gave for s =  0.0001953125   minimal norm  8.957419543140265
# Found minimum norm =  8.896978819717855  for s =  0.04550781250000001
# Flow step output with generator type  single_commutator using string  111ZZ11  gave for s =  0.04550781250000001   minimal norm  8.896978819717855
# Found minimum norm =  8.95723580788907  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  111Z1ZZ  gave for s =  0.0001953125   minimal norm  8.95723580788907
# Found minimum norm =  8.954796492143299  for s =  0.03886718750000001
# Flow step output with generator type  single_commutator using string  111Z1Z1  gave for s =  0.03886718750000001   minimal norm  8.954796492143299
# Found minimum norm =  8.94184533850837  for s =  0.0353515625
# Flow step output with generator type  single_commutator using string  111Z11Z  gave for s =  0.0353515625   minimal norm  8.94184533850837
# Found minimum norm =  8.952501384473779  for s =  0.012304687500000001
# Flow step output with generator type  single_commutator using string  111Z111  gave for s =  0.012304687500000001   minimal norm  8.952501384473779
# Found minimum norm =  8.957148636666869  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1111ZZZ  gave for s =  0.0001953125   minimal norm  8.957148636666869
# Found minimum norm =  8.787836162185915  for s =  0.0693359375
# Flow step output with generator type  single_commutator using string  1111ZZ1  gave for s =  0.0693359375   minimal norm  8.787836162185915
# Found minimum norm =  8.956843875763251  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1111Z1Z  gave for s =  0.0001953125   minimal norm  8.956843875763251
# Found minimum norm =  8.927483678300451  for s =  0.0244140625
# Flow step output with generator type  single_commutator using string  1111Z11  gave for s =  0.0244140625   minimal norm  8.927483678300451
# Found minimum norm =  8.947435003539725  for s =  0.0232421875
# Flow step output with generator type  single_commutator using string  11111ZZ  gave for s =  0.0232421875   minimal norm  8.947435003539725
# Found minimum norm =  8.956941935939422  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111Z1  gave for s =  0.0001953125   minimal norm  8.956941935939422
# Found minimum norm =  8.956910983597691  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  111111Z  gave for s =  0.0001953125   minimal norm  8.956910983597691
# Found minimum norm =  8.956836891782142  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1111111  gave for s =  0.0001953125   minimal norm  8.956836891782142
# Found minimum norm =  8.815821278661526  for s =  0.0029296875
# Found that canonical is worse because  8.815821278661526 8.787836162185915
# Found minimum norm =  8.787836162185915  for s =  0.0693359375
# Flowing forwards with type  single_commutator
# []

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

def plot_iteration_results(  ):
    flow.run_param_rc(fontsize=18)
    flow_results = flow.flow_outputs

    f=plt.figure(figsize = ( 8,7 ))
    n=1
    ax_a = f.add_subplot(1,n,1)
    norms = flow_results['minimal_norm_sigma_H_s']
    x_axis = [sum(flow_results['minimizing_flow_step'][:k])for k in range( 1, len(flow_results['minimizing_flow_step'])+1)]

    plt.plot( x_axis, norms, '-o')   
    if 1: 
        k=12
        plt.annotate('k = ' + str(k) + ': ' + flow_results['strs_of_minimizer_Z'][k-1], 
                     xy=(x_axis[k],norms[k]+.5), textcoords='data', fontsize=17)
        k=17
        plt.annotate('k = ' + str(k) + ': ' + flow_results['strs_of_minimizer_Z'][k-1], 
                     xy=(x_axis[k]-.13,norms[k]+1.2), textcoords='data', fontsize=17)
        k=20
        plt.annotate('k = ' + str(k) + ': ' + flow_results['strs_of_minimizer_Z'][k-1], 
                     xy=(x_axis[k]-.148,norms[k]+.55), textcoords='data', fontsize=17)
        k=19
        plt.annotate('k = ' + str(k) + ': ' + flow_results['strs_of_minimizer_Z'][k-1], 
                     xy=(x_axis[k]-.14,norms[k]-1.5), textcoords='data', fontsize=17)
    else:
        k=12
        plt.annotate('str(k)', xy=(x_axis[k],norms[k]), textcoords='data', fontsize=17)
        k=17
        plt.annotate('str(k)', xy=(x_axis[k],norms[k]), textcoords='data', fontsize=17)
        k=19
        plt.annotate('str(k)', xy=(x_axis[k],norms[k]), textcoords='data', fontsize=17)
        k=20
        plt.annotate('str(k)', xy=(x_axis[k],norms[k]), textcoords='data', fontsize=17)

    plt.annotate('b)', xy = (-.1,1.02),
                 xycoords='axes fraction')
    x_labels_rounded = [ round(x, 2 ) for x in x_axis ]
    chosen_label_idx = [0,1,4,13,17,-1]
    x_labels_rounded = [x_labels_rounded[idx] for idx in chosen_label_idx]
#     x_labels_rounded.pop(4)
    
    plt.xticks(x_labels_rounded)
    y_labels_rounded = [ round(y, 1 ) for y in norms ]
    y_labels_rounded = y_labels_rounded[0:5] + [min(y_labels_rounded)]
    plt.yticks(y_labels_rounded)
    plt.grid()
    plt.xlabel(r'Total flow duration $\ell$')
    plt.title(r'Norm off-diagonal $\vert\vert\sigma(\hat H_k)\vert\vert$')
    a =-.1
    b = 1.05
 
    axin1 = ax_a.inset_axes([0.2,.7, 0.31, 0.27])
    inset1 = axin1.imshow( H_TLFIM, cmap='RdBu' )
    divider1 = make_axes_locatable(axin1)
    div_ax = divider1.append_axes("right", size="10%", pad=0.05)
    cbar1 = plt.colorbar(inset1, cax = div_ax )
    range_plot = np.max( np.abs( H_TLFIM ) )
#     cbar1.set_clim( -range_plot, range_plot )
    axin1.set_yticks(range(2**L))  
    axin1.set_xticklabels([1]+['']*(2**L-2)+[2**L])
    axin1.set_yticklabels([1]+['']*(2**L-2)+[2**L])
    axin1.set_xticks(range(2**L))
    ax_a.annotate(' ',
            xy=(x_axis[0]+.01, norms[0]),  # theta, radius
            xytext=(0.24, 0.81),    # fraction, fraction
            textcoords='figure fraction',
            arrowprops=dict(facecolor='gray', shrink=0.01),
            horizontalalignment='left',
            verticalalignment='bottom')
#     axin1.set_xlabel(r'$j$')
#     axin1.set_title(r'$k$')
#     axin1.grid()
    axin2 = ax_a.inset_axes([0.65,.32, 0.31, 0.27])
    inset2 = axin2.imshow(flow_results['optimally_flowed_H'][-1], cmap='RdBu')

    divider2 = make_axes_locatable(axin2)
    div_ax2 = divider2.append_axes("right", size="10%", pad=0.05)
    cbar2 = plt.colorbar(inset2, cax = div_ax2 )
    ax_a.annotate(' ',
        xy=(x_axis[-1], 11.4),  # theta, radius
        xytext=(.95, .3),    # fraction, fraction
        textcoords='axes fraction',
        arrowprops=dict(facecolor='gray', shrink=0.05),
        horizontalalignment='left',
        verticalalignment='bottom')
    
    axin3 = ax_a.inset_axes([0.65,.7, 0.31, 0.27])
    inset3 = axin3.imshow(flow_results['optimally_flowed_H'][2], cmap='RdBu')

    divider3 = make_axes_locatable(axin3)
    div_ax3 = divider3.append_axes("right", size="10%", pad=0.05)
    cbar2 = plt.colorbar(inset3, cax = div_ax3 )
    ax_a.annotate(' ',
        xy=(x_axis[2]+.01, norms[2]+.6),  # theta, radius
        xytext=(0.65, 0.67),    # fraction, fraction
        textcoords='axes fraction',
        arrowprops=dict(facecolor='gray', shrink=0.05),
        horizontalalignment='left',
        verticalalignment='bottom')
    axin2.set_yticks(range(2**L))  
    axin2.set_xticklabels([1]+['']*(2**L-2)+[2**L])
    axin2.set_yticklabels([1]+['']*(2**L-2)+[2**L])
    axin2.set_xticks(range(2**L))    
    axin3.set_yticks(range(2**L))  
    axin3.set_xticklabels([1]+['']*(2**L-2)+[2**L])
    axin3.set_yticklabels([1]+['']*(2**L-2)+[2**L])
    axin3.set_xticks(range(2**L))
    chosen_steps = [1,2]
    plt.savefig( 'figs/variational_norm_'+hamiltonian_name+'.pdf')
    
plot_iteration_results()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:62: UserWarning: FixedFormatter should only be used together with FixedLocator
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:103: UserWarning: FixedFormatter should only be used together with FixedLocator
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:107: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# #### Simple plot for debugging

# %%
H = flow.flow_outputs['final_flowed_H'][-1]

plt.figure()
plt.subplot(121)
plt.imshow(abs(H_TLFIM), cmap='RdBu')
plt.colorbar()
plt.subplot(122)
plt.imshow(abs(H), cmap='RdBu')
plt.colorbar()
plt.tight_layout()

# %% [markdown]
# This variable stores or strings that have been tested in each step

# %%
print(flow.flow_outputs['all_Z_names'])
# Out:
# ['ZZZZZZZ', 'ZZZZZZ1', 'ZZZZZ1Z', 'ZZZZZ11', 'ZZZZ1ZZ', 'ZZZZ1Z1', 'ZZZZ11Z', 'ZZZZ111', 'ZZZ1ZZZ', 'ZZZ1ZZ1', 'ZZZ1Z1Z', 'ZZZ1Z11', 'ZZZ11ZZ', 'ZZZ11Z1', 'ZZZ111Z', 'ZZZ1111', 'ZZ1ZZZZ', 'ZZ1ZZZ1', 'ZZ1ZZ1Z', 'ZZ1ZZ11', 'ZZ1Z1ZZ', 'ZZ1Z1Z1', 'ZZ1Z11Z', 'ZZ1Z111', 'ZZ11ZZZ', 'ZZ11ZZ1', 'ZZ11Z1Z', 'ZZ11Z11', 'ZZ111ZZ', 'ZZ111Z1', 'ZZ1111Z', 'ZZ11111', 'Z1ZZZZZ', 'Z1ZZZZ1', 'Z1ZZZ1Z', 'Z1ZZZ11', 'Z1ZZ1ZZ', 'Z1ZZ1Z1', 'Z1ZZ11Z', 'Z1ZZ111', 'Z1Z1ZZZ', 'Z1Z1ZZ1', 'Z1Z1Z1Z', 'Z1Z1Z11', 'Z1Z11ZZ', 'Z1Z11Z1', 'Z1Z111Z', 'Z1Z1111', 'Z11ZZZZ', 'Z11ZZZ1', 'Z11ZZ1Z', 'Z11ZZ11', 'Z11Z1ZZ', 'Z11Z1Z1', 'Z11Z11Z', 'Z11Z111', 'Z111ZZZ', 'Z111ZZ1', 'Z111Z1Z', 'Z111Z11', 'Z1111ZZ', 'Z1111Z1', 'Z11111Z', 'Z111111', '1ZZZZZZ', '1ZZZZZ1', '1ZZZZ1Z', '1ZZZZ11', '1ZZZ1ZZ', '1ZZZ1Z1', '1ZZZ11Z', '1ZZZ111', '1ZZ1ZZZ', '1ZZ1ZZ1', '1ZZ1Z1Z', '1ZZ1Z11', '1ZZ11ZZ', '1ZZ11Z1', '1ZZ111Z', '1ZZ1111', '1Z1ZZZZ', '1Z1ZZZ1', '1Z1ZZ1Z', '1Z1ZZ11', '1Z1Z1ZZ', '1Z1Z1Z1', '1Z1Z11Z', '1Z1Z111', '1Z11ZZZ', '1Z11ZZ1', '1Z11Z1Z', '1Z11Z11', '1Z111ZZ', '1Z111Z1', '1Z1111Z', '1Z11111', '11ZZZZZ', '11ZZZZ1', '11ZZZ1Z', '11ZZZ11', '11ZZ1ZZ', '11ZZ1Z1', '11ZZ11Z', '11ZZ111', '11Z1ZZZ', '11Z1ZZ1', '11Z1Z1Z', '11Z1Z11', '11Z11ZZ', '11Z11Z1', '11Z111Z', '11Z1111', '111ZZZZ', '111ZZZ1', '111ZZ1Z', '111ZZ11', '111Z1ZZ', '111Z1Z1', '111Z11Z', '111Z111', '1111ZZZ', '1111ZZ1', '1111Z1Z', '1111Z11', '11111ZZ', '11111Z1', '111111Z', '1111111']

# %% [markdown]
# and these are the strings that gave the optimal generator to decrease the norm of the off-diagonal restriction

# %%
for i, z in enumerate(flow.flow_outputs['strs_of_minimizer_Z']):
    print(i, z)
# Out:
# 0 Canonical
# 1 Canonical
# 2 Canonical
# 3 Canonical
# 4 Canonical
# 5 Canonical
# 6 Canonical
# 7 Canonical
# 8 Canonical
# 9 Canonical
# 10 Canonical
# 11 111111Z
# 12 Canonical
# 13 Canonical
# 14 Canonical
# 15 Canonical
# 16 1Z11Z11
# 17 Canonical
# 18 1ZZ1111
# 19 1111ZZ1

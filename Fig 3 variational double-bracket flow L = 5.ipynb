# %%
from simple_exact_diagonalization_routines.local_matrix_class import *
from scipy.linalg import expm
import matplotlib.pyplot as plt
import time


# System size
L = 5

# Create objects of Pauli operators
X = X_class(L)
Y = Y_class(L)
Z = Z_class(L)
S_plus = S_plus_class(L)
S_minus = S_minus_class(L)

# Trivial initialization of the right size matrix
hamiltonian_name = "TLFIM_L_" +str(L)
H_TLFIM = 0*np.eye( 2**L ) 

for x in range(L-1):
    H_TLFIM = H_TLFIM + 2*X.at(x+1).dot(X.at(x+2)) + Z.at(x+1)+ X.at(x+1)
H_TLFIM = H_TLFIM + Z.at(L)    + X.at(L) +X.at(1).dot(X.at(L))

# %%
from class_double_bracket_flow import *


flow = double_bracket_flow( H_TLFIM )

flow.please_be_exhaustively_verbose = False
flow.please_be_verbose = True

flow.nmb_search_points_minimizing_s_search = 10
flow.flow_step_max = 0.2
flow.nmb_flow_steps = 10
flow.please_use_binary_search =  True
flow.please_compute_observables = False

#flow.flow_forwards( )
flow.flow_via_best_Z_search( please_also_check_canonical_bracket = True )

flow.show_flow_forwards_results()
# Out:
# Flow step  0
# Found minimum norm =  25.79004606815106  for s =  0.09511718749999999
# Flow step output with generator type  single_commutator using string  ZZZZZ  gave for s =  0.09511718749999999   minimal norm  25.79004606815106
# Found minimum norm =  25.27261875159258  for s =  0.0677734375
# Flow step output with generator type  single_commutator using string  ZZZZ1  gave for s =  0.0677734375   minimal norm  25.27261875159258
# Found minimum norm =  24.742102185191502  for s =  0.0595703125
# Flow step output with generator type  single_commutator using string  ZZZ1Z  gave for s =  0.0595703125   minimal norm  24.742102185191502
# Found minimum norm =  25.173395630844595  for s =  0.08066406250000002
# Flow step output with generator type  single_commutator using string  ZZZ11  gave for s =  0.08066406250000002   minimal norm  25.173395630844595
# Found minimum norm =  24.74210218519151  for s =  0.0595703125
# Flow step output with generator type  single_commutator using string  ZZ1ZZ  gave for s =  0.0595703125   minimal norm  24.74210218519151
# Found minimum norm =  23.819738357397753  for s =  0.0548828125
# Flow step output with generator type  single_commutator using string  ZZ1Z1  gave for s =  0.0548828125   minimal norm  23.819738357397753
# Found minimum norm =  24.46368727715476  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  ZZ11Z  gave for s =  0.0701171875   minimal norm  24.46368727715476
# Found minimum norm =  25.381370620684187  for s =  0.08691406250000001
# Flow step output with generator type  single_commutator using string  ZZ111  gave for s =  0.08691406250000001   minimal norm  25.381370620684187
# Found minimum norm =  24.74210218519151  for s =  0.0595703125
# Flow step output with generator type  single_commutator using string  Z1ZZZ  gave for s =  0.0595703125   minimal norm  24.74210218519151
# Found minimum norm =  23.83514341742237  for s =  0.0548828125
# Flow step output with generator type  single_commutator using string  Z1ZZ1  gave for s =  0.0548828125   minimal norm  23.83514341742237
# Found minimum norm =  23.115985564966625  for s =  0.05136718750000001
# Flow step output with generator type  single_commutator using string  Z1Z1Z  gave for s =  0.05136718750000001   minimal norm  23.115985564966625
# Found minimum norm =  24.06716254364528  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z11  gave for s =  0.0498046875   minimal norm  24.06716254364528
# Found minimum norm =  24.46368727715476  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  Z11ZZ  gave for s =  0.0701171875   minimal norm  24.46368727715476
# Found minimum norm =  23.759366840547877  for s =  0.0587890625
# Flow step output with generator type  single_commutator using string  Z11Z1  gave for s =  0.0587890625   minimal norm  23.759366840547877
# Found minimum norm =  24.684091737799235  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  Z111Z  gave for s =  0.07363281250000002   minimal norm  24.684091737799235
# Found minimum norm =  24.14720822144316  for s =  0.08769531250000001
# Flow step output with generator type  single_commutator using string  Z1111  gave for s =  0.08769531250000001   minimal norm  24.14720822144316
# Found minimum norm =  25.272618751592578  for s =  0.0677734375
# Flow step output with generator type  single_commutator using string  1ZZZZ  gave for s =  0.0677734375   minimal norm  25.272618751592578
# Found minimum norm =  24.46368727715476  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  1ZZZ1  gave for s =  0.0701171875   minimal norm  24.46368727715476
# Found minimum norm =  23.835143417422373  for s =  0.0548828125
# Flow step output with generator type  single_commutator using string  1ZZ1Z  gave for s =  0.0548828125   minimal norm  23.835143417422373
# Found minimum norm =  24.684091737799243  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  1ZZ11  gave for s =  0.07363281250000002   minimal norm  24.684091737799243
# Found minimum norm =  23.81973835739775  for s =  0.0548828125
# Flow step output with generator type  single_commutator using string  1Z1ZZ  gave for s =  0.0548828125   minimal norm  23.81973835739775
# Found minimum norm =  23.19415632886032  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1Z1  gave for s =  0.0498046875   minimal norm  23.19415632886032
# Found minimum norm =  23.759366840547884  for s =  0.0587890625
# Flow step output with generator type  single_commutator using string  1Z11Z  gave for s =  0.0587890625   minimal norm  23.759366840547884
# Found minimum norm =  23.11470179442829  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.07285156250000001   minimal norm  23.11470179442829
# Found minimum norm =  25.17339563084459  for s =  0.08066406250000002
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.08066406250000002   minimal norm  25.17339563084459
# Found minimum norm =  24.684091737799243  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.07363281250000002   minimal norm  24.684091737799243
# Found minimum norm =  24.067162543645274  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.0498046875   minimal norm  24.067162543645274
# Found minimum norm =  23.11470179442829  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.07285156250000001   minimal norm  23.11470179442829
# Found minimum norm =  25.381370620684184  for s =  0.08691406250000001
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.08691406250000001   minimal norm  25.381370620684184
# Found minimum norm =  23.11470179442829  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.07285156250000001   minimal norm  23.11470179442829
# Found minimum norm =  24.14720822144316  for s =  0.08769531250000001
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.08769531250000001   minimal norm  24.14720822144316
# Found minimum norm =  26.5329983228432  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111  gave for s =  0.0001953125   minimal norm  26.5329983228432
# Found minimum norm =  20.098274787334958  for s =  0.040039062500000014
# Found that canonical is better because  20.098274787334958 23.11470179442829
# Found minimum norm =  20.098274787334958  for s =  0.040039062500000014
# Flowing forwards with type  canonical
# []
# Flow step  1
# Found minimum norm =  19.093359770544186  for s =  0.0853515625
# Flow step output with generator type  single_commutator using string  ZZZZZ  gave for s =  0.0853515625   minimal norm  19.093359770544186
# Found minimum norm =  18.926299775915272  for s =  0.06699218750000001
# Flow step output with generator type  single_commutator using string  ZZZZ1  gave for s =  0.06699218750000001   minimal norm  18.926299775915272
# Found minimum norm =  18.87203632004934  for s =  0.06738281250000001
# Flow step output with generator type  single_commutator using string  ZZZ1Z  gave for s =  0.06738281250000001   minimal norm  18.87203632004934
# Found minimum norm =  19.444360491892876  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ11  gave for s =  0.0498046875   minimal norm  19.444360491892876
# Found minimum norm =  19.142712733570907  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZ  gave for s =  0.0498046875   minimal norm  19.142712733570907
# Found minimum norm =  18.9758658671119  for s =  0.0677734375
# Flow step output with generator type  single_commutator using string  ZZ1Z1  gave for s =  0.0677734375   minimal norm  18.9758658671119
# Found minimum norm =  19.428954117806427  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ11Z  gave for s =  0.0498046875   minimal norm  19.428954117806427
# Found minimum norm =  19.440816367959062  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ111  gave for s =  0.0498046875   minimal norm  19.440816367959062
# Found minimum norm =  18.87203632004934  for s =  0.06738281250000001
# Flow step output with generator type  single_commutator using string  Z1ZZZ  gave for s =  0.06738281250000001   minimal norm  18.87203632004934
# Found minimum norm =  18.971083449242673  for s =  0.0634765625
# Flow step output with generator type  single_commutator using string  Z1ZZ1  gave for s =  0.0634765625   minimal norm  18.971083449242673
# Found minimum norm =  18.40056255211922  for s =  0.07324218750000001
# Flow step output with generator type  single_commutator using string  Z1Z1Z  gave for s =  0.07324218750000001   minimal norm  18.40056255211922
# Found minimum norm =  19.211324342356576  for s =  0.0693359375
# Flow step output with generator type  single_commutator using string  Z1Z11  gave for s =  0.0693359375   minimal norm  19.211324342356576
# Found minimum norm =  19.428954117806427  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11ZZ  gave for s =  0.0498046875   minimal norm  19.428954117806427
# Found minimum norm =  19.3602506369415  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11Z1  gave for s =  0.0498046875   minimal norm  19.3602506369415
# Found minimum norm =  19.38429611904446  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z111Z  gave for s =  0.0498046875   minimal norm  19.38429611904446
# Found minimum norm =  18.876231172104067  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  Z1111  gave for s =  0.0701171875   minimal norm  18.876231172104067
# Found minimum norm =  18.926299775915275  for s =  0.06699218750000001
# Flow step output with generator type  single_commutator using string  1ZZZZ  gave for s =  0.06699218750000001   minimal norm  18.926299775915275
# Found minimum norm =  19.033674652470978  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZ1  gave for s =  0.0498046875   minimal norm  19.033674652470978
# Found minimum norm =  18.971083449242677  for s =  0.0634765625
# Flow step output with generator type  single_commutator using string  1ZZ1Z  gave for s =  0.0634765625   minimal norm  18.971083449242677
# Found minimum norm =  19.220422434291226  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ11  gave for s =  0.0498046875   minimal norm  19.220422434291226
# Found minimum norm =  18.9758658671119  for s =  0.0677734375
# Flow step output with generator type  single_commutator using string  1Z1ZZ  gave for s =  0.0677734375   minimal norm  18.9758658671119
# Found minimum norm =  18.605508330770512  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  1Z1Z1  gave for s =  0.07480468750000001   minimal norm  18.605508330770512
# Found minimum norm =  19.3602506369415  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11Z  gave for s =  0.0498046875   minimal norm  19.3602506369415
# Found minimum norm =  18.408188377807782  for s =  0.06816406250000001
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.06816406250000001   minimal norm  18.408188377807782
# Found minimum norm =  19.444360491892873  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.0498046875   minimal norm  19.444360491892873
# Found minimum norm =  19.220422434291226  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.0498046875   minimal norm  19.220422434291226
# Found minimum norm =  19.211324342356576  for s =  0.0693359375
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.0693359375   minimal norm  19.211324342356576
# Found minimum norm =  18.27100536896954  for s =  0.061132812499999994
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.061132812499999994   minimal norm  18.27100536896954
# Found minimum norm =  19.440816367959066  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.0498046875   minimal norm  19.440816367959066
# Found minimum norm =  18.40818837780778  for s =  0.06816406250000001
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.06816406250000001   minimal norm  18.40818837780778
# Found minimum norm =  18.876231172104063  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.0701171875   minimal norm  18.876231172104063
# Found minimum norm =  20.098274787334958  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111  gave for s =  0.0001953125   minimal norm  20.098274787334958
# Found minimum norm =  16.436530898511435  for s =  0.020898437500000002
# Found that canonical is better because  16.436530898511435 18.27100536896954
# Found minimum norm =  16.436530898511435  for s =  0.020898437500000002
# Flowing forwards with type  canonical
# []
# Flow step  2
# Found minimum norm =  15.485985065067343  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZZ  gave for s =  0.0498046875   minimal norm  15.485985065067343
# Found minimum norm =  15.715211959076145  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZ1  gave for s =  0.0498046875   minimal norm  15.715211959076145
# Found minimum norm =  15.834444245699155  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1Z  gave for s =  0.0498046875   minimal norm  15.834444245699155
# Found minimum norm =  15.851666030590849  for s =  0.0419921875
# Flow step output with generator type  single_commutator using string  ZZZ11  gave for s =  0.0419921875   minimal norm  15.851666030590849
# Found minimum norm =  15.836236088648324  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZ  gave for s =  0.0498046875   minimal norm  15.836236088648324
# Found minimum norm =  16.124457644105046  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1Z1  gave for s =  0.0498046875   minimal norm  16.124457644105046
# Found minimum norm =  16.056278745584688  for s =  0.0392578125
# Flow step output with generator type  single_commutator using string  ZZ11Z  gave for s =  0.0392578125   minimal norm  16.056278745584688
# Found minimum norm =  16.033230281474943  for s =  0.0373046875
# Flow step output with generator type  single_commutator using string  ZZ111  gave for s =  0.0373046875   minimal norm  16.033230281474943
# Found minimum norm =  15.834444245699157  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZZ  gave for s =  0.0498046875   minimal norm  15.834444245699157
# Found minimum norm =  15.946913194046717  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZ1  gave for s =  0.0498046875   minimal norm  15.946913194046717
# Found minimum norm =  15.98014842845076  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z1Z  gave for s =  0.0498046875   minimal norm  15.98014842845076
# Found minimum norm =  16.117721739501494  for s =  0.04082031250000001
# Flow step output with generator type  single_commutator using string  Z1Z11  gave for s =  0.04082031250000001   minimal norm  16.117721739501494
# Found minimum norm =  16.056278745584688  for s =  0.0392578125
# Flow step output with generator type  single_commutator using string  Z11ZZ  gave for s =  0.0392578125   minimal norm  16.056278745584688
# Found minimum norm =  16.11773412274554  for s =  0.040429687500000006
# Flow step output with generator type  single_commutator using string  Z11Z1  gave for s =  0.040429687500000006   minimal norm  16.11773412274554
# Found minimum norm =  16.089107620087546  for s =  0.0427734375
# Flow step output with generator type  single_commutator using string  Z111Z  gave for s =  0.0427734375   minimal norm  16.089107620087546
# Found minimum norm =  15.586095261131739  for s =  0.05996093749999999
# Flow step output with generator type  single_commutator using string  Z1111  gave for s =  0.05996093749999999   minimal norm  15.586095261131739
# Found minimum norm =  15.715211959076147  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZZ  gave for s =  0.0498046875   minimal norm  15.715211959076147
# Found minimum norm =  15.665546860812862  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZ1  gave for s =  0.0498046875   minimal norm  15.665546860812862
# Found minimum norm =  15.946913194046717  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1Z  gave for s =  0.0498046875   minimal norm  15.946913194046717
# Found minimum norm =  15.911535451034458  for s =  0.046289062500000006
# Flow step output with generator type  single_commutator using string  1ZZ11  gave for s =  0.046289062500000006   minimal norm  15.911535451034458
# Found minimum norm =  16.124457644105046  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1ZZ  gave for s =  0.0498046875   minimal norm  16.124457644105046
# Found minimum norm =  16.006371231394738  for s =  0.0490234375
# Flow step output with generator type  single_commutator using string  1Z1Z1  gave for s =  0.0490234375   minimal norm  16.006371231394738
# Found minimum norm =  16.117734122745542  for s =  0.040429687500000006
# Flow step output with generator type  single_commutator using string  1Z11Z  gave for s =  0.040429687500000006   minimal norm  16.117734122745542
# Found minimum norm =  15.206296392931787  for s =  0.0544921875
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.0544921875   minimal norm  15.206296392931787
# Found minimum norm =  15.851666030590847  for s =  0.0419921875
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.0419921875   minimal norm  15.851666030590847
# Found minimum norm =  15.91153545103446  for s =  0.046289062500000006
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.046289062500000006   minimal norm  15.91153545103446
# Found minimum norm =  16.117721739501498  for s =  0.04082031250000001
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.04082031250000001   minimal norm  16.117721739501498
# Found minimum norm =  15.139340018554051  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.0498046875   minimal norm  15.139340018554051
# Found minimum norm =  16.03323028147494  for s =  0.0373046875
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.0373046875   minimal norm  16.03323028147494
# Found minimum norm =  15.206296392931785  for s =  0.0544921875
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.0544921875   minimal norm  15.206296392931785
# Found minimum norm =  15.586095261131739  for s =  0.05996093749999999
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.05996093749999999   minimal norm  15.586095261131739
# Found minimum norm =  16.436530898511435  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111  gave for s =  0.0001953125   minimal norm  16.436530898511435
# Found minimum norm =  14.040563112531542  for s =  0.011132812500000002
# Found that canonical is better because  14.040563112531542 15.139340018554051
# Found minimum norm =  14.040563112531542  for s =  0.011132812500000002
# Flowing forwards with type  canonical
# []
# Flow step  3
# Found minimum norm =  13.312207708325188  for s =  0.040429687500000006
# Flow step output with generator type  single_commutator using string  ZZZZZ  gave for s =  0.040429687500000006   minimal norm  13.312207708325188
# Found minimum norm =  13.555851265231386  for s =  0.040429687500000006
# Flow step output with generator type  single_commutator using string  ZZZZ1  gave for s =  0.040429687500000006   minimal norm  13.555851265231386
# Found minimum norm =  13.715144620309845  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1Z  gave for s =  0.0498046875   minimal norm  13.715144620309845
# Found minimum norm =  13.55521636122819  for s =  0.044335937500000006
# Flow step output with generator type  single_commutator using string  ZZZ11  gave for s =  0.044335937500000006   minimal norm  13.55521636122819
# Found minimum norm =  13.85477633234517  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZ  gave for s =  0.0498046875   minimal norm  13.85477633234517
# Found minimum norm =  13.850035909029902  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1Z1  gave for s =  0.0498046875   minimal norm  13.850035909029902
# Found minimum norm =  13.669154321617947  for s =  0.038476562500000006
# Flow step output with generator type  single_commutator using string  ZZ11Z  gave for s =  0.038476562500000006   minimal norm  13.669154321617947
# Found minimum norm =  13.654249653015237  for s =  0.03886718750000001
# Flow step output with generator type  single_commutator using string  ZZ111  gave for s =  0.03886718750000001   minimal norm  13.654249653015237
# Found minimum norm =  13.715144620309843  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZZ  gave for s =  0.0498046875   minimal norm  13.715144620309843
# Found minimum norm =  13.843423668040076  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZ1  gave for s =  0.0498046875   minimal norm  13.843423668040076
# Found minimum norm =  13.696414020463308  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z1Z  gave for s =  0.0498046875   minimal norm  13.696414020463308
# Found minimum norm =  13.604980260094793  for s =  0.0490234375
# Flow step output with generator type  single_commutator using string  Z1Z11  gave for s =  0.0490234375   minimal norm  13.604980260094793
# Found minimum norm =  13.669154321617945  for s =  0.038476562500000006
# Flow step output with generator type  single_commutator using string  Z11ZZ  gave for s =  0.038476562500000006   minimal norm  13.669154321617945
# Found minimum norm =  13.552555258386512  for s =  0.0470703125
# Flow step output with generator type  single_commutator using string  Z11Z1  gave for s =  0.0470703125   minimal norm  13.552555258386512
# Found minimum norm =  13.545518066411532  for s =  0.0490234375
# Flow step output with generator type  single_commutator using string  Z111Z  gave for s =  0.0490234375   minimal norm  13.545518066411532
# Found minimum norm =  13.450260245245925  for s =  0.0568359375
# Flow step output with generator type  single_commutator using string  Z1111  gave for s =  0.0568359375   minimal norm  13.450260245245925
# Found minimum norm =  13.555851265231386  for s =  0.040429687500000006
# Flow step output with generator type  single_commutator using string  1ZZZZ  gave for s =  0.040429687500000006   minimal norm  13.555851265231386
# Found minimum norm =  13.586984257901385  for s =  0.0486328125
# Flow step output with generator type  single_commutator using string  1ZZZ1  gave for s =  0.0486328125   minimal norm  13.586984257901385
# Found minimum norm =  13.843423668040078  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1Z  gave for s =  0.0498046875   minimal norm  13.843423668040078
# Found minimum norm =  13.63311641882948  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ11  gave for s =  0.0498046875   minimal norm  13.63311641882948
# Found minimum norm =  13.850035909029906  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1ZZ  gave for s =  0.0498046875   minimal norm  13.850035909029906
# Found minimum norm =  13.405760677831909  for s =  0.0642578125
# Flow step output with generator type  single_commutator using string  1Z1Z1  gave for s =  0.0642578125   minimal norm  13.405760677831909
# Found minimum norm =  13.552555258386512  for s =  0.0470703125
# Flow step output with generator type  single_commutator using string  1Z11Z  gave for s =  0.0470703125   minimal norm  13.552555258386512
# Found minimum norm =  13.222079536651949  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.0498046875   minimal norm  13.222079536651949
# Found minimum norm =  13.555216361228188  for s =  0.044335937500000006
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.044335937500000006   minimal norm  13.555216361228188
# Found minimum norm =  13.63311641882948  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.0498046875   minimal norm  13.63311641882948
# Found minimum norm =  13.604980260094793  for s =  0.0490234375
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.0490234375   minimal norm  13.604980260094793
# Found minimum norm =  13.277166034178366  for s =  0.04550781250000001
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.04550781250000001   minimal norm  13.277166034178366
# Found minimum norm =  13.654249653015238  for s =  0.03886718750000001
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.03886718750000001   minimal norm  13.654249653015238
# Found minimum norm =  13.22207953665195  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.0498046875   minimal norm  13.22207953665195
# Found minimum norm =  13.450260245245929  for s =  0.0568359375
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.0568359375   minimal norm  13.450260245245929
# Found minimum norm =  14.040563112531542  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111  gave for s =  0.0001953125   minimal norm  14.040563112531542
# Found minimum norm =  12.911537245704805  for s =  0.0068359375
# Found that canonical is better because  12.911537245704805 13.222079536651949
# Found minimum norm =  12.911537245704805  for s =  0.0068359375
# Flowing forwards with type  canonical
# []
# Flow step  4
# Found minimum norm =  12.327408500874716  for s =  0.0458984375
# Flow step output with generator type  single_commutator using string  ZZZZZ  gave for s =  0.0458984375   minimal norm  12.327408500874716
# Found minimum norm =  12.547801703025296  for s =  0.0431640625
# Flow step output with generator type  single_commutator using string  ZZZZ1  gave for s =  0.0431640625   minimal norm  12.547801703025296
# Found minimum norm =  12.777006451517178  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1Z  gave for s =  0.0498046875   minimal norm  12.777006451517178
# Found minimum norm =  12.571192916977495  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ11  gave for s =  0.0498046875   minimal norm  12.571192916977495
# Found minimum norm =  12.911784238362316  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ1ZZ  gave for s =  0.0001953125   minimal norm  12.911784238362316
# Found minimum norm =  12.860837950856673  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1Z1  gave for s =  0.0498046875   minimal norm  12.860837950856673
# Found minimum norm =  12.598117465503904  for s =  0.04355468750000001
# Flow step output with generator type  single_commutator using string  ZZ11Z  gave for s =  0.04355468750000001   minimal norm  12.598117465503904
# Found minimum norm =  12.597789386039823  for s =  0.042382812500000006
# Flow step output with generator type  single_commutator using string  ZZ111  gave for s =  0.042382812500000006   minimal norm  12.597789386039823
# Found minimum norm =  12.77700645151718  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZZ  gave for s =  0.0498046875   minimal norm  12.77700645151718
# Found minimum norm =  12.860301811553578  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZ1  gave for s =  0.0498046875   minimal norm  12.860301811553578
# Found minimum norm =  12.70688833377625  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z1Z  gave for s =  0.0498046875   minimal norm  12.70688833377625
# Found minimum norm =  12.434035105301176  for s =  0.0615234375
# Flow step output with generator type  single_commutator using string  Z1Z11  gave for s =  0.0615234375   minimal norm  12.434035105301176
# Found minimum norm =  12.598117465503904  for s =  0.04355468750000001
# Flow step output with generator type  single_commutator using string  Z11ZZ  gave for s =  0.04355468750000001   minimal norm  12.598117465503904
# Found minimum norm =  12.376963355711736  for s =  0.0623046875
# Flow step output with generator type  single_commutator using string  Z11Z1  gave for s =  0.0623046875   minimal norm  12.376963355711736
# Found minimum norm =  12.320789996814005  for s =  0.06816406250000001
# Flow step output with generator type  single_commutator using string  Z111Z  gave for s =  0.06816406250000001   minimal norm  12.320789996814005
# Found minimum norm =  12.460264179168071  for s =  0.0615234375
# Flow step output with generator type  single_commutator using string  Z1111  gave for s =  0.0615234375   minimal norm  12.460264179168071
# Found minimum norm =  12.547801703025296  for s =  0.0431640625
# Flow step output with generator type  single_commutator using string  1ZZZZ  gave for s =  0.0431640625   minimal norm  12.547801703025296
# Found minimum norm =  12.62057707406243  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZ1  gave for s =  0.0498046875   minimal norm  12.62057707406243
# Found minimum norm =  12.860301811553578  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1Z  gave for s =  0.0498046875   minimal norm  12.860301811553578
# Found minimum norm =  12.549178480996677  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  1ZZ11  gave for s =  0.0705078125   minimal norm  12.549178480996677
# Found minimum norm =  12.860837950856675  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1ZZ  gave for s =  0.0498046875   minimal norm  12.860837950856675
# Found minimum norm =  12.210115765279538  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  1Z1Z1  gave for s =  0.07480468750000001   minimal norm  12.210115765279538
# Found minimum norm =  12.376963355711736  for s =  0.0623046875
# Flow step output with generator type  single_commutator using string  1Z11Z  gave for s =  0.0623046875   minimal norm  12.376963355711736
# Found minimum norm =  12.29111109092425  for s =  0.0544921875
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.0544921875   minimal norm  12.29111109092425
# Found minimum norm =  12.571192916977491  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.0498046875   minimal norm  12.571192916977491
# Found minimum norm =  12.549178480996677  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.0705078125   minimal norm  12.549178480996677
# Found minimum norm =  12.434035105301176  for s =  0.0615234375
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.0615234375   minimal norm  12.434035105301176
# Found minimum norm =  12.404173449418789  for s =  0.04472656250000001
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.04472656250000001   minimal norm  12.404173449418789
# Found minimum norm =  12.597789386039823  for s =  0.042382812500000006
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.042382812500000006   minimal norm  12.597789386039823
# Found minimum norm =  12.29111109092425  for s =  0.0544921875
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.0544921875   minimal norm  12.29111109092425
# Found minimum norm =  12.460264179168071  for s =  0.0615234375
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.0615234375   minimal norm  12.460264179168071
# Found minimum norm =  12.911537245704805  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111  gave for s =  0.0001953125   minimal norm  12.911537245704805
# Found minimum norm =  12.26005119121383  for s =  0.005664062500000001
# Found that canonical is worse because  12.26005119121383 12.210115765279538
# Found minimum norm =  12.210115765279538  for s =  0.07480468750000001
# Flowing forwards with type  single_commutator
# []
# Flow step  5
# Found minimum norm =  11.514342090305556  for s =  0.040429687500000006
# Flow step output with generator type  single_commutator using string  ZZZZZ  gave for s =  0.040429687500000006   minimal norm  11.514342090305556
# Found minimum norm =  11.721061264373644  for s =  0.03574218750000001
# Flow step output with generator type  single_commutator using string  ZZZZ1  gave for s =  0.03574218750000001   minimal norm  11.721061264373644
# Found minimum norm =  12.033464350337075  for s =  0.0294921875
# Flow step output with generator type  single_commutator using string  ZZZ1Z  gave for s =  0.0294921875   minimal norm  12.033464350337075
# Found minimum norm =  11.869207749748606  for s =  0.0349609375
# Flow step output with generator type  single_commutator using string  ZZZ11  gave for s =  0.0349609375   minimal norm  11.869207749748606
# Found minimum norm =  12.195220622194617  for s =  0.0107421875
# Flow step output with generator type  single_commutator using string  ZZ1ZZ  gave for s =  0.0107421875   minimal norm  12.195220622194617
# Found minimum norm =  12.210728380894881  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ1Z1  gave for s =  0.0001953125   minimal norm  12.210728380894881
# Found minimum norm =  11.842214404810727  for s =  0.0333984375
# Flow step output with generator type  single_commutator using string  ZZ11Z  gave for s =  0.0333984375   minimal norm  11.842214404810727
# Found minimum norm =  11.69268581510268  for s =  0.0427734375
# Flow step output with generator type  single_commutator using string  ZZ111  gave for s =  0.0427734375   minimal norm  11.69268581510268
# Found minimum norm =  12.033464350337075  for s =  0.0294921875
# Flow step output with generator type  single_commutator using string  Z1ZZZ  gave for s =  0.0294921875   minimal norm  12.033464350337075
# Found minimum norm =  12.126905492854672  for s =  0.022851562500000002
# Flow step output with generator type  single_commutator using string  Z1ZZ1  gave for s =  0.022851562500000002   minimal norm  12.126905492854672
# Found minimum norm =  12.209726147971875  for s =  0.0013671875000000001
# Flow step output with generator type  single_commutator using string  Z1Z1Z  gave for s =  0.0013671875000000001   minimal norm  12.209726147971875
# Found minimum norm =  11.90344240082118  for s =  0.0380859375
# Flow step output with generator type  single_commutator using string  Z1Z11  gave for s =  0.0380859375   minimal norm  11.90344240082118
# Found minimum norm =  11.842214404810727  for s =  0.0333984375
# Flow step output with generator type  single_commutator using string  Z11ZZ  gave for s =  0.0333984375   minimal norm  11.842214404810727
# Found minimum norm =  12.055628910684158  for s =  0.022460937500000003
# Flow step output with generator type  single_commutator using string  Z11Z1  gave for s =  0.022460937500000003   minimal norm  12.055628910684158
# Found minimum norm =  11.849382734492881  for s =  0.0349609375
# Flow step output with generator type  single_commutator using string  Z111Z  gave for s =  0.0349609375   minimal norm  11.849382734492881
# Found minimum norm =  11.668271736815061  for s =  0.040039062500000014
# Flow step output with generator type  single_commutator using string  Z1111  gave for s =  0.040039062500000014   minimal norm  11.668271736815061
# Found minimum norm =  11.721061264373645  for s =  0.03574218750000001
# Flow step output with generator type  single_commutator using string  1ZZZZ  gave for s =  0.03574218750000001   minimal norm  11.721061264373645
# Found minimum norm =  12.202201021085582  for s =  0.013085937500000002
# Flow step output with generator type  single_commutator using string  1ZZZ1  gave for s =  0.013085937500000002   minimal norm  12.202201021085582
# Found minimum norm =  12.126905492854672  for s =  0.022851562500000002
# Flow step output with generator type  single_commutator using string  1ZZ1Z  gave for s =  0.022851562500000002   minimal norm  12.126905492854672
# Found minimum norm =  12.087088508157182  for s =  0.025585937500000003
# Flow step output with generator type  single_commutator using string  1ZZ11  gave for s =  0.025585937500000003   minimal norm  12.087088508157182
# Found minimum norm =  12.210728380894881  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z1ZZ  gave for s =  0.0001953125   minimal norm  12.210728380894881
# Found minimum norm =  11.788313314348127  for s =  0.0333984375
# Flow step output with generator type  single_commutator using string  1Z1Z1  gave for s =  0.0333984375   minimal norm  11.788313314348127
# Found minimum norm =  12.05562891068416  for s =  0.022460937500000003
# Flow step output with generator type  single_commutator using string  1Z11Z  gave for s =  0.022460937500000003   minimal norm  12.05562891068416
# Found minimum norm =  11.749744466522884  for s =  0.038476562500000006
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.038476562500000006   minimal norm  11.749744466522884
# Found minimum norm =  11.869207749748606  for s =  0.0349609375
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.0349609375   minimal norm  11.869207749748606
# Found minimum norm =  12.08708850815718  for s =  0.025585937500000003
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.025585937500000003   minimal norm  12.08708850815718
# Found minimum norm =  11.903442400821179  for s =  0.0380859375
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.0380859375   minimal norm  11.903442400821179
# Found minimum norm =  11.369058430560989  for s =  0.0380859375
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.0380859375   minimal norm  11.369058430560989
# Found minimum norm =  11.692685815102681  for s =  0.0427734375
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.0427734375   minimal norm  11.692685815102681
# Found minimum norm =  11.749744466522884  for s =  0.038476562500000006
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.038476562500000006   minimal norm  11.749744466522884
# Found minimum norm =  11.668271736815065  for s =  0.040039062500000014
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.040039062500000014   minimal norm  11.668271736815065
# Found minimum norm =  12.210115765279538  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111  gave for s =  0.0001953125   minimal norm  12.210115765279538
# Found minimum norm =  11.427048648311144  for s =  0.0041015625
# Found that canonical is worse because  11.427048648311144 11.369058430560989
# Found minimum norm =  11.369058430560989  for s =  0.0380859375
# Flowing forwards with type  single_commutator
# []
# Flow step  6
# Found minimum norm =  10.719066045936154  for s =  0.0595703125
# Flow step output with generator type  single_commutator using string  ZZZZZ  gave for s =  0.0595703125   minimal norm  10.719066045936154
# Found minimum norm =  11.00992302844813  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZ1  gave for s =  0.0498046875   minimal norm  11.00992302844813
# Found minimum norm =  11.286840681303675  for s =  0.0349609375
# Flow step output with generator type  single_commutator using string  ZZZ1Z  gave for s =  0.0349609375   minimal norm  11.286840681303675
# Found minimum norm =  11.255338674206863  for s =  0.03378906250000001
# Flow step output with generator type  single_commutator using string  ZZZ11  gave for s =  0.03378906250000001   minimal norm  11.255338674206863
# Found minimum norm =  11.365520952147827  for s =  0.0060546875
# Flow step output with generator type  single_commutator using string  ZZ1ZZ  gave for s =  0.0060546875   minimal norm  11.365520952147827
# Found minimum norm =  11.37061986632748  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ1Z1  gave for s =  0.0001953125   minimal norm  11.37061986632748
# Found minimum norm =  11.16861954170088  for s =  0.0412109375
# Flow step output with generator type  single_commutator using string  ZZ11Z  gave for s =  0.0412109375   minimal norm  11.16861954170088
# Found minimum norm =  10.889655272096512  for s =  0.0556640625
# Flow step output with generator type  single_commutator using string  ZZ111  gave for s =  0.0556640625   minimal norm  10.889655272096512
# Found minimum norm =  11.286840681303676  for s =  0.0349609375
# Flow step output with generator type  single_commutator using string  Z1ZZZ  gave for s =  0.0349609375   minimal norm  11.286840681303676
# Found minimum norm =  11.320560917247445  for s =  0.024804687500000002
# Flow step output with generator type  single_commutator using string  Z1ZZ1  gave for s =  0.024804687500000002   minimal norm  11.320560917247445
# Found minimum norm =  11.369887011070839  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z1Z1Z  gave for s =  0.0001953125   minimal norm  11.369887011070839
# Found minimum norm =  11.22351465636232  for s =  0.0427734375
# Flow step output with generator type  single_commutator using string  Z1Z11  gave for s =  0.0427734375   minimal norm  11.22351465636232
# Found minimum norm =  11.16861954170088  for s =  0.0412109375
# Flow step output with generator type  single_commutator using string  Z11ZZ  gave for s =  0.0412109375   minimal norm  11.16861954170088
# Found minimum norm =  11.367391913682704  for s =  0.004882812500000001
# Flow step output with generator type  single_commutator using string  Z11Z1  gave for s =  0.004882812500000001   minimal norm  11.367391913682704
# Found minimum norm =  11.113400661760659  for s =  0.047460937499999994
# Flow step output with generator type  single_commutator using string  Z111Z  gave for s =  0.047460937499999994   minimal norm  11.113400661760659
# Found minimum norm =  10.788164308871488  for s =  0.0537109375
# Flow step output with generator type  single_commutator using string  Z1111  gave for s =  0.0537109375   minimal norm  10.788164308871488
# Found minimum norm =  11.009923028448132  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZZ  gave for s =  0.0498046875   minimal norm  11.009923028448132
# Found minimum norm =  11.35778169746513  for s =  0.0322265625
# Flow step output with generator type  single_commutator using string  1ZZZ1  gave for s =  0.0322265625   minimal norm  11.35778169746513
# Found minimum norm =  11.320560917247448  for s =  0.024804687500000002
# Flow step output with generator type  single_commutator using string  1ZZ1Z  gave for s =  0.024804687500000002   minimal norm  11.320560917247448
# Found minimum norm =  11.353231223245794  for s =  0.0162109375
# Flow step output with generator type  single_commutator using string  1ZZ11  gave for s =  0.0162109375   minimal norm  11.353231223245794
# Found minimum norm =  11.370619866327482  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z1ZZ  gave for s =  0.0001953125   minimal norm  11.370619866327482
# Found minimum norm =  11.170298559872862  for s =  0.0380859375
# Flow step output with generator type  single_commutator using string  1Z1Z1  gave for s =  0.0380859375   minimal norm  11.170298559872862
# Found minimum norm =  11.367391913682704  for s =  0.004882812500000001
# Flow step output with generator type  single_commutator using string  1Z11Z  gave for s =  0.004882812500000001   minimal norm  11.367391913682704
# Found minimum norm =  11.054008671511074  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.0498046875   minimal norm  11.054008671511074
# Found minimum norm =  11.255338674206865  for s =  0.03378906250000001
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.03378906250000001   minimal norm  11.255338674206865
# Found minimum norm =  11.353231223245794  for s =  0.0162109375
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.0162109375   minimal norm  11.353231223245794
# Found minimum norm =  11.22351465636232  for s =  0.0427734375
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.0427734375   minimal norm  11.22351465636232
# Found minimum norm =  10.968502809072701  for s =  0.0470703125
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.0470703125   minimal norm  10.968502809072701
# Found minimum norm =  10.889655272096514  for s =  0.0556640625
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.0556640625   minimal norm  10.889655272096514
# Found minimum norm =  11.054008671511072  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.0498046875   minimal norm  11.054008671511072
# Found minimum norm =  10.788164308871488  for s =  0.0537109375
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.0537109375   minimal norm  10.788164308871488
# Found minimum norm =  11.369058430560989  for s =  0.0001953125
# ...
# Found minimum norm =  10.503056951492876  for s =  0.03886718750000001
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.03886718750000001   minimal norm  10.503056951492876
# Found minimum norm =  10.674050491967545  for s =  0.017773437500000003
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.017773437500000003   minimal norm  10.674050491967545
# Found minimum norm =  10.69758843928148  for s =  0.0126953125
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.0126953125   minimal norm  10.69758843928148
# Found minimum norm =  10.601076192726579  for s =  0.03574218750000001
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.03574218750000001   minimal norm  10.601076192726579
# Found minimum norm =  10.228572977700544  for s =  0.04160156250000001
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.04160156250000001   minimal norm  10.228572977700544
# Found minimum norm =  10.402724422255758  for s =  0.0419921875
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.0419921875   minimal norm  10.402724422255758
# Found minimum norm =  10.503056951492876  for s =  0.03886718750000001
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.03886718750000001   minimal norm  10.503056951492876
# Found minimum norm =  10.214317672968152  for s =  0.0451171875
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.0451171875   minimal norm  10.214317672968152
# Found minimum norm =  10.719066045936154  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111  gave for s =  0.0001953125   minimal norm  10.719066045936154
# Found minimum norm =  10.250212231051593  for s =  0.0041015625
# Found that canonical is worse because  10.250212231051593 10.214317672968152
# Found minimum norm =  10.214317672968152  for s =  0.0451171875
# Flowing forwards with type  single_commutator
# []
# Flow step  8
# Found minimum norm =  10.179173084946664  for s =  0.017773437500000003
# Flow step output with generator type  single_commutator using string  ZZZZZ  gave for s =  0.017773437500000003   minimal norm  10.179173084946664
# Found minimum norm =  9.972569082863975  for s =  0.04160156250000001
# Flow step output with generator type  single_commutator using string  ZZZZ1  gave for s =  0.04160156250000001   minimal norm  9.972569082863975
# Found minimum norm =  10.214925572002755  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZZ1Z  gave for s =  0.0001953125   minimal norm  10.214925572002755
# Found minimum norm =  10.197898124354152  for s =  0.0115234375
# Flow step output with generator type  single_commutator using string  ZZZ11  gave for s =  0.0115234375   minimal norm  10.197898124354152
# Found minimum norm =  10.215003099139325  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ1ZZ  gave for s =  0.0001953125   minimal norm  10.215003099139325
# Found minimum norm =  10.215406647507045  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ1Z1  gave for s =  0.0001953125   minimal norm  10.215406647507045
# Found minimum norm =  10.132082297160702  for s =  0.0271484375
# Flow step output with generator type  single_commutator using string  ZZ11Z  gave for s =  0.0271484375   minimal norm  10.132082297160702
# Found minimum norm =  9.90546801085274  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ111  gave for s =  0.0498046875   minimal norm  9.90546801085274
# Found minimum norm =  10.214403398888606  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z1ZZZ  gave for s =  0.0001953125   minimal norm  10.214403398888606
# Found minimum norm =  10.165529023151967  for s =  0.020898437500000002
# Flow step output with generator type  single_commutator using string  Z1ZZ1  gave for s =  0.020898437500000002   minimal norm  10.165529023151967
# Found minimum norm =  10.214402473856996  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z1Z1Z  gave for s =  0.0001953125   minimal norm  10.214402473856996
# Found minimum norm =  10.177871507725044  for s =  0.0279296875
# Flow step output with generator type  single_commutator using string  Z1Z11  gave for s =  0.0279296875   minimal norm  10.177871507725044
# Found minimum norm =  10.093281338176538  for s =  0.032617187500000006
# Flow step output with generator type  single_commutator using string  Z11ZZ  gave for s =  0.032617187500000006   minimal norm  10.093281338176538
# Found minimum norm =  10.214468143335267  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z11Z1  gave for s =  0.0001953125   minimal norm  10.214468143335267
# Found minimum norm =  10.043259692441122  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z111Z  gave for s =  0.0498046875   minimal norm  10.043259692441122
# Found minimum norm =  9.95022434181535  for s =  0.03886718750000001
# Flow step output with generator type  single_commutator using string  Z1111  gave for s =  0.03886718750000001   minimal norm  9.95022434181535
# Found minimum norm =  9.9918474678055  for s =  0.0373046875
# Flow step output with generator type  single_commutator using string  1ZZZZ  gave for s =  0.0373046875   minimal norm  9.9918474678055
# Found minimum norm =  10.168414384341473  for s =  0.0275390625
# Flow step output with generator type  single_commutator using string  1ZZZ1  gave for s =  0.0275390625   minimal norm  10.168414384341473
# Found minimum norm =  10.173340102572451  for s =  0.020898437500000002
# Flow step output with generator type  single_commutator using string  1ZZ1Z  gave for s =  0.020898437500000002   minimal norm  10.173340102572451
# Found minimum norm =  10.206203320527264  for s =  0.009179687500000002
# Flow step output with generator type  single_commutator using string  1ZZ11  gave for s =  0.009179687500000002   minimal norm  10.206203320527264
# Found minimum norm =  10.215661561541792  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z1ZZ  gave for s =  0.0001953125   minimal norm  10.215661561541792
# Found minimum norm =  9.943875071618214  for s =  0.03886718750000001
# Flow step output with generator type  single_commutator using string  1Z1Z1  gave for s =  0.03886718750000001   minimal norm  9.943875071618214
# Found minimum norm =  10.21443583223807  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z11Z  gave for s =  0.0001953125   minimal norm  10.21443583223807
# Found minimum norm =  10.047267210584018  for s =  0.038476562500000006
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.038476562500000006   minimal norm  10.047267210584018
# Found minimum norm =  10.187155302335594  for s =  0.0158203125
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.0158203125   minimal norm  10.187155302335594
# Found minimum norm =  10.214490207753732  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.0001953125   minimal norm  10.214490207753732
# Found minimum norm =  9.992057929278536  for s =  0.05722656250000001
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.05722656250000001   minimal norm  9.992057929278536
# Found minimum norm =  9.673549763813451  for s =  0.0486328125
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.0486328125   minimal norm  9.673549763813451
# Found minimum norm =  9.90986917837669  for s =  0.04941406250000001
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.04941406250000001   minimal norm  9.90986917837669
# Found minimum norm =  10.060593684964667  for s =  0.0380859375
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.0380859375   minimal norm  10.060593684964667
# Found minimum norm =  9.687223864626548  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.0498046875   minimal norm  9.687223864626548
# Found minimum norm =  10.214317672968152  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111  gave for s =  0.0001953125   minimal norm  10.214317672968152
# Found minimum norm =  9.818463412026675  for s =  0.0041015625
# Found that canonical is worse because  9.818463412026675 9.673549763813451
# Found minimum norm =  9.673549763813451  for s =  0.0486328125
# Flowing forwards with type  single_commutator
# []
# Flow step  9
# Found minimum norm =  9.618596883474458  for s =  0.0236328125
# Flow step output with generator type  single_commutator using string  ZZZZZ  gave for s =  0.0236328125   minimal norm  9.618596883474458
# Found minimum norm =  9.443291553307573  for s =  0.0349609375
# Flow step output with generator type  single_commutator using string  ZZZZ1  gave for s =  0.0349609375   minimal norm  9.443291553307573
# Found minimum norm =  9.674019315995103  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZZ1Z  gave for s =  0.0001953125   minimal norm  9.674019315995103
# Found minimum norm =  9.650278590806773  for s =  0.012304687500000001
# Flow step output with generator type  single_commutator using string  ZZZ11  gave for s =  0.012304687500000001   minimal norm  9.650278590806773
# Found minimum norm =  9.673653167900216  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ1ZZ  gave for s =  0.0001953125   minimal norm  9.673653167900216
# Found minimum norm =  9.674546736356206  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ1Z1  gave for s =  0.0001953125   minimal norm  9.674546736356206
# Found minimum norm =  9.59325885192603  for s =  0.024804687500000002
# Flow step output with generator type  single_commutator using string  ZZ11Z  gave for s =  0.024804687500000002   minimal norm  9.59325885192603
# Found minimum norm =  9.400430778744541  for s =  0.044335937500000006
# Flow step output with generator type  single_commutator using string  ZZ111  gave for s =  0.044335937500000006   minimal norm  9.400430778744541
# Found minimum norm =  9.67357921029085  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z1ZZZ  gave for s =  0.0001953125   minimal norm  9.67357921029085
# Found minimum norm =  9.618700786530747  for s =  0.019335937500000004
# Flow step output with generator type  single_commutator using string  Z1ZZ1  gave for s =  0.019335937500000004   minimal norm  9.618700786530747
# Found minimum norm =  9.654423150672745  for s =  0.009179687500000002
# Flow step output with generator type  single_commutator using string  Z1Z1Z  gave for s =  0.009179687500000002   minimal norm  9.654423150672745
# Found minimum norm =  9.62224687553082  for s =  0.0431640625
# Flow step output with generator type  single_commutator using string  Z1Z11  gave for s =  0.0431640625   minimal norm  9.62224687553082
# Found minimum norm =  9.565147821911644  for s =  0.0279296875
# Flow step output with generator type  single_commutator using string  Z11ZZ  gave for s =  0.0279296875   minimal norm  9.565147821911644
# Found minimum norm =  9.673640135236768  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z11Z1  gave for s =  0.0001953125   minimal norm  9.673640135236768
# Found minimum norm =  9.532186859821362  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z111Z  gave for s =  0.0498046875   minimal norm  9.532186859821362
# Found minimum norm =  9.355218786041688  for s =  0.03691406250000001
# Flow step output with generator type  single_commutator using string  Z1111  gave for s =  0.03691406250000001   minimal norm  9.355218786041688
# Found minimum norm =  9.47885793732334  for s =  0.0314453125
# Flow step output with generator type  single_commutator using string  1ZZZZ  gave for s =  0.0314453125   minimal norm  9.47885793732334
# Found minimum norm =  9.614554188522701  for s =  0.026757812500000002
# Flow step output with generator type  single_commutator using string  1ZZZ1  gave for s =  0.026757812500000002   minimal norm  9.614554188522701
# Found minimum norm =  9.64268845223307  for s =  0.0154296875
# Flow step output with generator type  single_commutator using string  1ZZ1Z  gave for s =  0.0154296875   minimal norm  9.64268845223307
# Found minimum norm =  9.66618737061272  for s =  0.008398437500000001
# Flow step output with generator type  single_commutator using string  1ZZ11  gave for s =  0.008398437500000001   minimal norm  9.66618737061272
# Found minimum norm =  9.674789136209197  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z1ZZ  gave for s =  0.0001953125   minimal norm  9.674789136209197
# Found minimum norm =  9.455877120359162  for s =  0.0322265625
# Flow step output with generator type  single_commutator using string  1Z1Z1  gave for s =  0.0322265625   minimal norm  9.455877120359162
# Found minimum norm =  9.67343674866044  for s =  0.0009765625
# Flow step output with generator type  single_commutator using string  1Z11Z  gave for s =  0.0009765625   minimal norm  9.67343674866044
# Found minimum norm =  9.487719615783922  for s =  0.034570312500000006
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.034570312500000006   minimal norm  9.487719615783922
# Found minimum norm =  9.645477455082867  for s =  0.014257812500000001
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.014257812500000001   minimal norm  9.645477455082867
# Found minimum norm =  9.673671056281872  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.0001953125   minimal norm  9.673671056281872
# Found minimum norm =  9.438745176608352  for s =  0.0634765625
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.0634765625   minimal norm  9.438745176608352
# Found minimum norm =  9.387298196952514  for s =  0.0341796875
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.0341796875   minimal norm  9.387298196952514
# Found minimum norm =  9.36380047218139  for s =  0.047460937499999994
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.047460937499999994   minimal norm  9.36380047218139
# Found minimum norm =  9.514124765237542  for s =  0.03378906250000001
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.03378906250000001   minimal norm  9.514124765237542
# Found minimum norm =  9.117432762543185  for s =  0.0470703125
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.0470703125   minimal norm  9.117432762543185
# Found minimum norm =  9.673549763813451  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111  gave for s =  0.0001953125   minimal norm  9.673549763813451
# Found minimum norm =  9.330250192735662  for s =  0.0033203125000000003
# Found that canonical is worse because  9.330250192735662 9.117432762543185
# Found minimum norm =  9.117432762543185  for s =  0.0470703125
# Flowing forwards with type  single_commutator
# []

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

def plot_iteration_results(  ):
    flow.run_param_rc(fontsize=19)
    flow_results = flow.flow_outputs

    f=plt.figure(figsize = ( 8,7 ))
    n=1
    ax_a = f.add_subplot(1,n,1)
    norms = flow_results['minimal_norm_sigma_H_s']
    x_axis = [sum(flow_results['minimizing_flow_step'][:k])for k in range( 1, len(flow_results['minimizing_flow_step'])+1)]

    plt.plot( x_axis, norms, '-o')   
    N = 10
    k=0
    for xy in zip([x+.01 for x in x_axis[0:N]], 
                  [n - 0.03 for n in norms[0:N]]):  
        if k == 0 or k == 9 or k == 8:
            a=1
        else:
            plt.annotate('k = ' + str(k) + ': ' + flow_results['strs_of_minimizer_Z'][k-1], xy=xy, textcoords='data', fontsize=17)
        k=k+1
    
    plt.annotate('k = ' + str(k) + ': ' + flow_results['strs_of_minimizer_Z'][k-1], 
                 xy=(x_axis[-1]-.11,norms[-1]-.7), textcoords='data', fontsize=17)

    plt.annotate('k = ' + str(k-1) + ': ' + flow_results['strs_of_minimizer_Z'][k-2], 
                 xy=(x_axis[k-1]-.11,norms[k-1]-.5), textcoords='data', fontsize=17)
    plt.annotate('k = ' + str(k-2) + ': ' + flow_results['strs_of_minimizer_Z'][k-3], 
                 xy=(x_axis[k-2]+.021,norms[k-2]-.13), textcoords='data', fontsize=17)
    x_labels_rounded = [ round(x, 2 ) for x in x_axis ]
    x_labels_rounded = [0] + x_labels_rounded[1:9]  + [max(x_labels_rounded)]
    x_labels_rounded.pop(2)
    x_labels_rounded.pop(2)
    x_labels_rounded.pop(-2)
#     x_labels_rounded.pop(4)
    
    plt.xticks(x_labels_rounded)
    y_labels_rounded = [ round(y, 1 ) for y in norms ]
    y_labels_rounded = y_labels_rounded[0:5] + [min(y_labels_rounded)]
    plt.yticks(y_labels_rounded)
    plt.grid()
    plt.xlabel(r'Total flow duration $\ell$')
    plt.title(r'Norm off-diagonal $\vert\vert\sigma(\hat H_k)\vert\vert$')
    a =-.1
    b = 1.05
 
    axin1 = ax_a.inset_axes([0.2,.7, 0.31, 0.27])
    inset1 = axin1.imshow( H_TLFIM, cmap='RdBu' )
    divider1 = make_axes_locatable(axin1)
    div_ax = divider1.append_axes("right", size="10%", pad=0.05)
    cbar1 = plt.colorbar(inset1, cax = div_ax )
    range_plot = np.max( np.abs( H_TLFIM ) )
#     cbar1.set_clim( -range_plot, range_plot )
    axin1.set_yticks(range(2**L))  
    axin1.set_xticklabels([1]+['']*(2**L-2)+[2**L])
    axin1.set_yticklabels([1]+['']*(2**L-2)+[2**L])
    axin1.set_xticks(range(2**L))
    ax_a.annotate(' ',
            xy=(x_axis[0]+.01, norms[0]),  # theta, radius
            xytext=(0.24, 0.81),    # fraction, fraction
            textcoords='figure fraction',
            arrowprops=dict(facecolor='gray', shrink=0.01),
            horizontalalignment='left',
            verticalalignment='bottom')
#     axin1.set_xlabel(r'$j$')
#     axin1.set_title(r'$k$')
#     axin1.grid()
    axin2 = ax_a.inset_axes([0.65,.32, 0.31, 0.27])
    inset2 = axin2.imshow(flow_results['optimally_flowed_H'][-1], cmap='RdBu')

    divider2 = make_axes_locatable(axin2)
    div_ax2 = divider2.append_axes("right", size="10%", pad=0.05)
    cbar2 = plt.colorbar(inset2, cax = div_ax2 )
    ax_a.annotate(' ',
        xy=(x_axis[-1], 11.4),  # theta, radius
        xytext=(.95, .3),    # fraction, fraction
        textcoords='axes fraction',
        arrowprops=dict(facecolor='gray', shrink=0.05),
        horizontalalignment='left',
        verticalalignment='bottom')
    
    axin3 = ax_a.inset_axes([0.65,.7, 0.31, 0.27])
    inset3 = axin3.imshow(flow_results['optimally_flowed_H'][2], cmap='RdBu')

    divider3 = make_axes_locatable(axin3)
    div_ax3 = divider3.append_axes("right", size="10%", pad=0.05)
    cbar2 = plt.colorbar(inset3, cax = div_ax3 )
    ax_a.annotate(' ',
        xy=(x_axis[2]+.01, norms[2]+.6),  # theta, radius
        xytext=(0.65, 0.67),    # fraction, fraction
        textcoords='axes fraction',
        arrowprops=dict(facecolor='gray', shrink=0.05),
        horizontalalignment='left',
        verticalalignment='bottom')
    axin2.set_yticks(range(2**L))  
    axin2.set_xticklabels([1]+['']*(2**L-2)+[2**L])
    axin2.set_yticklabels([1]+['']*(2**L-2)+[2**L])
    axin2.set_xticks(range(2**L))    
    axin3.set_yticks(range(2**L))  
    axin3.set_xticklabels([1]+['']*(2**L-2)+[2**L])
    axin3.set_yticklabels([1]+['']*(2**L-2)+[2**L])
    axin3.set_xticks(range(2**L))
    chosen_steps = [1,2]
    plt.savefig( 'figs/mix_L_'+str(L)+'.pdf')
    
plot_iteration_results()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:56: UserWarning: FixedFormatter should only be used together with FixedLocator
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:97: UserWarning: FixedFormatter should only be used together with FixedLocator
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:101: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# #### Some additional uses of the class

# %% [markdown]
# The stored observables are these:

# %%
flow.flow_outputs.keys()
# Out:
# dict_keys(['flow_generator_type', 'minimal_norms_sigma_H', 'minimizing_flow_step', 'cumulative_flow_parameters', 'flow_steps_grids_binary_search', 'norms_flow_generator_W', 'flowed_hamiltonians', 'flowed_hamiltonian', 'config', 'norm_H_for_optimal_Z', 'norms_H_for_different_Z', 'all_norms_computed_in_search', 'all_Z_names', 'str_of_minimizer_Z', 'optimally_flowed_H', 'minimal_norm_sigma_H_s', 's_grid', 'norms_sigma_H_s', 'strs_of_minimizer_Z', 'final_flowed_H'])

# %% [markdown]
# (some of these are empty)
# The Hamiltonians are stored as optimally flowed in the sense that the flow step duration was optimized by a brute force grid search or local binary search.
# The first element is the initial Hamiltonin so

# %%
len(flow.flow_outputs['optimally_flowed_H'])
# Out:
# 11

# %% [markdown]
# we get 1 + nmb of steps

# %% [markdown]
# #### Simple plot for debugging

# %%
H = flow.flow_outputs['final_flowed_H'][-1]

plt.figure()
plt.subplot(121)
plt.imshow(abs(H_TLFIM), cmap='RdBu')
plt.colorbar()
plt.subplot(122)
plt.imshow(abs(H), cmap='RdBu')
plt.colorbar()
plt.tight_layout()

# %% [markdown]
# This variable stores or strings that have been tested in each step

# %%
print(flow.flow_outputs['all_Z_names'])
# Out:
# ['ZZZZZ', 'ZZZZ1', 'ZZZ1Z', 'ZZZ11', 'ZZ1ZZ', 'ZZ1Z1', 'ZZ11Z', 'ZZ111', 'Z1ZZZ', 'Z1ZZ1', 'Z1Z1Z', 'Z1Z11', 'Z11ZZ', 'Z11Z1', 'Z111Z', 'Z1111', '1ZZZZ', '1ZZZ1', '1ZZ1Z', '1ZZ11', '1Z1ZZ', '1Z1Z1', '1Z11Z', '1Z111', '11ZZZ', '11ZZ1', '11Z1Z', '11Z11', '111ZZ', '111Z1', '1111Z', '11111']

# %% [markdown]
# and these are the strings that gave the optimal generator to decrease the norm of the off-diagonal restriction

# %%
flow.flow_outputs['strs_of_minimizer_Z']
# Out:
# ['Canonical',
#  'Canonical',
#  'Canonical',
#  'Canonical',
#  '1Z1Z1',
#  '11Z11',
#  'ZZZZZ',
#  'Z1111',
#  '11Z11',
#  '1111Z']

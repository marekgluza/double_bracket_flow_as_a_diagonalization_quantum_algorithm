# %%
from simple_exact_diagonalization_routines.local_matrix_class import *
from scipy.linalg import expm
import matplotlib.pyplot as plt
import time


# System size
L = 5

# Create objects of Pauli operators
X = X_class(L)
Y = Y_class(L)
Z = Z_class(L)
S_plus = S_plus_class(L)
S_minus = S_minus_class(L)

# Trivial initialization of the right size matrix
hamiltonian_name = "TLFIM_L_" +str(L)
H_TLFIM = 0*np.eye( 2**L ) 

for x in range(L-1):
    H_TLFIM = H_TLFIM + 2*X.at(x+1).dot(X.at(x+2)) + Z.at(x+1)+ X.at(x+1)
H_TLFIM = H_TLFIM + Z.at(L)    + X.at(L)

# %%
from class_double_bracket_flow import *


flow = double_bracket_flow( H_TLFIM )

flow.please_be_exhaustively_verbose = False
flow.please_be_verbose = True

flow.nmb_search_points_minimizing_s_search = 10
flow.flow_step_max = 0.2
flow.nmb_flow_steps = 10
flow.please_use_binary_search =  True
flow.please_compute_observables = False

#flow.flow_forwards( )
flow.flow_via_best_Z_search( please_also_check_canonical_bracket = True )

flow.show_flow_forwards_results()
# Out:
# Flow step  0
#     Found minimum norm =  25.162004614047625  for s =  0.09511718749999999
# Flow step output with generator type  single_commutator using string  ZZZZZ  gave for s =  0.09511718749999999   minimal norm  25.162004614047625
#     Found minimum norm =  24.47003064806511  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  ZZZZ1  gave for s =  0.08144531250000002   minimal norm  24.47003064806511
#     Found minimum norm =  24.086751971622455  for s =  0.0595703125
# Flow step output with generator type  single_commutator using string  ZZZ1Z  gave for s =  0.0595703125   minimal norm  24.086751971622455
#     Found minimum norm =  24.675806736260835  for s =  0.0880859375
# Flow step output with generator type  single_commutator using string  ZZZ11  gave for s =  0.0880859375   minimal norm  24.675806736260835
#     Found minimum norm =  24.08675197162246  for s =  0.0595703125
# Flow step output with generator type  single_commutator using string  ZZ1ZZ  gave for s =  0.0595703125   minimal norm  24.08675197162246
#     Found minimum norm =  23.371036802944545  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1Z1  gave for s =  0.0498046875   minimal norm  23.371036802944545
#     Found minimum norm =  23.80067215845854  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  ZZ11Z  gave for s =  0.0701171875   minimal norm  23.80067215845854
#     Found minimum norm =  24.855062846971677  for s =  0.09824218750000001
# Flow step output with generator type  single_commutator using string  ZZ111  gave for s =  0.09824218750000001   minimal norm  24.855062846971677
#     Found minimum norm =  24.08675197162246  for s =  0.0595703125
# Flow step output with generator type  single_commutator using string  Z1ZZZ  gave for s =  0.0595703125   minimal norm  24.08675197162246
#     Found minimum norm =  23.385936711463142  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZ1  gave for s =  0.0498046875   minimal norm  23.385936711463142
#     Found minimum norm =  22.41313875028987  for s =  0.05136718750000001
# Flow step output with generator type  single_commutator using string  Z1Z1Z  gave for s =  0.05136718750000001   minimal norm  22.41313875028987
#     Found minimum norm =  23.5451955012407  for s =  0.058007812500000006
# Flow step output with generator type  single_commutator using string  Z1Z11  gave for s =  0.058007812500000006   minimal norm  23.5451955012407
#     Found minimum norm =  23.80067215845854  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  Z11ZZ  gave for s =  0.0701171875   minimal norm  23.80067215845854
#     Found minimum norm =  23.069353686966746  for s =  0.0626953125
# Flow step output with generator type  single_commutator using string  Z11Z1  gave for s =  0.0626953125   minimal norm  23.069353686966746
#     Found minimum norm =  24.027159318572984  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  Z111Z  gave for s =  0.07363281250000002   minimal norm  24.027159318572984
#     Found minimum norm =  23.679128187419888  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  Z1111  gave for s =  0.0998046875   minimal norm  23.679128187419888
#     Found minimum norm =  24.470030648065105  for s =  0.08144531250000002
# Flow step output with generator type  single_commutator using string  1ZZZZ  gave for s =  0.08144531250000002   minimal norm  24.470030648065105
#     Found minimum norm =  23.80067215845854  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  1ZZZ1  gave for s =  0.0701171875   minimal norm  23.80067215845854
#     Found minimum norm =  23.385936711463142  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1Z  gave for s =  0.0498046875   minimal norm  23.385936711463142
#     Found minimum norm =  24.027159318572984  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  1ZZ11  gave for s =  0.07363281250000002   minimal norm  24.027159318572984
#     Found minimum norm =  23.371036802944545  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1ZZ  gave for s =  0.0498046875   minimal norm  23.371036802944545
#     Found minimum norm =  22.493752194945404  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1Z1  gave for s =  0.0498046875   minimal norm  22.493752194945404
#     Found minimum norm =  23.06935368696675  for s =  0.0626953125
# Flow step output with generator type  single_commutator using string  1Z11Z  gave for s =  0.0626953125   minimal norm  23.06935368696675
#     Found minimum norm =  22.41181472003877  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.07285156250000001   minimal norm  22.41181472003877
#     Found minimum norm =  24.67580673626084  for s =  0.0880859375
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.0880859375   minimal norm  24.67580673626084
#     Found minimum norm =  24.027159318572988  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.07363281250000002   minimal norm  24.027159318572988
#     Found minimum norm =  23.5451955012407  for s =  0.058007812500000006
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.058007812500000006   minimal norm  23.5451955012407
#     Found minimum norm =  22.411814720038766  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.07285156250000001   minimal norm  22.411814720038766
#     Found minimum norm =  24.855062846971677  for s =  0.09824218750000001
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.09824218750000001   minimal norm  24.855062846971677
#     Found minimum norm =  22.411814720038766  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.07285156250000001   minimal norm  22.411814720038766
#     Found minimum norm =  23.67912818741989  for s =  0.0998046875
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.0998046875   minimal norm  23.67912818741989
#     Found minimum norm =  25.92296279363144  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111  gave for s =  0.0001953125   minimal norm  25.92296279363144
#     Found minimum norm =  19.615017200428703  for s =  0.040429687500000006
# Found that canonical is better because  19.615017200428703 22.411814720038766
#     Found minimum norm =  19.615017200428703  for s =  0.040429687500000006
# Flowing forwards with type  canonical
# []
# Flow step  1
#     Found minimum norm =  18.776608593884706  for s =  0.0880859375
# Flow step output with generator type  single_commutator using string  ZZZZZ  gave for s =  0.0880859375   minimal norm  18.776608593884706
#     Found minimum norm =  18.633779735547144  for s =  0.07207031250000001
# Flow step output with generator type  single_commutator using string  ZZZZ1  gave for s =  0.07207031250000001   minimal norm  18.633779735547144
#     Found minimum norm =  18.655612792029885  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  ZZZ1Z  gave for s =  0.0701171875   minimal norm  18.655612792029885
#     Found minimum norm =  18.983882688746085  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ11  gave for s =  0.0498046875   minimal norm  18.983882688746085
#     Found minimum norm =  18.960659992228248  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZ  gave for s =  0.0498046875   minimal norm  18.960659992228248
#     Found minimum norm =  18.47429442647068  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  ZZ1Z1  gave for s =  0.0705078125   minimal norm  18.47429442647068
#     Found minimum norm =  19.106509603993988  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ11Z  gave for s =  0.0498046875   minimal norm  19.106509603993988
#     Found minimum norm =  18.975931535241333  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ111  gave for s =  0.0498046875   minimal norm  18.975931535241333
#     Found minimum norm =  18.655612792029885  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  Z1ZZZ  gave for s =  0.0701171875   minimal norm  18.655612792029885
#     Found minimum norm =  18.480275641688635  for s =  0.0642578125
# Flow step output with generator type  single_commutator using string  Z1ZZ1  gave for s =  0.0642578125   minimal norm  18.480275641688635
#     Found minimum norm =  17.638973802481782  for s =  0.07792968750000001
# Flow step output with generator type  single_commutator using string  Z1Z1Z  gave for s =  0.07792968750000001   minimal norm  17.638973802481782
#     Found minimum norm =  18.72197371592451  for s =  0.0724609375
# Flow step output with generator type  single_commutator using string  Z1Z11  gave for s =  0.0724609375   minimal norm  18.72197371592451
#     Found minimum norm =  19.106509603993988  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11ZZ  gave for s =  0.0498046875   minimal norm  19.106509603993988
#     Found minimum norm =  18.88775984766721  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11Z1  gave for s =  0.0498046875   minimal norm  18.88775984766721
#     Found minimum norm =  19.093732456689427  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z111Z  gave for s =  0.0498046875   minimal norm  19.093732456689427
#     Found minimum norm =  18.536129247120943  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  Z1111  gave for s =  0.07480468750000001   minimal norm  18.536129247120943
#     Found minimum norm =  18.63377973554714  for s =  0.07207031250000001
# Flow step output with generator type  single_commutator using string  1ZZZZ  gave for s =  0.07207031250000001   minimal norm  18.63377973554714
#     Found minimum norm =  18.319257049988792  for s =  0.0634765625
# Flow step output with generator type  single_commutator using string  1ZZZ1  gave for s =  0.0634765625   minimal norm  18.319257049988792
#     Found minimum norm =  18.480275641688632  for s =  0.0642578125
# Flow step output with generator type  single_commutator using string  1ZZ1Z  gave for s =  0.0642578125   minimal norm  18.480275641688632
#     Found minimum norm =  18.70205297750022  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ11  gave for s =  0.0498046875   minimal norm  18.70205297750022
#     Found minimum norm =  18.47429442647068  for s =  0.0705078125
# Flow step output with generator type  single_commutator using string  1Z1ZZ  gave for s =  0.0705078125   minimal norm  18.47429442647068
#     Found minimum norm =  17.866876547237993  for s =  0.08066406250000002
# Flow step output with generator type  single_commutator using string  1Z1Z1  gave for s =  0.08066406250000002   minimal norm  17.866876547237993
#     Found minimum norm =  18.887759847667205  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11Z  gave for s =  0.0498046875   minimal norm  18.887759847667205
#     Found minimum norm =  17.917545245398465  for s =  0.07089843750000001
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.07089843750000001   minimal norm  17.917545245398465
#     Found minimum norm =  18.983882688746085  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.0498046875   minimal norm  18.983882688746085
#     Found minimum norm =  18.70205297750022  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.0498046875   minimal norm  18.70205297750022
#     Found minimum norm =  18.72197371592451  for s =  0.0724609375
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.0724609375   minimal norm  18.72197371592451
#     Found minimum norm =  17.735459221995928  for s =  0.0607421875
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.0607421875   minimal norm  17.735459221995928
#     Found minimum norm =  18.975931535241333  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.0498046875   minimal norm  18.975931535241333
#     Found minimum norm =  17.917545245398465  for s =  0.07089843750000001
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.07089843750000001   minimal norm  17.917545245398465
#     Found minimum norm =  18.536129247120943  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.07480468750000001   minimal norm  18.536129247120943
#     Found minimum norm =  19.615017200428703  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111  gave for s =  0.0001953125   minimal norm  19.615017200428703
#     Found minimum norm =  16.24428203466039  for s =  0.0212890625
# Found that canonical is better because  16.24428203466039 17.638973802481782
#     Found minimum norm =  16.24428203466039  for s =  0.0212890625
# Flowing forwards with type  canonical
# []
# Flow step  2
#     Found minimum norm =  15.808388569285984  for s =  0.04550781250000001
# Flow step output with generator type  single_commutator using string  ZZZZZ  gave for s =  0.04550781250000001   minimal norm  15.808388569285984
#     Found minimum norm =  15.668611896683982  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZ1  gave for s =  0.0498046875   minimal norm  15.668611896683982
#     Found minimum norm =  15.952192901206082  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1Z  gave for s =  0.0498046875   minimal norm  15.952192901206082
#     Found minimum norm =  15.66723844384269  for s =  0.04355468750000001
# Flow step output with generator type  single_commutator using string  ZZZ11  gave for s =  0.04355468750000001   minimal norm  15.66723844384269
#     Found minimum norm =  16.068402042601793  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZ  gave for s =  0.0498046875   minimal norm  16.068402042601793
#     Found minimum norm =  15.973109989113434  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1Z1  gave for s =  0.0498046875   minimal norm  15.973109989113434
#     Found minimum norm =  16.182056297843943  for s =  0.024804687500000002
# Flow step output with generator type  single_commutator using string  ZZ11Z  gave for s =  0.024804687500000002   minimal norm  16.182056297843943
#     Found minimum norm =  15.828363935799054  for s =  0.0380859375
# Flow step output with generator type  single_commutator using string  ZZ111  gave for s =  0.0380859375   minimal norm  15.828363935799054
#     Found minimum norm =  15.952192901206082  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZZ  gave for s =  0.0498046875   minimal norm  15.952192901206082
#     Found minimum norm =  15.569916520275795  for s =  0.0693359375
# Flow step output with generator type  single_commutator using string  Z1ZZ1  gave for s =  0.0693359375   minimal norm  15.569916520275795
#     Found minimum norm =  15.832626310862251  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z1Z  gave for s =  0.0498046875   minimal norm  15.832626310862251
#     Found minimum norm =  15.995443916321083  for s =  0.03964843750000001
# Flow step output with generator type  single_commutator using string  Z1Z11  gave for s =  0.03964843750000001   minimal norm  15.995443916321083
#     Found minimum norm =  16.182056297843943  for s =  0.024804687500000002
# Flow step output with generator type  single_commutator using string  Z11ZZ  gave for s =  0.024804687500000002   minimal norm  16.182056297843943
#     Found minimum norm =  15.98445644181716  for s =  0.040429687500000006
# Flow step output with generator type  single_commutator using string  Z11Z1  gave for s =  0.040429687500000006   minimal norm  15.98445644181716
#     Found minimum norm =  16.169550217991357  for s =  0.0373046875
# Flow step output with generator type  single_commutator using string  Z111Z  gave for s =  0.0373046875   minimal norm  16.169550217991357
#     Found minimum norm =  15.466964563782714  for s =  0.06699218750000001
# Flow step output with generator type  single_commutator using string  Z1111  gave for s =  0.06699218750000001   minimal norm  15.466964563782714
#     Found minimum norm =  15.668611896683982  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZZ  gave for s =  0.0498046875   minimal norm  15.668611896683982
#     Found minimum norm =  15.247956975449565  for s =  0.061914062500000006
# Flow step output with generator type  single_commutator using string  1ZZZ1  gave for s =  0.061914062500000006   minimal norm  15.247956975449565
#     Found minimum norm =  15.569916520275793  for s =  0.0693359375
# Flow step output with generator type  single_commutator using string  1ZZ1Z  gave for s =  0.0693359375   minimal norm  15.569916520275793
#     Found minimum norm =  15.665046024948117  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ11  gave for s =  0.0498046875   minimal norm  15.665046024948117
#     Found minimum norm =  15.973109989113436  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1ZZ  gave for s =  0.0498046875   minimal norm  15.973109989113436
#     Found minimum norm =  15.785751217679387  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1Z1  gave for s =  0.0498046875   minimal norm  15.785751217679387
#     Found minimum norm =  15.984456441817166  for s =  0.040429687500000006
# Flow step output with generator type  single_commutator using string  1Z11Z  gave for s =  0.040429687500000006   minimal norm  15.984456441817166
#     Found minimum norm =  14.961324580172763  for s =  0.056054687500000006
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.056054687500000006   minimal norm  14.961324580172763
#     Found minimum norm =  15.667238443842688  for s =  0.04355468750000001
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.04355468750000001   minimal norm  15.667238443842688
#     Found minimum norm =  15.665046024948117  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.0498046875   minimal norm  15.665046024948117
#     Found minimum norm =  15.995443916321085  for s =  0.03964843750000001
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.03964843750000001   minimal norm  15.995443916321085
#     Found minimum norm =  14.90547779204353  for s =  0.052148437500000006
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.052148437500000006   minimal norm  14.90547779204353
#     Found minimum norm =  15.828363935799052  for s =  0.0380859375
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.0380859375   minimal norm  15.828363935799052
#     Found minimum norm =  14.961324580172763  for s =  0.056054687500000006
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.056054687500000006   minimal norm  14.961324580172763
#     Found minimum norm =  15.466964563782712  for s =  0.06699218750000001
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.06699218750000001   minimal norm  15.466964563782712
#     Found minimum norm =  16.24428203466039  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111  gave for s =  0.0001953125   minimal norm  16.24428203466039
#     Found minimum norm =  14.07362400816175  for s =  0.011132812500000002
# Found that canonical is better because  14.07362400816175 14.90547779204353
#     Found minimum norm =  14.07362400816175  for s =  0.011132812500000002
# Flowing forwards with type  canonical
# []
# Flow step  3
#     Found minimum norm =  13.688600393919083  for s =  0.0380859375
# Flow step output with generator type  single_commutator using string  ZZZZZ  gave for s =  0.0380859375   minimal norm  13.688600393919083
#     Found minimum norm =  13.609755398803587  for s =  0.0439453125
# Flow step output with generator type  single_commutator using string  ZZZZ1  gave for s =  0.0439453125   minimal norm  13.609755398803587
#     Found minimum norm =  13.89416235217237  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1Z  gave for s =  0.0498046875   minimal norm  13.89416235217237
#     Found minimum norm =  13.568206756801901  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ11  gave for s =  0.0498046875   minimal norm  13.568206756801901
#     Found minimum norm =  14.074011096907244  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ1ZZ  gave for s =  0.0001953125   minimal norm  14.074011096907244
#     Found minimum norm =  13.710604636249716  for s =  0.0716796875
# Flow step output with generator type  single_commutator using string  ZZ1Z1  gave for s =  0.0716796875   minimal norm  13.710604636249716
#     Found minimum norm =  13.946736169636317  for s =  0.031835937499999994
# Flow step output with generator type  single_commutator using string  ZZ11Z  gave for s =  0.031835937499999994   minimal norm  13.946736169636317
#     Found minimum norm =  13.689224763558125  for s =  0.0419921875
# Flow step output with generator type  single_commutator using string  ZZ111  gave for s =  0.0419921875   minimal norm  13.689224763558125
#     Found minimum norm =  13.894162352172371  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZZ  gave for s =  0.0498046875   minimal norm  13.894162352172371
#     Found minimum norm =  13.549455770195358  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  Z1ZZ1  gave for s =  0.07480468750000001   minimal norm  13.549455770195358
#     Found minimum norm =  13.652482425038578  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z1Z  gave for s =  0.0498046875   minimal norm  13.652482425038578
#     Found minimum norm =  13.697407000201252  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z11  gave for s =  0.0498046875   minimal norm  13.697407000201252
#     Found minimum norm =  13.946736169636317  for s =  0.031835937499999994
# Flow step output with generator type  single_commutator using string  Z11ZZ  gave for s =  0.031835937499999994   minimal norm  13.946736169636317
#     Found minimum norm =  13.600888956857696  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11Z1  gave for s =  0.0498046875   minimal norm  13.600888956857696
#     Found minimum norm =  13.856054688682036  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z111Z  gave for s =  0.0498046875   minimal norm  13.856054688682036
#     Found minimum norm =  13.440420461570488  for s =  0.0693359375
# Flow step output with generator type  single_commutator using string  Z1111  gave for s =  0.0693359375   minimal norm  13.440420461570488
#     Found minimum norm =  13.60975539880359  for s =  0.0439453125
# Flow step output with generator type  single_commutator using string  1ZZZZ  gave for s =  0.0439453125   minimal norm  13.60975539880359
#     Found minimum norm =  13.453610587600513  for s =  0.0568359375
# Flow step output with generator type  single_commutator using string  1ZZZ1  gave for s =  0.0568359375   minimal norm  13.453610587600513
#     Found minimum norm =  13.549455770195356  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  1ZZ1Z  gave for s =  0.07480468750000001   minimal norm  13.549455770195356
#     Found minimum norm =  13.606889256750224  for s =  0.0630859375
# Flow step output with generator type  single_commutator using string  1ZZ11  gave for s =  0.0630859375   minimal norm  13.606889256750224
#     Found minimum norm =  13.710604636249718  for s =  0.0716796875
# Flow step output with generator type  single_commutator using string  1Z1ZZ  gave for s =  0.0716796875   minimal norm  13.710604636249718
#     Found minimum norm =  13.34805005714477  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  1Z1Z1  gave for s =  0.07480468750000001   minimal norm  13.34805005714477
#     Found minimum norm =  13.600888956857698  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11Z  gave for s =  0.0498046875   minimal norm  13.600888956857698
#     Found minimum norm =  13.2068674902834  for s =  0.05722656250000001
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.05722656250000001   minimal norm  13.2068674902834
#     Found minimum norm =  13.568206756801903  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.0498046875   minimal norm  13.568206756801903
#     Found minimum norm =  13.606889256750224  for s =  0.0630859375
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.0630859375   minimal norm  13.606889256750224
#     Found minimum norm =  13.697407000201254  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.0498046875   minimal norm  13.697407000201254
#     Found minimum norm =  13.325958041352306  for s =  0.04941406250000001
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.04941406250000001   minimal norm  13.325958041352306
#     Found minimum norm =  13.689224763558126  for s =  0.0419921875
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.0419921875   minimal norm  13.689224763558126
#     Found minimum norm =  13.206867490283402  for s =  0.05722656250000001
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.05722656250000001   minimal norm  13.206867490283402
#     Found minimum norm =  13.440420461570483  for s =  0.0693359375
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.0693359375   minimal norm  13.440420461570483
#     Found minimum norm =  14.07362400816175  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111  gave for s =  0.0001953125   minimal norm  14.07362400816175
#     Found minimum norm =  12.84118695628909  for s =  0.0087890625
# Found that canonical is better because  12.84118695628909 13.2068674902834
#     Found minimum norm =  12.84118695628909  for s =  0.0087890625
# Flowing forwards with type  canonical
# []
# Flow step  4
#     Found minimum norm =  12.440648763038565  for s =  0.03769531250000001
# Flow step output with generator type  single_commutator using string  ZZZZZ  gave for s =  0.03769531250000001   minimal norm  12.440648763038565
#     Found minimum norm =  12.459915611241202  for s =  0.03886718750000001
# Flow step output with generator type  single_commutator using string  ZZZZ1  gave for s =  0.03886718750000001   minimal norm  12.459915611241202
#     Found minimum norm =  12.811684641634203  for s =  0.0412109375
# Flow step output with generator type  single_commutator using string  ZZZ1Z  gave for s =  0.0412109375   minimal norm  12.811684641634203
#     Found minimum norm =  12.52666034190589  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ11  gave for s =  0.0498046875   minimal norm  12.52666034190589
#     Found minimum norm =  12.842289367667128  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ1ZZ  gave for s =  0.0001953125   minimal norm  12.842289367667128
#     Found minimum norm =  12.633943809410958  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  ZZ1Z1  gave for s =  0.07285156250000001   minimal norm  12.633943809410958
#     Found minimum norm =  12.66861476428402  for s =  0.0322265625
# Flow step output with generator type  single_commutator using string  ZZ11Z  gave for s =  0.0322265625   minimal norm  12.66861476428402
#     Found minimum norm =  12.517380620388634  for s =  0.036523437500000006
# Flow step output with generator type  single_commutator using string  ZZ111  gave for s =  0.036523437500000006   minimal norm  12.517380620388634
#     Found minimum norm =  12.811684641634203  for s =  0.0412109375
# Flow step output with generator type  single_commutator using string  Z1ZZZ  gave for s =  0.0412109375   minimal norm  12.811684641634203
#     Found minimum norm =  12.425741534283693  for s =  0.08105468750000001
# Flow step output with generator type  single_commutator using string  Z1ZZ1  gave for s =  0.08105468750000001   minimal norm  12.425741534283693
#     Found minimum norm =  12.453075301569358  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z1Z  gave for s =  0.0498046875   minimal norm  12.453075301569358
#     Found minimum norm =  12.43680635250651  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z11  gave for s =  0.0498046875   minimal norm  12.43680635250651
#     Found minimum norm =  12.668614764284023  for s =  0.0322265625
# Flow step output with generator type  single_commutator using string  Z11ZZ  gave for s =  0.0322265625   minimal norm  12.668614764284023
#     Found minimum norm =  12.2816813544535  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11Z1  gave for s =  0.0498046875   minimal norm  12.2816813544535
#     Found minimum norm =  12.519294578396678  for s =  0.0630859375
# Flow step output with generator type  single_commutator using string  Z111Z  gave for s =  0.0630859375   minimal norm  12.519294578396678
#     Found minimum norm =  12.33156290694882  for s =  0.06503906250000001
# Flow step output with generator type  single_commutator using string  Z1111  gave for s =  0.06503906250000001   minimal norm  12.33156290694882
#     Found minimum norm =  12.459915611241202  for s =  0.03886718750000001
# Flow step output with generator type  single_commutator using string  1ZZZZ  gave for s =  0.03886718750000001   minimal norm  12.459915611241202
#     Found minimum norm =  12.436301356722133  for s =  0.04941406250000001
# Flow step output with generator type  single_commutator using string  1ZZZ1  gave for s =  0.04941406250000001   minimal norm  12.436301356722133
#     Found minimum norm =  12.425741534283693  for s =  0.08105468750000001
# Flow step output with generator type  single_commutator using string  1ZZ1Z  gave for s =  0.08105468750000001   minimal norm  12.425741534283693
#     Found minimum norm =  12.477623440648793  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  1ZZ11  gave for s =  0.07480468750000001   minimal norm  12.477623440648793
#     Found minimum norm =  12.633943809410958  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  1Z1ZZ  gave for s =  0.07285156250000001   minimal norm  12.633943809410958
#     Found minimum norm =  12.187499202960716  for s =  0.07792968750000001
# Flow step output with generator type  single_commutator using string  1Z1Z1  gave for s =  0.07792968750000001   minimal norm  12.187499202960716
#     Found minimum norm =  12.281681354453504  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11Z  gave for s =  0.0498046875   minimal norm  12.281681354453504
#     Found minimum norm =  12.158924656723903  for s =  0.05253906250000001
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.05253906250000001   minimal norm  12.158924656723903
#     Found minimum norm =  12.526660341905892  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.0498046875   minimal norm  12.526660341905892
#     Found minimum norm =  12.477623440648793  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.07480468750000001   minimal norm  12.477623440648793
#     Found minimum norm =  12.43680635250651  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.0498046875   minimal norm  12.43680635250651
#     Found minimum norm =  12.278343015128566  for s =  0.0431640625
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.0431640625   minimal norm  12.278343015128566
#     Found minimum norm =  12.517380620388638  for s =  0.036523437500000006
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.036523437500000006   minimal norm  12.517380620388638
#     Found minimum norm =  12.158924656723904  for s =  0.05253906250000001
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.05253906250000001   minimal norm  12.158924656723904
#     Found minimum norm =  12.331562906948818  for s =  0.06503906250000001
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.06503906250000001   minimal norm  12.331562906948818
#     Found minimum norm =  12.84118695628909  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111  gave for s =  0.0001953125   minimal norm  12.84118695628909
#     Found minimum norm =  12.064910163425932  for s =  0.0064453125000000005
# Found that canonical is better because  12.064910163425932 12.158924656723903
#     Found minimum norm =  12.064910163425932  for s =  0.0064453125000000005
# Flowing forwards with type  canonical
# []
# Flow step  5
#     Found minimum norm =  11.755673107445071  for s =  0.03964843750000001
# Flow step output with generator type  single_commutator using string  ZZZZZ  gave for s =  0.03964843750000001   minimal norm  11.755673107445071
#     Found minimum norm =  11.775167942863801  for s =  0.0392578125
# Flow step output with generator type  single_commutator using string  ZZZZ1  gave for s =  0.0392578125   minimal norm  11.775167942863801
#     Found minimum norm =  12.04922929960809  for s =  0.0427734375
# Flow step output with generator type  single_commutator using string  ZZZ1Z  gave for s =  0.0427734375   minimal norm  12.04922929960809
#     Found minimum norm =  11.858828359813025  for s =  0.0537109375
# Flow step output with generator type  single_commutator using string  ZZZ11  gave for s =  0.0537109375   minimal norm  11.858828359813025
#     Found minimum norm =  12.066124246113436  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ1ZZ  gave for s =  0.0001953125   minimal norm  12.066124246113436
#     Found minimum norm =  11.890735927556388  for s =  0.08105468750000001
# Flow step output with generator type  single_commutator using string  ZZ1Z1  gave for s =  0.08105468750000001   minimal norm  11.890735927556388
#     Found minimum norm =  11.947664974384814  for s =  0.0322265625
# Flow step output with generator type  single_commutator using string  ZZ11Z  gave for s =  0.0322265625   minimal norm  11.947664974384814
#     Found minimum norm =  11.82890570404846  for s =  0.0353515625
# Flow step output with generator type  single_commutator using string  ZZ111  gave for s =  0.0353515625   minimal norm  11.82890570404846
#     Found minimum norm =  12.049229299608088  for s =  0.0427734375
# Flow step output with generator type  single_commutator using string  Z1ZZZ  gave for s =  0.0427734375   minimal norm  12.049229299608088
#     Found minimum norm =  11.754188722866582  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  Z1ZZ1  gave for s =  0.07480468750000001   minimal norm  11.754188722866582
#     Found minimum norm =  11.703658488182198  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z1Z  gave for s =  0.0498046875   minimal norm  11.703658488182198
#     Found minimum norm =  11.642440688733588  for s =  0.06738281250000001
# Flow step output with generator type  single_commutator using string  Z1Z11  gave for s =  0.06738281250000001   minimal norm  11.642440688733588
#     Found minimum norm =  11.947664974384814  for s =  0.0322265625
# Flow step output with generator type  single_commutator using string  Z11ZZ  gave for s =  0.0322265625   minimal norm  11.947664974384814
#     Found minimum norm =  11.477789449215726  for s =  0.06738281250000001
# Flow step output with generator type  single_commutator using string  Z11Z1  gave for s =  0.06738281250000001   minimal norm  11.477789449215726
#     Found minimum norm =  11.610247392636543  for s =  0.0853515625
# Flow step output with generator type  single_commutator using string  Z111Z  gave for s =  0.0853515625   minimal norm  11.610247392636543
#     Found minimum norm =  11.642706032719445  for s =  0.0615234375
# Flow step output with generator type  single_commutator using string  Z1111  gave for s =  0.0615234375   minimal norm  11.642706032719445
#     Found minimum norm =  11.775167942863803  for s =  0.0392578125
# Flow step output with generator type  single_commutator using string  1ZZZZ  gave for s =  0.0392578125   minimal norm  11.775167942863803
#     Found minimum norm =  11.760563381256084  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZ1  gave for s =  0.0498046875   minimal norm  11.760563381256084
#     Found minimum norm =  11.754188722866582  for s =  0.07480468750000001
# Flow step output with generator type  single_commutator using string  1ZZ1Z  gave for s =  0.07480468750000001   minimal norm  11.754188722866582
#     Found minimum norm =  11.761813583223164  for s =  0.08222656250000002
# Flow step output with generator type  single_commutator using string  1ZZ11  gave for s =  0.08222656250000002   minimal norm  11.761813583223164
#     Found minimum norm =  11.890735927556388  for s =  0.08105468750000001
# Flow step output with generator type  single_commutator using string  1Z1ZZ  gave for s =  0.08105468750000001   minimal norm  11.890735927556388
#     Found minimum norm =  11.379407269711702  for s =  0.0849609375
# Flow step output with generator type  single_commutator using string  1Z1Z1  gave for s =  0.0849609375   minimal norm  11.379407269711702
#     Found minimum norm =  11.477789449215726  for s =  0.06738281250000001
# Flow step output with generator type  single_commutator using string  1Z11Z  gave for s =  0.06738281250000001   minimal norm  11.477789449215726
#     Found minimum norm =  11.49239616286847  for s =  0.0576171875
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.0576171875   minimal norm  11.49239616286847
#     Found minimum norm =  11.858828359813025  for s =  0.0537109375
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.0537109375   minimal norm  11.858828359813025
#     Found minimum norm =  11.761813583223162  for s =  0.08222656250000002
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.08222656250000002   minimal norm  11.761813583223162
#     Found minimum norm =  11.64244068873359  for s =  0.06738281250000001
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.06738281250000001   minimal norm  11.64244068873359
#     Found minimum norm =  11.62967491362948  for s =  0.044335937500000006
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.044335937500000006   minimal norm  11.62967491362948
#     Found minimum norm =  11.82890570404846  for s =  0.0353515625
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.0353515625   minimal norm  11.82890570404846
#     Found minimum norm =  11.49239616286847  for s =  0.0576171875
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.0576171875   minimal norm  11.49239616286847
#     Found minimum norm =  11.642706032719445  for s =  0.0615234375
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.0615234375   minimal norm  11.642706032719445
#     Found minimum norm =  12.064910163425932  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111  gave for s =  0.0001953125   minimal norm  12.064910163425932
#     Found minimum norm =  11.524105597988001  for s =  0.005664062500000001
# Found that canonical is worse because  11.524105597988001 11.379407269711702
#     Found minimum norm =  11.379407269711702  for s =  0.0849609375
# Flowing forwards with type  single_commutator
# []
# Flow step  6
#     Found minimum norm =  11.070993385887142  for s =  0.03574218750000001
# Flow step output with generator type  single_commutator using string  ZZZZZ  gave for s =  0.03574218750000001   minimal norm  11.070993385887142
#     Found minimum norm =  10.873373522862996  for s =  0.0294921875
# Flow step output with generator type  single_commutator using string  ZZZZ1  gave for s =  0.0294921875   minimal norm  10.873373522862996
#     Found minimum norm =  11.341649578035803  for s =  0.0134765625
# Flow step output with generator type  single_commutator using string  ZZZ1Z  gave for s =  0.0134765625   minimal norm  11.341649578035803
#     Found minimum norm =  11.077656374329493  for s =  0.032617187500000006
# Flow step output with generator type  single_commutator using string  ZZZ11  gave for s =  0.032617187500000006   minimal norm  11.077656374329493
#     Found minimum norm =  11.283391767660044  for s =  0.015039062499999999
# Flow step output with generator type  single_commutator using string  ZZ1ZZ  gave for s =  0.015039062499999999   minimal norm  11.283391767660044
#     Found minimum norm =  11.38022356118606  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ1Z1  gave for s =  0.0001953125   minimal norm  11.38022356118606
#     Found minimum norm =  11.153721621489964  for s =  0.025585937500000003
# Flow step output with generator type  single_commutator using string  ZZ11Z  gave for s =  0.025585937500000003   minimal norm  11.153721621489964
#     Found minimum norm =  10.884773893579927  for s =  0.036523437500000006
# Flow step output with generator type  single_commutator using string  ZZ111  gave for s =  0.036523437500000006   minimal norm  10.884773893579927
#     Found minimum norm =  11.341649578035804  for s =  0.0134765625
# Flow step output with generator type  single_commutator using string  Z1ZZZ  gave for s =  0.0134765625   minimal norm  11.341649578035804
#     Found minimum norm =  11.205306996616484  for s =  0.024804687500000002
# Flow step output with generator type  single_commutator using string  Z1ZZ1  gave for s =  0.024804687500000002   minimal norm  11.205306996616484
#     Found minimum norm =  11.162754108989256  for s =  0.019726562500000003
# Flow step output with generator type  single_commutator using string  Z1Z1Z  gave for s =  0.019726562500000003   minimal norm  11.162754108989256
#     Found minimum norm =  11.060295348793023  for s =  0.044335937500000006
# Flow step output with generator type  single_commutator using string  Z1Z11  gave for s =  0.044335937500000006   minimal norm  11.060295348793023
#     Found minimum norm =  11.153721621489966  for s =  0.025585937500000003
# Flow step output with generator type  single_commutator using string  Z11ZZ  gave for s =  0.025585937500000003   minimal norm  11.153721621489966
#     Found minimum norm =  11.256102037719048  for s =  0.020898437500000002
# Flow step output with generator type  single_commutator using string  Z11Z1  gave for s =  0.020898437500000002   minimal norm  11.256102037719048
#     Found minimum norm =  11.306978583287247  for s =  0.0244140625
# Flow step output with generator type  single_commutator using string  Z111Z  gave for s =  0.0244140625   minimal norm  11.306978583287247
#     Found minimum norm =  10.847372261280707  for s =  0.0314453125
# Flow step output with generator type  single_commutator using string  Z1111  gave for s =  0.0314453125   minimal norm  10.847372261280707
#     Found minimum norm =  10.873373522862996  for s =  0.0294921875
# Flow step output with generator type  single_commutator using string  1ZZZZ  gave for s =  0.0294921875   minimal norm  10.873373522862996
#     Found minimum norm =  11.371584888235697  for s =  0.010351562500000001
# Flow step output with generator type  single_commutator using string  1ZZZ1  gave for s =  0.010351562500000001   minimal norm  11.371584888235697
#     Found minimum norm =  11.20530699661648  for s =  0.024804687500000002
# Flow step output with generator type  single_commutator using string  1ZZ1Z  gave for s =  0.024804687500000002   minimal norm  11.20530699661648
#     Found minimum norm =  11.300103019467738  for s =  0.018554687500000003
# Flow step output with generator type  single_commutator using string  1ZZ11  gave for s =  0.018554687500000003   minimal norm  11.300103019467738
#     Found minimum norm =  11.380223561186062  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z1ZZ  gave for s =  0.0001953125   minimal norm  11.380223561186062
#     Found minimum norm =  10.932245589379274  for s =  0.0283203125
# Flow step output with generator type  single_commutator using string  1Z1Z1  gave for s =  0.0283203125   minimal norm  10.932245589379274
#     Found minimum norm =  11.25610203771905  for s =  0.020898437500000002
# Flow step output with generator type  single_commutator using string  1Z11Z  gave for s =  0.020898437500000002   minimal norm  11.25610203771905
#     Found minimum norm =  10.860195399403448  for s =  0.03886718750000001
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.03886718750000001   minimal norm  10.860195399403448
#     Found minimum norm =  11.077656374329498  for s =  0.032617187500000006
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.032617187500000006   minimal norm  11.077656374329498
#     Found minimum norm =  11.30010301946774  for s =  0.018554687500000003
# ...
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.038476562500000006   minimal norm  10.509804854525575
#     Found minimum norm =  10.639837019629718  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.0001953125   minimal norm  10.639837019629718
#     Found minimum norm =  10.380555708744337  for s =  0.0716796875
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.0716796875   minimal norm  10.380555708744337
#     Found minimum norm =  10.322362069486708  for s =  0.04941406250000001
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.04941406250000001   minimal norm  10.322362069486708
#     Found minimum norm =  10.174628275782842  for s =  0.0634765625
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.0634765625   minimal norm  10.174628275782842
#     Found minimum norm =  10.252652674358982  for s =  0.0654296875
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.0654296875   minimal norm  10.252652674358982
#     Found minimum norm =  10.16821203646668  for s =  0.054101562500000006
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.054101562500000006   minimal norm  10.16821203646668
#     Found minimum norm =  10.63934107808478  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111  gave for s =  0.0001953125   minimal norm  10.63934107808478
#     Found minimum norm =  10.17167723137851  for s =  0.005664062500000001
# Found that canonical is worse because  10.17167723137851 10.16821203646668
#     Found minimum norm =  10.16821203646668  for s =  0.054101562500000006
# Flowing forwards with type  single_commutator
# []
# Flow step  8
#     Found minimum norm =  9.893999269636103  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZZ  gave for s =  0.0498046875   minimal norm  9.893999269636103
#     Found minimum norm =  9.883260496190063  for s =  0.03574218750000001
# Flow step output with generator type  single_commutator using string  ZZZZ1  gave for s =  0.03574218750000001   minimal norm  9.883260496190063
#     Found minimum norm =  10.158948446996686  for s =  0.0119140625
# Flow step output with generator type  single_commutator using string  ZZZ1Z  gave for s =  0.0119140625   minimal norm  10.158948446996686
#     Found minimum norm =  10.113810659638782  for s =  0.019335937500000004
# Flow step output with generator type  single_commutator using string  ZZZ11  gave for s =  0.019335937500000004   minimal norm  10.113810659638782
#     Found minimum norm =  10.168276602066056  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ1ZZ  gave for s =  0.0001953125   minimal norm  10.168276602066056
#     Found minimum norm =  10.169205758883507  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ1Z1  gave for s =  0.0001953125   minimal norm  10.169205758883507
#     Found minimum norm =  10.123878509352982  for s =  0.0181640625
# Flow step output with generator type  single_commutator using string  ZZ11Z  gave for s =  0.0181640625   minimal norm  10.123878509352982
#     Found minimum norm =  9.85915717148064  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ111  gave for s =  0.0498046875   minimal norm  9.85915717148064
#     Found minimum norm =  10.168119411008314  for s =  0.0009765625
# Flow step output with generator type  single_commutator using string  Z1ZZZ  gave for s =  0.0009765625   minimal norm  10.168119411008314
#     Found minimum norm =  10.145462438440784  for s =  0.014257812500000001
# Flow step output with generator type  single_commutator using string  Z1ZZ1  gave for s =  0.014257812500000001   minimal norm  10.145462438440784
#     Found minimum norm =  10.088213369267706  for s =  0.016992187500000002
# Flow step output with generator type  single_commutator using string  Z1Z1Z  gave for s =  0.016992187500000002   minimal norm  10.088213369267706
#     Found minimum norm =  10.017137098708641  for s =  0.0693359375
# Flow step output with generator type  single_commutator using string  Z1Z11  gave for s =  0.0693359375   minimal norm  10.017137098708641
#     Found minimum norm =  10.112868858059285  for s =  0.020507812500000003
# Flow step output with generator type  single_commutator using string  Z11ZZ  gave for s =  0.020507812500000003   minimal norm  10.112868858059285
#     Found minimum norm =  10.164795639594097  for s =  0.0076171875
# Flow step output with generator type  single_commutator using string  Z11Z1  gave for s =  0.0076171875   minimal norm  10.164795639594097
#     Found minimum norm =  10.168252671744478  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  Z111Z  gave for s =  0.0001953125   minimal norm  10.168252671744478
#     Found minimum norm =  9.958355499420906  for s =  0.0283203125
# Flow step output with generator type  single_commutator using string  Z1111  gave for s =  0.0283203125   minimal norm  9.958355499420906
#     Found minimum norm =  9.851712476405051  for s =  0.03574218750000001
# Flow step output with generator type  single_commutator using string  1ZZZZ  gave for s =  0.03574218750000001   minimal norm  9.851712476405051
#     Found minimum norm =  10.136965697689877  for s =  0.0353515625
# Flow step output with generator type  single_commutator using string  1ZZZ1  gave for s =  0.0353515625   minimal norm  10.136965697689877
#     Found minimum norm =  10.070070853986278  for s =  0.0283203125
# Flow step output with generator type  single_commutator using string  1ZZ1Z  gave for s =  0.0283203125   minimal norm  10.070070853986278
#     Found minimum norm =  10.16812400051477  for s =  0.0009765625
# Flow step output with generator type  single_commutator using string  1ZZ11  gave for s =  0.0009765625   minimal norm  10.16812400051477
#     Found minimum norm =  10.169073531338457  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z1ZZ  gave for s =  0.0001953125   minimal norm  10.169073531338457
#     Found minimum norm =  9.98391392382726  for s =  0.029882812499999998
# Flow step output with generator type  single_commutator using string  1Z1Z1  gave for s =  0.029882812499999998   minimal norm  9.98391392382726
#     Found minimum norm =  10.133726783525526  for s =  0.020507812500000003
# Flow step output with generator type  single_commutator using string  1Z11Z  gave for s =  0.020507812500000003   minimal norm  10.133726783525526
#     Found minimum norm =  9.856565511341287  for s =  0.046289062500000006
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.046289062500000006   minimal norm  9.856565511341287
#     Found minimum norm =  10.021935979123255  for s =  0.0314453125
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.0314453125   minimal norm  10.021935979123255
#     Found minimum norm =  10.168344474936607  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.0001953125   minimal norm  10.168344474936607
#     Found minimum norm =  9.950452359018161  for s =  0.061914062500000006
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.061914062500000006   minimal norm  9.950452359018161
#     Found minimum norm =  9.772995971955018  for s =  0.038476562500000006
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.038476562500000006   minimal norm  9.772995971955018
#     Found minimum norm =  9.634347888778585  for s =  0.055273437499999994
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.055273437499999994   minimal norm  9.634347888778585
#     Found minimum norm =  9.821614815362066  for s =  0.048242187500000006
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.048242187500000006   minimal norm  9.821614815362066
#     Found minimum norm =  9.678908587517157  for s =  0.0412109375
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.0412109375   minimal norm  9.678908587517157
#     Found minimum norm =  10.16821203646668  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111  gave for s =  0.0001953125   minimal norm  10.16821203646668
#     Found minimum norm =  9.78499328002133  for s =  0.0037109375
# Found that canonical is worse because  9.78499328002133 9.634347888778585
#     Found minimum norm =  9.634347888778585  for s =  0.055273437499999994
# Flowing forwards with type  single_commutator
# []
# Flow step  9
#     Found minimum norm =  9.455893828486408  for s =  0.0466796875
# Flow step output with generator type  single_commutator using string  ZZZZZ  gave for s =  0.0466796875   minimal norm  9.455893828486408
#     Found minimum norm =  9.341930421265221  for s =  0.0361328125
# Flow step output with generator type  single_commutator using string  ZZZZ1  gave for s =  0.0361328125   minimal norm  9.341930421265221
#     Found minimum norm =  9.634458271592006  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZZ1Z  gave for s =  0.0001953125   minimal norm  9.634458271592006
#     Found minimum norm =  9.565511699654722  for s =  0.017773437500000003
# Flow step output with generator type  single_commutator using string  ZZZ11  gave for s =  0.017773437500000003   minimal norm  9.565511699654722
#     Found minimum norm =  9.630521312727888  for s =  0.0044921875000000005
# Flow step output with generator type  single_commutator using string  ZZ1ZZ  gave for s =  0.0044921875000000005   minimal norm  9.630521312727888
#     Found minimum norm =  9.634982231007688  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  ZZ1Z1  gave for s =  0.0001953125   minimal norm  9.634982231007688
#     Found minimum norm =  9.505451753745476  for s =  0.0271484375
# Flow step output with generator type  single_commutator using string  ZZ11Z  gave for s =  0.0271484375   minimal norm  9.505451753745476
#     Found minimum norm =  9.414172207451157  for s =  0.0431640625
# Flow step output with generator type  single_commutator using string  ZZ111  gave for s =  0.0431640625   minimal norm  9.414172207451157
#     Found minimum norm =  9.577416099986536  for s =  0.019335937500000004
# Flow step output with generator type  single_commutator using string  Z1ZZZ  gave for s =  0.019335937500000004   minimal norm  9.577416099986536
#     Found minimum norm =  9.625681577386601  for s =  0.008398437500000001
# Flow step output with generator type  single_commutator using string  Z1ZZ1  gave for s =  0.008398437500000001   minimal norm  9.625681577386601
#     Found minimum norm =  9.50486534917288  for s =  0.022851562500000002
# Flow step output with generator type  single_commutator using string  Z1Z1Z  gave for s =  0.022851562500000002   minimal norm  9.50486534917288
#     Found minimum norm =  9.56210102628467  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z11  gave for s =  0.0498046875   minimal norm  9.56210102628467
#     Found minimum norm =  9.610295855871131  for s =  0.015039062499999999
# Flow step output with generator type  single_commutator using string  Z11ZZ  gave for s =  0.015039062499999999   minimal norm  9.610295855871131
#     Found minimum norm =  9.557111346433874  for s =  0.0236328125
# Flow step output with generator type  single_commutator using string  Z11Z1  gave for s =  0.0236328125   minimal norm  9.557111346433874
#     Found minimum norm =  9.633841134565591  for s =  0.0060546875
# Flow step output with generator type  single_commutator using string  Z111Z  gave for s =  0.0060546875   minimal norm  9.633841134565591
#     Found minimum norm =  9.324047633978031  for s =  0.034570312500000006
# Flow step output with generator type  single_commutator using string  Z1111  gave for s =  0.034570312500000006   minimal norm  9.324047633978031
#     Found minimum norm =  9.332179500025811  for s =  0.0349609375
# Flow step output with generator type  single_commutator using string  1ZZZZ  gave for s =  0.0349609375   minimal norm  9.332179500025811
#     Found minimum norm =  9.614106575613887  for s =  0.022851562500000002
# Flow step output with generator type  single_commutator using string  1ZZZ1  gave for s =  0.022851562500000002   minimal norm  9.614106575613887
#     Found minimum norm =  9.546749552543726  for s =  0.0240234375
# Flow step output with generator type  single_commutator using string  1ZZ1Z  gave for s =  0.0240234375   minimal norm  9.546749552543726
#     Found minimum norm =  9.634995436878249  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZ11  gave for s =  0.0001953125   minimal norm  9.634995436878249
#     Found minimum norm =  9.635390449097919  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z1ZZ  gave for s =  0.0001953125   minimal norm  9.635390449097919
#     Found minimum norm =  9.369521625580617  for s =  0.0341796875
# Flow step output with generator type  single_commutator using string  1Z1Z1  gave for s =  0.0341796875   minimal norm  9.369521625580617
#     Found minimum norm =  9.634428654453407  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1Z11Z  gave for s =  0.0001953125   minimal norm  9.634428654453407
#     Found minimum norm =  9.300405869273215  for s =  0.04082031250000001
# Flow step output with generator type  single_commutator using string  1Z111  gave for s =  0.04082031250000001   minimal norm  9.300405869273215
#     Found minimum norm =  9.600461205193088  for s =  0.017773437500000003
# Flow step output with generator type  single_commutator using string  11ZZZ  gave for s =  0.017773437500000003   minimal norm  9.600461205193088
#     Found minimum norm =  9.626726432217437  for s =  0.0072265625
# Flow step output with generator type  single_commutator using string  11ZZ1  gave for s =  0.0072265625   minimal norm  9.626726432217437
#     Found minimum norm =  9.579893595170018  for s =  0.0353515625
# Flow step output with generator type  single_commutator using string  11Z1Z  gave for s =  0.0353515625   minimal norm  9.579893595170018
#     Found minimum norm =  9.10866746157777  for s =  0.0427734375
# Flow step output with generator type  single_commutator using string  11Z11  gave for s =  0.0427734375   minimal norm  9.10866746157777
#     Found minimum norm =  9.550195189008228  for s =  0.0212890625
# Flow step output with generator type  single_commutator using string  111ZZ  gave for s =  0.0212890625   minimal norm  9.550195189008228
#     Found minimum norm =  9.50491378130754  for s =  0.0361328125
# Flow step output with generator type  single_commutator using string  111Z1  gave for s =  0.0361328125   minimal norm  9.50491378130754
#     Found minimum norm =  9.200525912242373  for s =  0.0419921875
# Flow step output with generator type  single_commutator using string  1111Z  gave for s =  0.0419921875   minimal norm  9.200525912242373
#     Found minimum norm =  9.634347888778585  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  11111  gave for s =  0.0001953125   minimal norm  9.634347888778585
#     Found minimum norm =  9.237297193907926  for s =  0.0037109375
# Found that canonical is worse because  9.237297193907926 9.10866746157777
#     Found minimum norm =  9.10866746157777  for s =  0.0427734375
# Flowing forwards with type  single_commutator
# []

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

def plot_iteration_results(  ):
    flow.run_param_rc(fontsize=19)
    flow_results = flow.flow_outputs

    f=plt.figure(figsize = ( 8,7 ))
    n=1
    ax_a = f.add_subplot(1,n,1)
    norms = flow_results['minimal_norm_sigma_H_s']
    x_axis = [sum(flow_results['minimizing_flow_step'][:k])for k in range( 1, len(flow_results['minimizing_flow_step'])+1)]

    plt.plot( x_axis, norms, '-o')   
    N = 10
    k=0
    for xy in zip([x+.01 for x in x_axis[0:N]], 
                  [n - 0.03 for n in norms[0:N]]):  
        if k == 0 or k == 9 or k == 8:
            a=1
        else:
            plt.annotate('k = ' + str(k) + ': ' + flow_results['strs_of_minimizer_Z'][k-1], xy=xy, textcoords='data', fontsize=17)
        k=k+1
    
    plt.annotate('k = ' + str(k) + ': ' + flow_results['strs_of_minimizer_Z'][k-1], 
                 xy=(x_axis[-1]-.11,norms[-1]-.7), textcoords='data', fontsize=17)

    plt.annotate('k = ' + str(k-1) + ': ' + flow_results['strs_of_minimizer_Z'][k-2], 
                 xy=(x_axis[k-1]-.11,norms[k-1]-.5), textcoords='data', fontsize=17)
    plt.annotate('k = ' + str(k-2) + ': ' + flow_results['strs_of_minimizer_Z'][k-3], 
                 xy=(x_axis[k-2]+.021,norms[k-2]-.13), textcoords='data', fontsize=17)
    x_labels_rounded = [ round(x, 2 ) for x in x_axis ]
    x_labels_rounded = [0] + x_labels_rounded[1:9]  + [max(x_labels_rounded)]
    x_labels_rounded.pop(2)
    x_labels_rounded.pop(2)
    x_labels_rounded.pop(-2)
    x_labels_rounded.pop(3)
    
    plt.xticks(x_labels_rounded)
    y_labels_rounded = [ round(y, 1 ) for y in norms ]
    y_labels_rounded = y_labels_rounded[0:5] + [min(y_labels_rounded)]
    plt.yticks(y_labels_rounded)
    plt.grid()
    plt.xlabel(r'Total DBI duration $\ell$')
    plt.ylabel(r'$\vert\vert\sigma(\hat H_k)\vert\vert_{\mathrm{HS}}$')
    plt.title(r'Diagonalization DBI with $\hat D_k = Z_{\mu(k)}$ or $\hat D_k =\Delta(\hat H_k)$')
    a =-.1
    b = 1.05
 
    colorbar_max = max([np.max(H_TLFIM),np.max(flow_results['optimally_flowed_H'][-1]),
                        np.max(flow_results['optimally_flowed_H'][2])])   
    colorbar_min = min([np.min(H_TLFIM),np.min(flow_results['optimally_flowed_H'][-1]),
                        np.min(flow_results['optimally_flowed_H'][2])])
    axin1 = ax_a.inset_axes([0.2,.7, 0.31, 0.27])
    inset1 = axin1.imshow( H_TLFIM, cmap='RdBu' )
    divider1 = make_axes_locatable(axin1)
    div_ax = divider1.append_axes("right", size="10%", pad=0.05)
    cbar1 = plt.colorbar(inset1, cax = div_ax )
    
    range_plot = np.max( np.abs( H_TLFIM ) )
#     cbar1.set_clim( -range_plot, range_plot )
    axin1.set_yticks(range(2**L))  
    axin1.set_xticklabels([1]+['']*(2**L-2)+[2**L])
    axin1.set_yticklabels([1]+['']*(2**L-2)+[2**L])
    axin1.set_xticks(range(2**L))
    ax_a.annotate(' ',
            xy=(x_axis[0]+.01, norms[0]),  # theta, radius
            xytext=(0.24, 0.81),    # fraction, fraction
            textcoords='figure fraction',
            arrowprops=dict(facecolor='gray', shrink=0.01),
            horizontalalignment='left',
            verticalalignment='bottom')
#     axin1.set_xlabel(r'$j$')
#     axin1.set_title(r'$k$')
#     axin1.grid()
    axin2 = ax_a.inset_axes([0.62,.32, 0.31, 0.27])
    inset2 = axin2.imshow(flow_results['optimally_flowed_H'][-1], cmap='RdBu')

    divider2 = make_axes_locatable(axin2)
    div_ax2 = divider2.append_axes("right", size="10%", pad=0.05)
    ticks = [-colorbar_max,0,colorbar_max]
    ticks = [ round(t,1) for t in ticks]
    cbar2 = plt.colorbar(inset2, cax = div_ax2 )
    inset2.set_clim(-colorbar_max,colorbar_max)
  
    ax_a.annotate(' ',
        xy=(x_axis[-1], 11.4),  # theta, radius
        xytext=(.95, .3),    # fraction, fraction
        textcoords='axes fraction',
        arrowprops=dict(facecolor='gray', shrink=0.05),
        horizontalalignment='left',
        verticalalignment='bottom')
    
    axin3 = ax_a.inset_axes([0.62,.7, 0.31, 0.27])
    inset3 = axin3.imshow(flow_results['optimally_flowed_H'][2], cmap='RdBu')

    divider3 = make_axes_locatable(axin3)
    div_ax3 = divider3.append_axes("right", size="10%", pad=0.05)
    cbar2 = plt.colorbar(inset3, cax = div_ax3 )
    inset3.set_clim(-colorbar_max,colorbar_max)
    ax_a.annotate(' ',
        xy=(x_axis[2]+.01, norms[2]+.6),  # theta, radius
        xytext=(0.65, 0.67),    # fraction, fraction
        textcoords='axes fraction',
        arrowprops=dict(facecolor='gray', shrink=0.05),
        horizontalalignment='left',
        verticalalignment='bottom')
    axin2.set_yticks(range(2**L))  
    axin2.set_xticklabels([1]+['']*(2**L-2)+[2**L])
    axin2.set_yticklabels([1]+['']*(2**L-2)+[2**L])
    axin2.set_xticks(range(2**L))    
    axin3.set_yticks(range(2**L))  
    axin3.set_xticklabels([1]+['']*(2**L-2)+[2**L])
    axin3.set_yticklabels([1]+['']*(2**L-2)+[2**L])
    axin3.set_xticks(range(2**L))
    chosen_steps = [1,2]
    plt.savefig( 'figs/mix_L_'+str(L)+'.pdf')
    
plot_iteration_results()
# Out:
# /tmp/ipykernel_90905/568403580.py:62: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axin1.set_xticklabels([1]+['']*(2**L-2)+[2**L])
# /tmp/ipykernel_90905/568403580.py:108: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axin2.set_xticklabels([1]+['']*(2**L-2)+[2**L])
# /tmp/ipykernel_90905/568403580.py:112: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axin3.set_xticklabels([1]+['']*(2**L-2)+[2**L])

# %% [markdown]
# #### Some additional uses of the class

# %% [markdown]
# The stored observables are these:

# %%
flow.flow_outputs.keys()

# %% [markdown]
# (some of these are empty)
# The Hamiltonians are stored as optimally flowed in the sense that the flow step duration was optimized by a brute force grid search or local binary search.
# The first element is the initial Hamiltonin so

# %%
len(flow.flow_outputs['optimally_flowed_H'])

# %% [markdown]
# we get 1 + nmb of steps

# %% [markdown]
# #### Simple plot for debugging

# %%
H = flow.flow_outputs['final_flowed_H'][-1]

plt.figure()
plt.subplot(121)
plt.imshow(abs(H_TLFIM), cmap='RdBu')
plt.colorbar()
plt.subplot(122)
plt.imshow(abs(H), cmap='RdBu')
plt.colorbar()
plt.tight_layout()

# %% [markdown]
# This variable stores or strings that have been tested in each step

# %%
print(flow.flow_outputs['all_Z_names'])

# %% [markdown]
# and these are the strings that gave the optimal generator to decrease the norm of the off-diagonal restriction

# %%
flow.flow_outputs['strs_of_minimizer_Z']

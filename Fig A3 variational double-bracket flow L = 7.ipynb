# %%
from simple_exact_diagonalization_routines.local_matrix_class import *
from scipy.linalg import expm
import matplotlib.pyplot as plt
import time


# System size
L = 7

# Create objects of Pauli operators
X = X_class(L)
Y = Y_class(L)
Z = Z_class(L)
S_plus = S_plus_class(L)
S_minus = S_minus_class(L)

# Trivial initialization of the right size matrix
hamiltonian_name = "TLFIM_L_" +str(L)
H_TLFIM = 0*np.eye( 2**L ) 

for x in range(L-1):
    H_TLFIM = H_TLFIM + 2*X.at(x+1).dot(X.at(x+2)) + Z.at(x+1)+ X.at(x+1)
H_TLFIM = H_TLFIM + Z.at(L)    + X.at(L) +X.at(1).dot(X.at(L))

# %%
from class_double_bracket_flow import *


flow = double_bracket_flow( H_TLFIM )

flow.please_be_exhaustively_verbose = False
flow.please_be_verbose = True

flow.nmb_search_points_minimizing_s_search = 10
flow.flow_step_max = 0.2
flow.nmb_flow_steps = 10
flow.please_use_binary_search =  True
flow.please_compute_observables = False

#flow.flow_forwards( )
flow.flow_via_best_Z_search( please_also_check_canonical_bracket = True )

flow.show_flow_forwards_results()
# Out:
# Flow step  0
# Found minimum norm =  62.06081241669935  for s =  0.0833984375
# Flow step output with generator type  single_commutator using string  ZZZZZZZ  gave for s =  0.0833984375   minimal norm  62.06081241669935
# Found minimum norm =  61.10390728073946  for s =  0.0646484375
# Flow step output with generator type  single_commutator using string  ZZZZZZ1  gave for s =  0.0646484375   minimal norm  61.10390728073946
# Found minimum norm =  60.37199045198094  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZZ1Z  gave for s =  0.0498046875   minimal norm  60.37199045198094
# Found minimum norm =  61.040895598884426  for s =  0.07207031250000001
# Flow step output with generator type  single_commutator using string  ZZZZZ11  gave for s =  0.07207031250000001   minimal norm  61.040895598884426
# Found minimum norm =  60.37199045198095  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZ1ZZ  gave for s =  0.0498046875   minimal norm  60.37199045198095
# Found minimum norm =  58.75866605119189  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZ1Z1  gave for s =  0.0498046875   minimal norm  58.75866605119189
# Found minimum norm =  59.87035244695531  for s =  0.0646484375
# Flow step output with generator type  single_commutator using string  ZZZZ11Z  gave for s =  0.0646484375   minimal norm  59.87035244695531
# Found minimum norm =  61.40767797171202  for s =  0.07597656250000001
# Flow step output with generator type  single_commutator using string  ZZZZ111  gave for s =  0.07597656250000001   minimal norm  61.40767797171202
# Found minimum norm =  60.37199045198094  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1ZZZ  gave for s =  0.0498046875   minimal norm  60.37199045198094
# Found minimum norm =  58.85134063745005  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1ZZ1  gave for s =  0.0498046875   minimal norm  58.85134063745005
# Found minimum norm =  57.58719687617972  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1Z1Z  gave for s =  0.0498046875   minimal norm  57.58719687617972
# Found minimum norm =  59.062426931027744  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1Z11  gave for s =  0.0498046875   minimal norm  59.062426931027744
# Found minimum norm =  59.8703524469553  for s =  0.0646484375
# Flow step output with generator type  single_commutator using string  ZZZ11ZZ  gave for s =  0.0646484375   minimal norm  59.8703524469553
# Found minimum norm =  58.8217732155  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ11Z1  gave for s =  0.0498046875   minimal norm  58.8217732155
# Found minimum norm =  60.245501922781116  for s =  0.06699218750000001
# Flow step output with generator type  single_commutator using string  ZZZ111Z  gave for s =  0.06699218750000001   minimal norm  60.245501922781116
# Found minimum norm =  61.764062288260355  for s =  0.08066406250000002
# Flow step output with generator type  single_commutator using string  ZZZ1111  gave for s =  0.08066406250000002   minimal norm  61.764062288260355
# Found minimum norm =  60.37199045198095  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZZZ  gave for s =  0.0498046875   minimal norm  60.37199045198095
# Found minimum norm =  58.85134063745005  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZZ1  gave for s =  0.0498046875   minimal norm  58.85134063745005
# Found minimum norm =  57.74912490030422  for s =  0.048242187500000006
# Flow step output with generator type  single_commutator using string  ZZ1ZZ1Z  gave for s =  0.048242187500000006   minimal norm  57.74912490030422
# Found minimum norm =  59.08601334914106  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZ11  gave for s =  0.0498046875   minimal norm  59.08601334914106
# Found minimum norm =  57.5871968761797  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1Z1ZZ  gave for s =  0.0498046875   minimal norm  57.5871968761797
# Found minimum norm =  56.03920799586853  for s =  0.0458984375
# Flow step output with generator type  single_commutator using string  ZZ1Z1Z1  gave for s =  0.0458984375   minimal norm  56.03920799586853
# Found minimum norm =  57.703267242602706  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1Z11Z  gave for s =  0.0498046875   minimal norm  57.703267242602706
# Found minimum norm =  59.52175035579097  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1Z111  gave for s =  0.0498046875   minimal norm  59.52175035579097
# Found minimum norm =  59.8703524469553  for s =  0.0646484375
# Flow step output with generator type  single_commutator using string  ZZ11ZZZ  gave for s =  0.0646484375   minimal norm  59.8703524469553
# Found minimum norm =  58.84545609244266  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ11ZZ1  gave for s =  0.0498046875   minimal norm  58.84545609244266
# Found minimum norm =  57.70326724260269  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ11Z1Z  gave for s =  0.0498046875   minimal norm  57.70326724260269
# Found minimum norm =  58.76372132853426  for s =  0.0587890625
# Flow step output with generator type  single_commutator using string  ZZ11Z11  gave for s =  0.0587890625   minimal norm  58.76372132853426
# Found minimum norm =  60.24550192278112  for s =  0.06699218750000001
# Flow step output with generator type  single_commutator using string  ZZ111ZZ  gave for s =  0.06699218750000001   minimal norm  60.24550192278112
# Found minimum norm =  59.083693595932814  for s =  0.05722656250000001
# Flow step output with generator type  single_commutator using string  ZZ111Z1  gave for s =  0.05722656250000001   minimal norm  59.083693595932814
# Found minimum norm =  60.61260579102087  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  ZZ1111Z  gave for s =  0.0701171875   minimal norm  60.61260579102087
# Found minimum norm =  62.103590059980604  for s =  0.08691406250000001
# Flow step output with generator type  single_commutator using string  ZZ11111  gave for s =  0.08691406250000001   minimal norm  62.103590059980604
# Found minimum norm =  60.37199045198095  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZZZZ  gave for s =  0.0498046875   minimal norm  60.37199045198095
# Found minimum norm =  58.77620659691762  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZZZ1  gave for s =  0.0498046875   minimal norm  58.77620659691762
# Found minimum norm =  57.74912490030423  for s =  0.048242187500000006
# Flow step output with generator type  single_commutator using string  Z1ZZZ1Z  gave for s =  0.048242187500000006   minimal norm  57.74912490030423
# Found minimum norm =  59.0798772916045  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZZ11  gave for s =  0.0498046875   minimal norm  59.0798772916045
# Found minimum norm =  57.74912490030422  for s =  0.048242187500000006
# Flow step output with generator type  single_commutator using string  Z1ZZ1ZZ  gave for s =  0.048242187500000006   minimal norm  57.74912490030422
# Found minimum norm =  56.10727617265463  for s =  0.04550781250000001
# Flow step output with generator type  single_commutator using string  Z1ZZ1Z1  gave for s =  0.04550781250000001   minimal norm  56.10727617265463
# Found minimum norm =  57.727408992463104  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZ11Z  gave for s =  0.0498046875   minimal norm  57.727408992463104
# Found minimum norm =  59.53906609298767  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZ111  gave for s =  0.0498046875   minimal norm  59.53906609298767
# Found minimum norm =  57.58719687617972  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z1ZZZ  gave for s =  0.0498046875   minimal norm  57.58719687617972
# Found minimum norm =  56.052800298593205  for s =  0.0458984375
# Flow step output with generator type  single_commutator using string  Z1Z1ZZ1  gave for s =  0.0458984375   minimal norm  56.052800298593205
# Found minimum norm =  54.84228171251686  for s =  0.04355468750000001
# Flow step output with generator type  single_commutator using string  Z1Z1Z1Z  gave for s =  0.04355468750000001   minimal norm  54.84228171251686
# Found minimum norm =  56.322323273435636  for s =  0.0470703125
# Flow step output with generator type  single_commutator using string  Z1Z1Z11  gave for s =  0.0470703125   minimal norm  56.322323273435636
# Found minimum norm =  57.703267242602706  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z11ZZ  gave for s =  0.0498046875   minimal norm  57.703267242602706
# Found minimum norm =  56.16404853285125  for s =  0.047460937499999994
# Flow step output with generator type  single_commutator using string  Z1Z11Z1  gave for s =  0.047460937499999994   minimal norm  56.16404853285125
# Found minimum norm =  58.15164038807925  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z111Z  gave for s =  0.0498046875   minimal norm  58.15164038807925
# Found minimum norm =  59.974271580478316  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z1111  gave for s =  0.0498046875   minimal norm  59.974271580478316
# Found minimum norm =  59.87035244695531  for s =  0.0646484375
# Flow step output with generator type  single_commutator using string  Z11ZZZZ  gave for s =  0.0646484375   minimal norm  59.87035244695531
# Found minimum norm =  58.83929494839113  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11ZZZ1  gave for s =  0.0498046875   minimal norm  58.83929494839113
# Found minimum norm =  57.727408992463104  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11ZZ1Z  gave for s =  0.0498046875   minimal norm  57.727408992463104
# Found minimum norm =  58.79507271584371  for s =  0.0583984375
# Flow step output with generator type  single_commutator using string  Z11ZZ11  gave for s =  0.0583984375   minimal norm  58.79507271584371
# Found minimum norm =  57.703267242602706  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11Z1ZZ  gave for s =  0.0498046875   minimal norm  57.703267242602706
# Found minimum norm =  56.16404853285124  for s =  0.047460937499999994
# Flow step output with generator type  single_commutator using string  Z11Z1Z1  gave for s =  0.047460937499999994   minimal norm  56.16404853285124
# Found minimum norm =  57.67144867138526  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11Z11Z  gave for s =  0.0498046875   minimal norm  57.67144867138526
# Found minimum norm =  59.13870643885859  for s =  0.0607421875
# Flow step output with generator type  single_commutator using string  Z11Z111  gave for s =  0.0607421875   minimal norm  59.13870643885859
# Found minimum norm =  60.245501922781116  for s =  0.06699218750000001
# Flow step output with generator type  single_commutator using string  Z111ZZZ  gave for s =  0.06699218750000001   minimal norm  60.245501922781116
# Found minimum norm =  59.30288892329753  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z111ZZ1  gave for s =  0.0498046875   minimal norm  59.30288892329753
# Found minimum norm =  58.15164038807925  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z111Z1Z  gave for s =  0.0498046875   minimal norm  58.15164038807925
# Found minimum norm =  59.13870643885859  for s =  0.0607421875
# Flow step output with generator type  single_commutator using string  Z111Z11  gave for s =  0.0607421875   minimal norm  59.13870643885859
# Found minimum norm =  60.61260579102086  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  Z1111ZZ  gave for s =  0.0701171875   minimal norm  60.61260579102086
# Found minimum norm =  59.481342038112295  for s =  0.0587890625
# Flow step output with generator type  single_commutator using string  Z1111Z1  gave for s =  0.0587890625   minimal norm  59.481342038112295
# Found minimum norm =  60.96898834391427  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  Z11111Z  gave for s =  0.07363281250000002   minimal norm  60.96898834391427
# Found minimum norm =  60.10283403932738  for s =  0.08769531250000001
# Flow step output with generator type  single_commutator using string  Z111111  gave for s =  0.08769531250000001   minimal norm  60.10283403932738
# Found minimum norm =  61.103907280739456  for s =  0.0646484375
# Flow step output with generator type  single_commutator using string  1ZZZZZZ  gave for s =  0.0646484375   minimal norm  61.103907280739456
# Found minimum norm =  59.87035244695531  for s =  0.0646484375
# Flow step output with generator type  single_commutator using string  1ZZZZZ1  gave for s =  0.0646484375   minimal norm  59.87035244695531
# Found minimum norm =  58.776206596917625  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZZ1Z  gave for s =  0.0498046875   minimal norm  58.776206596917625
# Found minimum norm =  60.24550192278114  for s =  0.06699218750000001
# Flow step output with generator type  single_commutator using string  1ZZZZ11  gave for s =  0.06699218750000001   minimal norm  60.24550192278114
# Found minimum norm =  58.851340637450036  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZ1ZZ  gave for s =  0.0498046875   minimal norm  58.851340637450036
# Found minimum norm =  57.7032672426027  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZ1Z1  gave for s =  0.0498046875   minimal norm  57.7032672426027
# Found minimum norm =  58.839294948391114  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZ11Z  gave for s =  0.0498046875   minimal norm  58.839294948391114
# Found minimum norm =  60.61260579102086  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  1ZZZ111  gave for s =  0.0701171875   minimal norm  60.61260579102086
# Found minimum norm =  58.851340637450036  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1ZZZ  gave for s =  0.0498046875   minimal norm  58.851340637450036
# Found minimum norm =  57.7274089924631  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1ZZ1  gave for s =  0.0498046875   minimal norm  57.7274089924631
# Found minimum norm =  56.052800298593226  for s =  0.0458984375
# Flow step output with generator type  single_commutator using string  1ZZ1Z1Z  gave for s =  0.0458984375   minimal norm  56.052800298593226
# Found minimum norm =  58.15164038807925  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1Z11  gave for s =  0.0498046875   minimal norm  58.15164038807925
# Found minimum norm =  58.84545609244265  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ11ZZ  gave for s =  0.0498046875   minimal norm  58.84545609244265
# Found minimum norm =  57.67144867138527  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ11Z1  gave for s =  0.0498046875   minimal norm  57.67144867138527
# Found minimum norm =  59.30288892329753  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ111Z  gave for s =  0.0498046875   minimal norm  59.30288892329753
# Found minimum norm =  60.96898834391428  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  1ZZ1111  gave for s =  0.07363281250000002   minimal norm  60.96898834391428
# Found minimum norm =  58.75866605119188  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1ZZZZ  gave for s =  0.0498046875   minimal norm  58.75866605119188
# Found minimum norm =  57.7032672426027  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1ZZZ1  gave for s =  0.0498046875   minimal norm  57.7032672426027
# Found minimum norm =  56.10727617265463  for s =  0.04550781250000001
# Flow step output with generator type  single_commutator using string  1Z1ZZ1Z  gave for s =  0.04550781250000001   minimal norm  56.10727617265463
# Found minimum norm =  58.15164038807925  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1ZZ11  gave for s =  0.0498046875   minimal norm  58.15164038807925
# Found minimum norm =  56.039207995868544  for s =  0.0458984375
# Flow step output with generator type  single_commutator using string  1Z1Z1ZZ  gave for s =  0.0458984375   minimal norm  56.039207995868544
# Found minimum norm =  54.97598893211592  for s =  0.04472656250000001
# Flow step output with generator type  single_commutator using string  1Z1Z1Z1  gave for s =  0.04472656250000001   minimal norm  54.97598893211592
# Found minimum norm =  56.16404853285125  for s =  0.047460937499999994
# Flow step output with generator type  single_commutator using string  1Z1Z11Z  gave for s =  0.047460937499999994   minimal norm  56.16404853285125
# Found minimum norm =  58.58221190114321  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1Z111  gave for s =  0.0498046875   minimal norm  58.58221190114321
# Found minimum norm =  58.82177321549999  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11ZZZ  gave for s =  0.0498046875   minimal norm  58.82177321549999
# Found minimum norm =  57.67144867138526  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11ZZ1  gave for s =  0.0498046875   minimal norm  57.67144867138526
# Found minimum norm =  56.164048532851254  for s =  0.047460937499999994
# Flow step output with generator type  single_commutator using string  1Z11Z1Z  gave for s =  0.047460937499999994   minimal norm  56.164048532851254
# Found minimum norm =  58.106485918184916  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11Z11  gave for s =  0.0498046875   minimal norm  58.106485918184916
# Found minimum norm =  59.08369359593282  for s =  0.05722656250000001
# Flow step output with generator type  single_commutator using string  1Z111ZZ  gave for s =  0.05722656250000001   minimal norm  59.08369359593282
# Found minimum norm =  58.106485918184916  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z111Z1  gave for s =  0.0498046875   minimal norm  58.106485918184916
# Found minimum norm =  59.4813420381123  for s =  0.0587890625
# Flow step output with generator type  single_commutator using string  1Z1111Z  gave for s =  0.0587890625   minimal norm  59.4813420381123
# Found minimum norm =  58.456460345982165  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  1Z11111  gave for s =  0.07285156250000001   minimal norm  58.456460345982165
# Found minimum norm =  61.040895598884426  for s =  0.07207031250000001
# Flow step output with generator type  single_commutator using string  11ZZZZZ  gave for s =  0.07207031250000001   minimal norm  61.040895598884426
# Found minimum norm =  60.24550192278113  for s =  0.06699218750000001
# Flow step output with generator type  single_commutator using string  11ZZZZ1  gave for s =  0.06699218750000001   minimal norm  60.24550192278113
# Found minimum norm =  59.0798772916045  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZZ1Z  gave for s =  0.0498046875   minimal norm  59.0798772916045
# Found minimum norm =  60.612605791020854  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  11ZZZ11  gave for s =  0.0701171875   minimal norm  60.612605791020854
# Found minimum norm =  59.08601334914107  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZ1ZZ  gave for s =  0.0498046875   minimal norm  59.08601334914107
# Found minimum norm =  58.15164038807925  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZ1Z1  gave for s =  0.0498046875   minimal norm  58.15164038807925
# Found minimum norm =  58.79507271584372  for s =  0.0583984375
# Flow step output with generator type  single_commutator using string  11ZZ11Z  gave for s =  0.0583984375   minimal norm  58.79507271584372
# Found minimum norm =  60.96898834391428  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  11ZZ111  gave for s =  0.07363281250000002   minimal norm  60.96898834391428
# Found minimum norm =  59.062426931027744  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11Z1ZZZ  gave for s =  0.0498046875   minimal norm  59.062426931027744
# Found minimum norm =  58.15164038807925  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11Z1ZZ1  gave for s =  0.0498046875   minimal norm  58.15164038807925
# Found minimum norm =  56.322323273435636  for s =  0.0470703125
# Flow step output with generator type  single_commutator using string  11Z1Z1Z  gave for s =  0.0470703125   minimal norm  56.322323273435636
# Found minimum norm =  58.58221190114321  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11Z1Z11  gave for s =  0.0498046875   minimal norm  58.58221190114321
# Found minimum norm =  58.76372132853425  for s =  0.0587890625
# Flow step output with generator type  single_commutator using string  11Z11ZZ  gave for s =  0.0587890625   minimal norm  58.76372132853425
# Found minimum norm =  58.106485918184916  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11Z11Z1  gave for s =  0.0498046875   minimal norm  58.106485918184916
# Found minimum norm =  59.13870643885859  for s =  0.0607421875
# Flow step output with generator type  single_commutator using string  11Z111Z  gave for s =  0.0607421875   minimal norm  59.13870643885859
# Found minimum norm =  58.456460345982165  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  11Z1111  gave for s =  0.07285156250000001   minimal norm  58.456460345982165
# Found minimum norm =  61.40767797171201  for s =  0.07597656250000001
# Flow step output with generator type  single_commutator using string  111ZZZZ  gave for s =  0.07597656250000001   minimal norm  61.40767797171201
# Found minimum norm =  60.61260579102086  for s =  0.0701171875
# Flow step output with generator type  single_commutator using string  111ZZZ1  gave for s =  0.0701171875   minimal norm  60.61260579102086
# Found minimum norm =  59.539066092987674  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  111ZZ1Z  gave for s =  0.0498046875   minimal norm  59.539066092987674
# Found minimum norm =  60.968988343914276  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  111ZZ11  gave for s =  0.07363281250000002   minimal norm  60.968988343914276
# Found minimum norm =  59.52175035579097  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  111Z1ZZ  gave for s =  0.0498046875   minimal norm  59.52175035579097
# Found minimum norm =  58.582211901143204  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  111Z1Z1  gave for s =  0.0498046875   minimal norm  58.582211901143204
# Found minimum norm =  59.13870643885859  for s =  0.0607421875
# Flow step output with generator type  single_commutator using string  111Z11Z  gave for s =  0.0607421875   minimal norm  59.13870643885859
# Found minimum norm =  58.456460345982165  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  111Z111  gave for s =  0.07285156250000001   minimal norm  58.456460345982165
# Found minimum norm =  61.76406228826034  for s =  0.08066406250000002
# Flow step output with generator type  single_commutator using string  1111ZZZ  gave for s =  0.08066406250000002   minimal norm  61.76406228826034
# Found minimum norm =  60.968988343914276  for s =  0.07363281250000002
# Flow step output with generator type  single_commutator using string  1111ZZ1  gave for s =  0.07363281250000002   minimal norm  60.968988343914276
# Found minimum norm =  59.9742715804783  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1111Z1Z  gave for s =  0.0498046875   minimal norm  59.9742715804783
# Found minimum norm =  58.456460345982165  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  1111Z11  gave for s =  0.07285156250000001   minimal norm  58.456460345982165
# Found minimum norm =  62.1035900599806  for s =  0.08691406250000001
# Flow step output with generator type  single_commutator using string  11111ZZ  gave for s =  0.08691406250000001   minimal norm  62.1035900599806
# Found minimum norm =  58.456460345982165  for s =  0.07285156250000001
# Flow step output with generator type  single_commutator using string  11111Z1  gave for s =  0.07285156250000001   minimal norm  58.456460345982165
# Found minimum norm =  60.10283403932737  for s =  0.08769531250000001
# Flow step output with generator type  single_commutator using string  111111Z  gave for s =  0.08769531250000001   minimal norm  60.10283403932737
# Found minimum norm =  64.0  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1111111  gave for s =  0.0001953125   minimal norm  64.0
# Found minimum norm =  48.52660363152643  for s =  0.0392578125
# Found that canonical is better because  48.52660363152643 54.84228171251686
# Found minimum norm =  48.52660363152643  for s =  0.0392578125
# Flowing forwards with type  canonical
# []
# Flow step  1
# Found minimum norm =  46.54249672974209  for s =  0.07832031250000002
# Flow step output with generator type  single_commutator using string  ZZZZZZZ  gave for s =  0.07832031250000002   minimal norm  46.54249672974209
# Found minimum norm =  46.411194899138806  for s =  0.0654296875
# Flow step output with generator type  single_commutator using string  ZZZZZZ1  gave for s =  0.0654296875   minimal norm  46.411194899138806
# Found minimum norm =  46.049292541351086  for s =  0.06503906250000001
# Flow step output with generator type  single_commutator using string  ZZZZZ1Z  gave for s =  0.06503906250000001   minimal norm  46.049292541351086
# Found minimum norm =  47.219003687674586  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZZ11  gave for s =  0.0498046875   minimal norm  47.219003687674586
# Found minimum norm =  46.486286066404  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZ1ZZ  gave for s =  0.0498046875   minimal norm  46.486286066404
# Found minimum norm =  45.619616765558995  for s =  0.0646484375
# Flow step output with generator type  single_commutator using string  ZZZZ1Z1  gave for s =  0.0646484375   minimal norm  45.619616765558995
# Found minimum norm =  46.75448255221293  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZ11Z  gave for s =  0.0498046875   minimal norm  46.75448255221293
# Found minimum norm =  47.372369259814384  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZZ111  gave for s =  0.0498046875   minimal norm  47.372369259814384
# Found minimum norm =  46.48903167781452  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1ZZZ  gave for s =  0.0498046875   minimal norm  46.48903167781452
# Found minimum norm =  46.001427094328676  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1ZZ1  gave for s =  0.0498046875   minimal norm  46.001427094328676
# Found minimum norm =  45.123032044786264  for s =  0.0634765625
# Flow step output with generator type  single_commutator using string  ZZZ1Z1Z  gave for s =  0.0634765625   minimal norm  45.123032044786264
# Found minimum norm =  46.57433433474062  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1Z11  gave for s =  0.0498046875   minimal norm  46.57433433474062
# Found minimum norm =  46.88365993509908  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ11ZZ  gave for s =  0.0498046875   minimal norm  46.88365993509908
# Found minimum norm =  46.49413662586675  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ11Z1  gave for s =  0.0498046875   minimal norm  46.49413662586675
# Found minimum norm =  46.95267851578827  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ111Z  gave for s =  0.0498046875   minimal norm  46.95267851578827
# Found minimum norm =  47.36395578696502  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZZ1111  gave for s =  0.0498046875   minimal norm  47.36395578696502
# Found minimum norm =  46.486286066404  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZZZ  gave for s =  0.0498046875   minimal norm  46.486286066404
# Found minimum norm =  45.96383757168077  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZZ1  gave for s =  0.0498046875   minimal norm  45.96383757168077
# Found minimum norm =  45.5709465103427  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZ1Z  gave for s =  0.0498046875   minimal norm  45.5709465103427
# Found minimum norm =  46.527719153116344  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1ZZ11  gave for s =  0.0498046875   minimal norm  46.527719153116344
# Found minimum norm =  45.62900807208607  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1Z1ZZ  gave for s =  0.0498046875   minimal norm  45.62900807208607
# Found minimum norm =  44.68853987625461  for s =  0.0623046875
# Flow step output with generator type  single_commutator using string  ZZ1Z1Z1  gave for s =  0.0623046875   minimal norm  44.68853987625461
# Found minimum norm =  45.95316558185174  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1Z11Z  gave for s =  0.0498046875   minimal norm  45.95316558185174
# Found minimum norm =  47.00982779888572  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1Z111  gave for s =  0.0498046875   minimal norm  47.00982779888572
# Found minimum norm =  46.88365993509909  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ11ZZZ  gave for s =  0.0498046875   minimal norm  46.88365993509909
# Found minimum norm =  46.37943803505835  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ11ZZ1  gave for s =  0.0498046875   minimal norm  46.37943803505835
# Found minimum norm =  45.974111771809035  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ11Z1Z  gave for s =  0.0498046875   minimal norm  45.974111771809035
# Found minimum norm =  47.00569588760684  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ11Z11  gave for s =  0.0498046875   minimal norm  47.00569588760684
# Found minimum norm =  47.11664274983582  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ111ZZ  gave for s =  0.0498046875   minimal norm  47.11664274983582
# Found minimum norm =  46.86128466931706  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ111Z1  gave for s =  0.0498046875   minimal norm  46.86128466931706
# Found minimum norm =  47.20034813997805  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ1111Z  gave for s =  0.0498046875   minimal norm  47.20034813997805
# Found minimum norm =  47.40183270798895  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  ZZ11111  gave for s =  0.0498046875   minimal norm  47.40183270798895
# Found minimum norm =  46.049292541351086  for s =  0.06503906250000001
# Flow step output with generator type  single_commutator using string  Z1ZZZZZ  gave for s =  0.06503906250000001   minimal norm  46.049292541351086
# Found minimum norm =  45.8602698878802  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZZZ1  gave for s =  0.0498046875   minimal norm  45.8602698878802
# Found minimum norm =  45.48068351431979  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZZ1Z  gave for s =  0.0498046875   minimal norm  45.48068351431979
# Found minimum norm =  46.44456025797251  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZZ11  gave for s =  0.0498046875   minimal norm  46.44456025797251
# Found minimum norm =  45.5709465103427  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZ1ZZ  gave for s =  0.0498046875   minimal norm  45.5709465103427
# Found minimum norm =  45.00252190903782  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZ1Z1  gave for s =  0.0498046875   minimal norm  45.00252190903782
# Found minimum norm =  45.82806874035766  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZ11Z  gave for s =  0.0498046875   minimal norm  45.82806874035766
# Found minimum norm =  46.89986644837128  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1ZZ111  gave for s =  0.0498046875   minimal norm  46.89986644837128
# Found minimum norm =  45.123032044786264  for s =  0.0634765625
# Flow step output with generator type  single_commutator using string  Z1Z1ZZZ  gave for s =  0.0634765625   minimal norm  45.123032044786264
# Found minimum norm =  44.923321147789764  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z1ZZ1  gave for s =  0.0498046875   minimal norm  44.923321147789764
# Found minimum norm =  43.909327010790385  for s =  0.06386718749999999
# Flow step output with generator type  single_commutator using string  Z1Z1Z1Z  gave for s =  0.06386718749999999   minimal norm  43.909327010790385
# Found minimum norm =  45.13255901723286  for s =  0.06386718749999999
# Flow step output with generator type  single_commutator using string  Z1Z1Z11  gave for s =  0.06386718749999999   minimal norm  45.13255901723286
# Found minimum norm =  45.974111771809035  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z11ZZ  gave for s =  0.0498046875   minimal norm  45.974111771809035
# Found minimum norm =  45.51641403495246  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z11Z1  gave for s =  0.0498046875   minimal norm  45.51641403495246
# Found minimum norm =  46.19821165667102  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1Z111Z  gave for s =  0.0498046875   minimal norm  46.19821165667102
# Found minimum norm =  46.888678152145395  for s =  0.07128906250000001
# Flow step output with generator type  single_commutator using string  Z1Z1111  gave for s =  0.07128906250000001   minimal norm  46.888678152145395
# Found minimum norm =  46.75448255221292  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11ZZZZ  gave for s =  0.0498046875   minimal norm  46.75448255221292
# Found minimum norm =  46.21043550604606  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11ZZZ1  gave for s =  0.0498046875   minimal norm  46.21043550604606
# Found minimum norm =  45.82806874035766  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11ZZ1Z  gave for s =  0.0498046875   minimal norm  45.82806874035766
# Found minimum norm =  46.804824216449774  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11ZZ11  gave for s =  0.0498046875   minimal norm  46.804824216449774
# Found minimum norm =  45.95316558185174  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11Z1ZZ  gave for s =  0.0498046875   minimal norm  45.95316558185174
# Found minimum norm =  45.43937083942674  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11Z1Z1  gave for s =  0.0498046875   minimal norm  45.43937083942674
# Found minimum norm =  46.268251783735046  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11Z11Z  gave for s =  0.0498046875   minimal norm  46.268251783735046
# Found minimum norm =  47.304669038883574  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11Z111  gave for s =  0.0498046875   minimal norm  47.304669038883574
# Found minimum norm =  46.95267851578827  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z111ZZZ  gave for s =  0.0498046875   minimal norm  46.95267851578827
# Found minimum norm =  46.580993797996705  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z111ZZ1  gave for s =  0.0498046875   minimal norm  46.580993797996705
# Found minimum norm =  46.19821165667102  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z111Z1Z  gave for s =  0.0498046875   minimal norm  46.19821165667102
# Found minimum norm =  47.21903906611029  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z111Z11  gave for s =  0.0498046875   minimal norm  47.21903906611029
# Found minimum norm =  47.20034813997805  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z1111ZZ  gave for s =  0.0498046875   minimal norm  47.20034813997805
# Found minimum norm =  46.84839979058248  for s =  0.0658203125
# Flow step output with generator type  single_commutator using string  Z1111Z1  gave for s =  0.0658203125   minimal norm  46.84839979058248
# Found minimum norm =  47.27148908752461  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  Z11111Z  gave for s =  0.0498046875   minimal norm  47.27148908752461
# Found minimum norm =  46.54402514390052  for s =  0.07089843750000001
# Flow step output with generator type  single_commutator using string  Z111111  gave for s =  0.07089843750000001   minimal norm  46.54402514390052
# Found minimum norm =  46.411194899138806  for s =  0.0654296875
# Flow step output with generator type  single_commutator using string  1ZZZZZZ  gave for s =  0.0654296875   minimal norm  46.411194899138806
# Found minimum norm =  46.3937834316764  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZZZ1  gave for s =  0.0498046875   minimal norm  46.3937834316764
# Found minimum norm =  45.8602698878802  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZZ1Z  gave for s =  0.0498046875   minimal norm  45.8602698878802
# Found minimum norm =  46.776636367692575  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZZ11  gave for s =  0.0498046875   minimal norm  46.776636367692575
# Found minimum norm =  45.96383757168077  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZ1ZZ  gave for s =  0.0498046875   minimal norm  45.96383757168077
# Found minimum norm =  45.69444808872275  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZ1Z1  gave for s =  0.0498046875   minimal norm  45.69444808872275
# Found minimum norm =  46.21043550604606  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZ11Z  gave for s =  0.0498046875   minimal norm  46.21043550604606
# Found minimum norm =  46.869970728132635  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZZ111  gave for s =  0.0498046875   minimal norm  46.869970728132635
# Found minimum norm =  46.001427094328676  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1ZZZ  gave for s =  0.0498046875   minimal norm  46.001427094328676
# Found minimum norm =  45.66525401840681  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1ZZ1  gave for s =  0.0498046875   minimal norm  45.66525401840681
# Found minimum norm =  44.92332114778977  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1Z1Z  gave for s =  0.0498046875   minimal norm  44.92332114778977
# Found minimum norm =  46.314794263796045  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1Z11  gave for s =  0.0498046875   minimal norm  46.314794263796045
# Found minimum norm =  46.37943803505835  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ11ZZ  gave for s =  0.0498046875   minimal norm  46.37943803505835
# Found minimum norm =  46.196544606246924  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ11Z1  gave for s =  0.0498046875   minimal norm  46.196544606246924
# Found minimum norm =  46.580993797996705  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ111Z  gave for s =  0.0498046875   minimal norm  46.580993797996705
# Found minimum norm =  47.02108547777366  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1ZZ1111  gave for s =  0.0498046875   minimal norm  47.02108547777366
# Found minimum norm =  45.619616765558995  for s =  0.0646484375
# Flow step output with generator type  single_commutator using string  1Z1ZZZZ  gave for s =  0.0646484375   minimal norm  45.619616765558995
# Found minimum norm =  45.694448088722744  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1ZZZ1  gave for s =  0.0498046875   minimal norm  45.694448088722744
# Found minimum norm =  45.00252190903782  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1ZZ1Z  gave for s =  0.0498046875   minimal norm  45.00252190903782
# Found minimum norm =  46.31667040861247  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1ZZ11  gave for s =  0.0498046875   minimal norm  46.31667040861247
# Found minimum norm =  44.68853987625461  for s =  0.0623046875
# Flow step output with generator type  single_commutator using string  1Z1Z1ZZ  gave for s =  0.0623046875   minimal norm  44.68853987625461
# Found minimum norm =  44.25780277445682  for s =  0.0654296875
# Flow step output with generator type  single_commutator using string  1Z1Z1Z1  gave for s =  0.0654296875   minimal norm  44.25780277445682
# Found minimum norm =  45.439370839426736  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z1Z11Z  gave for s =  0.0498046875   minimal norm  45.439370839426736
# Found minimum norm =  46.34346069791023  for s =  0.0693359375
# Flow step output with generator type  single_commutator using string  1Z1Z111  gave for s =  0.0693359375   minimal norm  46.34346069791023
# Found minimum norm =  46.49413662586675  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11ZZZ  gave for s =  0.0498046875   minimal norm  46.49413662586675
# Found minimum norm =  46.19654460624693  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11ZZ1  gave for s =  0.0498046875   minimal norm  46.19654460624693
# Found minimum norm =  45.51641403495246  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11Z1Z  gave for s =  0.0498046875   minimal norm  45.51641403495246
# Found minimum norm =  46.85379461890379  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z11Z11  gave for s =  0.0498046875   minimal norm  46.85379461890379
# Found minimum norm =  46.86128466931705  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z111ZZ  gave for s =  0.0498046875   minimal norm  46.86128466931705
# Found minimum norm =  46.71568937758993  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  1Z111Z1  gave for s =  0.0498046875   minimal norm  46.71568937758993
# Found minimum norm =  46.84839979058248  for s =  0.0658203125
# Flow step output with generator type  single_commutator using string  1Z1111Z  gave for s =  0.0658203125   minimal norm  46.84839979058248
# Found minimum norm =  45.8064865679424  for s =  0.06894531250000001
# Flow step output with generator type  single_commutator using string  1Z11111  gave for s =  0.06894531250000001   minimal norm  45.8064865679424
# Found minimum norm =  47.21900368767459  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZZZZ  gave for s =  0.0498046875   minimal norm  47.21900368767459
# Found minimum norm =  46.776636367692575  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZZZ1  gave for s =  0.0498046875   minimal norm  46.776636367692575
# Found minimum norm =  46.44456025797251  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZZ1Z  gave for s =  0.0498046875   minimal norm  46.44456025797251
# Found minimum norm =  47.05121487154038  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZZ11  gave for s =  0.0498046875   minimal norm  47.05121487154038
# Found minimum norm =  46.527719153116344  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZ1ZZ  gave for s =  0.0498046875   minimal norm  46.527719153116344
# Found minimum norm =  46.31667040861247  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZ1Z1  gave for s =  0.0498046875   minimal norm  46.31667040861247
# Found minimum norm =  46.80482421644978  for s =  0.0498046875
# Flow step output with generator type  single_commutator using string  11ZZ11Z  gave for s =  0.0498046875   minimal norm  46.80482421644978
# Found minimum norm =  47.194026410081534  for s =  0.0486328125
# ...
# Found minimum norm =  26.042519062670063  for s =  0.0154296875
# Flow step output with generator type  single_commutator using string  Z11Z11Z  gave for s =  0.0154296875   minimal norm  26.042519062670063
# Found minimum norm =  26.227086446424  for s =  0.0080078125
# Flow step output with generator type  single_commutator using string  Z11Z111  gave for s =  0.0080078125   minimal norm  26.227086446424
# Found minimum norm =  26.12776825342365  for s =  0.0134765625
# Flow step output with generator type  single_commutator using string  Z111ZZZ  gave for s =  0.0134765625   minimal norm  26.12776825342365
# Found minimum norm =  25.954321072265753  for s =  0.017773437500000003
# Flow step output with generator type  single_commutator using string  Z111ZZ1  gave for s =  0.017773437500000003   minimal norm  25.954321072265753
# Found minimum norm =  26.171618032174557  for s =  0.0115234375
# Flow step output with generator type  single_commutator using string  Z111Z1Z  gave for s =  0.0115234375   minimal norm  26.171618032174557
# Found minimum norm =  26.193142357849382  for s =  0.010351562500000001
# Flow step output with generator type  single_commutator using string  Z111Z11  gave for s =  0.010351562500000001   minimal norm  26.193142357849382
# Found minimum norm =  25.935482992516558  for s =  0.017773437500000003
# Flow step output with generator type  single_commutator using string  Z1111ZZ  gave for s =  0.017773437500000003   minimal norm  25.935482992516558
# Found minimum norm =  26.245221127062962  for s =  0.0029296875
# Flow step output with generator type  single_commutator using string  Z1111Z1  gave for s =  0.0029296875   minimal norm  26.245221127062962
# Found minimum norm =  26.237666216257665  for s =  0.0041015625
# Flow step output with generator type  single_commutator using string  Z11111Z  gave for s =  0.0041015625   minimal norm  26.237666216257665
# Found minimum norm =  25.62818576747404  for s =  0.0220703125
# Flow step output with generator type  single_commutator using string  Z111111  gave for s =  0.0220703125   minimal norm  25.62818576747404
# Found minimum norm =  26.163423391846692  for s =  0.013085937500000002
# Flow step output with generator type  single_commutator using string  1ZZZZZZ  gave for s =  0.013085937500000002   minimal norm  26.163423391846692
# Found minimum norm =  26.053552247050096  for s =  0.0158203125
# Flow step output with generator type  single_commutator using string  1ZZZZZ1  gave for s =  0.0158203125   minimal norm  26.053552247050096
# Found minimum norm =  26.05474313809363  for s =  0.0154296875
# Flow step output with generator type  single_commutator using string  1ZZZZ1Z  gave for s =  0.0154296875   minimal norm  26.05474313809363
# Found minimum norm =  26.092382831436332  for s =  0.016992187500000002
# Flow step output with generator type  single_commutator using string  1ZZZZ11  gave for s =  0.016992187500000002   minimal norm  26.092382831436332
# Found minimum norm =  26.13920184292199  for s =  0.011132812500000002
# Flow step output with generator type  single_commutator using string  1ZZZ1ZZ  gave for s =  0.011132812500000002   minimal norm  26.13920184292199
# Found minimum norm =  26.20403477273428  for s =  0.008398437500000001
# Flow step output with generator type  single_commutator using string  1ZZZ1Z1  gave for s =  0.008398437500000001   minimal norm  26.20403477273428
# Found minimum norm =  26.22620123085108  for s =  0.0068359375
# Flow step output with generator type  single_commutator using string  1ZZZ11Z  gave for s =  0.0068359375   minimal norm  26.22620123085108
# Found minimum norm =  25.877634051635056  for s =  0.018945312500000002
# Flow step output with generator type  single_commutator using string  1ZZZ111  gave for s =  0.018945312500000002   minimal norm  25.877634051635056
# Found minimum norm =  26.0913112475555  for s =  0.014257812500000001
# Flow step output with generator type  single_commutator using string  1ZZ1ZZZ  gave for s =  0.014257812500000001   minimal norm  26.0913112475555
# Found minimum norm =  26.20438260201372  for s =  0.0087890625
# Flow step output with generator type  single_commutator using string  1ZZ1ZZ1  gave for s =  0.0087890625   minimal norm  26.20438260201372
# Found minimum norm =  26.248842789181413  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1ZZ1Z1Z  gave for s =  0.0001953125   minimal norm  26.248842789181413
# Found minimum norm =  25.918391572012986  for s =  0.018945312500000002
# Flow step output with generator type  single_commutator using string  1ZZ1Z11  gave for s =  0.018945312500000002   minimal norm  25.918391572012986
# Found minimum norm =  26.242001092580093  for s =  0.0037109375
# Flow step output with generator type  single_commutator using string  1ZZ11ZZ  gave for s =  0.0037109375   minimal norm  26.242001092580093
# Found minimum norm =  25.967375569535907  for s =  0.017773437500000003
# Flow step output with generator type  single_commutator using string  1ZZ11Z1  gave for s =  0.017773437500000003   minimal norm  25.967375569535907
# Found minimum norm =  25.954321072265703  for s =  0.017773437500000003
# Flow step output with generator type  single_commutator using string  1ZZ111Z  gave for s =  0.017773437500000003   minimal norm  25.954321072265703
# Found minimum norm =  26.139732334631425  for s =  0.0154296875
# Flow step output with generator type  single_commutator using string  1ZZ1111  gave for s =  0.0154296875   minimal norm  26.139732334631425
# Found minimum norm =  26.103481949511313  for s =  0.012304687500000001
# Flow step output with generator type  single_commutator using string  1Z1ZZZZ  gave for s =  0.012304687500000001   minimal norm  26.103481949511313
# Found minimum norm =  26.204034772734285  for s =  0.008398437500000001
# Flow step output with generator type  single_commutator using string  1Z1ZZZ1  gave for s =  0.008398437500000001   minimal norm  26.204034772734285
# Found minimum norm =  26.246499649946276  for s =  0.0017578125
# Flow step output with generator type  single_commutator using string  1Z1ZZ1Z  gave for s =  0.0017578125   minimal norm  26.246499649946276
# Found minimum norm =  25.928663569209494  for s =  0.0173828125
# Flow step output with generator type  single_commutator using string  1Z1ZZ11  gave for s =  0.0173828125   minimal norm  25.928663569209494
# Found minimum norm =  26.246657116650304  for s =  0.0013671875000000001
# Flow step output with generator type  single_commutator using string  1Z1Z1ZZ  gave for s =  0.0013671875000000001   minimal norm  26.246657116650304
# Found minimum norm =  26.19856186433863  for s =  0.0068359375
# Flow step output with generator type  single_commutator using string  1Z1Z1Z1  gave for s =  0.0068359375   minimal norm  26.19856186433863
# Found minimum norm =  25.983881784833166  for s =  0.015039062499999999
# Flow step output with generator type  single_commutator using string  1Z1Z11Z  gave for s =  0.015039062499999999   minimal norm  25.983881784833166
# Found minimum norm =  26.175977881311592  for s =  0.0134765625
# Flow step output with generator type  single_commutator using string  1Z1Z111  gave for s =  0.0134765625   minimal norm  26.175977881311592
# Found minimum norm =  26.203645770015864  for s =  0.009960937500000003
# Flow step output with generator type  single_commutator using string  1Z11ZZZ  gave for s =  0.009960937500000003   minimal norm  26.203645770015864
# Found minimum norm =  25.967375569535896  for s =  0.017773437500000003
# Flow step output with generator type  single_commutator using string  1Z11ZZ1  gave for s =  0.017773437500000003   minimal norm  25.967375569535896
# Found minimum norm =  25.9303920727802  for s =  0.0173828125
# Flow step output with generator type  single_commutator using string  1Z11Z1Z  gave for s =  0.0173828125   minimal norm  25.9303920727802
# Found minimum norm =  26.233266067987433  for s =  0.0064453125000000005
# Flow step output with generator type  single_commutator using string  1Z11Z11  gave for s =  0.0064453125000000005   minimal norm  26.233266067987433
# Found minimum norm =  26.048718187938313  for s =  0.014257812500000001
# Flow step output with generator type  single_commutator using string  1Z111ZZ  gave for s =  0.014257812500000001   minimal norm  26.048718187938313
# Found minimum norm =  26.226284298312613  for s =  0.0064453125000000005
# Flow step output with generator type  single_commutator using string  1Z111Z1  gave for s =  0.0064453125000000005   minimal norm  26.226284298312613
# Found minimum norm =  26.245221127062972  for s =  0.0029296875
# Flow step output with generator type  single_commutator using string  1Z1111Z  gave for s =  0.0029296875   minimal norm  26.245221127062972
# Found minimum norm =  25.548047622007626  for s =  0.022851562500000002
# Flow step output with generator type  single_commutator using string  1Z11111  gave for s =  0.022851562500000002   minimal norm  25.548047622007626
# Found minimum norm =  26.003871110088614  for s =  0.017773437500000003
# Flow step output with generator type  single_commutator using string  11ZZZZZ  gave for s =  0.017773437500000003   minimal norm  26.003871110088614
# Found minimum norm =  26.092382831436336  for s =  0.016992187500000002
# Flow step output with generator type  single_commutator using string  11ZZZZ1  gave for s =  0.016992187500000002   minimal norm  26.092382831436336
# Found minimum norm =  26.100568022803298  for s =  0.015039062499999999
# Flow step output with generator type  single_commutator using string  11ZZZ1Z  gave for s =  0.015039062499999999   minimal norm  26.100568022803298
# Found minimum norm =  25.780150913808495  for s =  0.0212890625
# Flow step output with generator type  single_commutator using string  11ZZZ11  gave for s =  0.0212890625   minimal norm  25.780150913808495
# Found minimum norm =  26.190141061201945  for s =  0.011132812500000002
# Flow step output with generator type  single_commutator using string  11ZZ1ZZ  gave for s =  0.011132812500000002   minimal norm  26.190141061201945
# Found minimum norm =  25.928663569209515  for s =  0.0173828125
# Flow step output with generator type  single_commutator using string  11ZZ1Z1  gave for s =  0.0173828125   minimal norm  25.928663569209515
# Found minimum norm =  25.949942004796153  for s =  0.0181640625
# Flow step output with generator type  single_commutator using string  11ZZ11Z  gave for s =  0.0181640625   minimal norm  25.949942004796153
# Found minimum norm =  26.100540378059748  for s =  0.0220703125
# Flow step output with generator type  single_commutator using string  11ZZ111  gave for s =  0.0220703125   minimal norm  26.100540378059748
# Found minimum norm =  26.126538748612486  for s =  0.0138671875
# Flow step output with generator type  single_commutator using string  11Z1ZZZ  gave for s =  0.0138671875   minimal norm  26.126538748612486
# Found minimum norm =  25.918391572012993  for s =  0.018945312500000002
# Flow step output with generator type  single_commutator using string  11Z1ZZ1  gave for s =  0.018945312500000002   minimal norm  25.918391572012993
# Found minimum norm =  26.123388074602275  for s =  0.0138671875
# Flow step output with generator type  single_commutator using string  11Z1Z1Z  gave for s =  0.0138671875   minimal norm  26.123388074602275
# Found minimum norm =  26.217843471004734  for s =  0.009179687500000002
# Flow step output with generator type  single_commutator using string  11Z1Z11  gave for s =  0.009179687500000002   minimal norm  26.217843471004734
# Found minimum norm =  25.998150087287463  for s =  0.0166015625
# Flow step output with generator type  single_commutator using string  11Z11ZZ  gave for s =  0.0166015625   minimal norm  25.998150087287463
# Found minimum norm =  26.233266067987422  for s =  0.0064453125000000005
# Flow step output with generator type  single_commutator using string  11Z11Z1  gave for s =  0.0064453125000000005   minimal norm  26.233266067987422
# Found minimum norm =  26.193142357849393  for s =  0.010351562500000001
# Flow step output with generator type  single_commutator using string  11Z111Z  gave for s =  0.010351562500000001   minimal norm  26.193142357849393
# Found minimum norm =  25.50594941603856  for s =  0.022851562500000002
# Flow step output with generator type  single_commutator using string  11Z1111  gave for s =  0.022851562500000002   minimal norm  25.50594941603856
# Found minimum norm =  26.05796992521508  for s =  0.0166015625
# Flow step output with generator type  single_commutator using string  111ZZZZ  gave for s =  0.0166015625   minimal norm  26.05796992521508
# Found minimum norm =  25.877634051635056  for s =  0.018945312500000002
# Flow step output with generator type  single_commutator using string  111ZZZ1  gave for s =  0.018945312500000002   minimal norm  25.877634051635056
# Found minimum norm =  25.993528027958416  for s =  0.016992187500000002
# Flow step output with generator type  single_commutator using string  111ZZ1Z  gave for s =  0.016992187500000002   minimal norm  25.993528027958416
# Found minimum norm =  26.10054037805976  for s =  0.0220703125
# Flow step output with generator type  single_commutator using string  111ZZ11  gave for s =  0.0220703125   minimal norm  26.10054037805976
# Found minimum norm =  25.98530085979436  for s =  0.0162109375
# Flow step output with generator type  single_commutator using string  111Z1ZZ  gave for s =  0.0162109375   minimal norm  25.98530085979436
# Found minimum norm =  26.175977881311592  for s =  0.0134765625
# Flow step output with generator type  single_commutator using string  111Z1Z1  gave for s =  0.0134765625   minimal norm  26.175977881311592
# Found minimum norm =  26.22708644642402  for s =  0.0080078125
# Flow step output with generator type  single_commutator using string  111Z11Z  gave for s =  0.0080078125   minimal norm  26.22708644642402
# Found minimum norm =  25.52691350855975  for s =  0.021679687500000003
# Flow step output with generator type  single_commutator using string  111Z111  gave for s =  0.021679687500000003   minimal norm  25.52691350855975
# Found minimum norm =  25.917796876270362  for s =  0.018554687500000003
# Flow step output with generator type  single_commutator using string  1111ZZZ  gave for s =  0.018554687500000003   minimal norm  25.917796876270362
# Found minimum norm =  26.139732334631436  for s =  0.0154296875
# Flow step output with generator type  single_commutator using string  1111ZZ1  gave for s =  0.0154296875   minimal norm  26.139732334631436
# Found minimum norm =  26.220819368344014  for s =  0.0076171875
# Flow step output with generator type  single_commutator using string  1111Z1Z  gave for s =  0.0076171875   minimal norm  26.220819368344014
# Found minimum norm =  25.505949416038554  for s =  0.022851562500000002
# Flow step output with generator type  single_commutator using string  1111Z11  gave for s =  0.022851562500000002   minimal norm  25.505949416038554
# Found minimum norm =  26.090201920555423  for s =  0.0173828125
# Flow step output with generator type  single_commutator using string  11111ZZ  gave for s =  0.0173828125   minimal norm  26.090201920555423
# Found minimum norm =  25.548047622007637  for s =  0.022851562500000002
# Flow step output with generator type  single_commutator using string  11111Z1  gave for s =  0.022851562500000002   minimal norm  25.548047622007637
# Found minimum norm =  25.628185767474008  for s =  0.0220703125
# Flow step output with generator type  single_commutator using string  111111Z  gave for s =  0.0220703125   minimal norm  25.628185767474008
# Found minimum norm =  26.247823710752865  for s =  0.0001953125
# Flow step output with generator type  single_commutator using string  1111111  gave for s =  0.0001953125   minimal norm  26.247823710752865
# Found minimum norm =  25.484512856877323  for s =  0.0013671875000000001
# Found that canonical is better because  25.484512856877323 25.505949416038554
# Found minimum norm =  25.484512856877323  for s =  0.0013671875000000001
# Flowing forwards with type  canonical
# []

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

def plot_iteration_results(  ):
    flow.run_param_rc(fontsize=18)
    flow_results = flow.flow_outputs

    f=plt.figure(figsize = ( 8,7 ))
    n=1
    ax_a = f.add_subplot(1,n,1)
    norms = flow_results['minimal_norm_sigma_H_s']
    x_axis = [sum(flow_results['minimizing_flow_step'][:k])for k in range( 1, len(flow_results['minimizing_flow_step'])+1)]

    plt.plot( x_axis, norms, '-o')   
    N = 10
    k=0
    for xy in zip([x+.01 for x in x_axis[0:N]], 
                  [n - 0.03 for n in norms[0:N]]):  
        if k == 0 or k == 9 or k == 8 or k== 7 or k ==6:
            a=1
        else:
            plt.annotate('k = ' + str(k) + ': ' + flow_results['strs_of_minimizer_Z'][k-1], xy=xy, textcoords='data', fontsize=16)
        k=k+1
    #10
    plt.annotate('k = ' + str(k) + ': ' + flow_results['strs_of_minimizer_Z'][k-1], 
                 xy=(x_axis[-1]-.062,norms[-1]-1.5), textcoords='data', fontsize=16)
#8
    plt.annotate('k = ' + str(k-2) + ': ' + flow_results['strs_of_minimizer_Z'][k-3], 
                 xy=(x_axis[k-2]-.071,norms[k-2]-1.66), textcoords='data', fontsize=17)
#9
    plt.annotate('k = ' + str(k-1) + ': ' + flow_results['strs_of_minimizer_Z'][k-2], 
                  xy=(x_axis[k-1]-.03,norms[k-1]+0.5), textcoords='data', fontsize=17)
#7
    plt.annotate('k = ' + str(k-3) + ': ' + flow_results['strs_of_minimizer_Z'][k-4], 
                  xy=(x_axis[k-3]-.07,norms[k-3]-.7), textcoords='data', fontsize=17)
    plt.annotate('k = ' + str(k-4) + ': ' + flow_results['strs_of_minimizer_Z'][k-5], 
                  xy=(x_axis[k-4]+.0051,norms[k-4]-.7), textcoords='data', fontsize=17)
    
    x_labels_rounded = [ round(x, 2 ) for x in x_axis ]
    x_labels_rounded = [0] + x_labels_rounded[1:9]  + [max(x_labels_rounded)]
    x_labels_rounded.pop(2)
    x_labels_rounded.pop(2)
    x_labels_rounded.pop(-2)
#     x_labels_rounded.pop(4)
    
    plt.xticks(x_labels_rounded)
    y_labels_rounded = [ round(y, 1 ) for y in norms ]
    y_labels_rounded = y_labels_rounded[0:5] + [min(y_labels_rounded)]
    plt.yticks(y_labels_rounded)
    plt.grid()
    plt.xlabel(r'Total flow duration $\ell$')
    plt.title(r'Norm off-diagonal $\vert\vert\sigma(\hat H_k)\vert\vert$')
    a =-.1
    b = 1.05
 
    axin1 = ax_a.inset_axes([0.2,.7, 0.31, 0.27])
    inset1 = axin1.imshow( H_TLFIM, cmap='RdBu' )
    divider1 = make_axes_locatable(axin1)
    div_ax = divider1.append_axes("right", size="10%", pad=0.05)
    cbar1 = plt.colorbar(inset1, cax = div_ax )
    range_plot = np.max( np.abs( H_TLFIM ) )
#     cbar1.set_clim( -range_plot, range_plot )
    axin1.set_yticks(range(2**L))  
    axin1.set_xticklabels([1]+['']*(2**L-2)+[2**L])
    axin1.set_yticklabels([1]+['']*(2**L-2)+[2**L])
    axin1.set_xticks(range(2**L))
    ax_a.annotate(' ',
            xy=(x_axis[0]+.01, norms[0]),  # theta, radius
            xytext=(0.24, 0.81),    # fraction, fraction
            textcoords='figure fraction',
            arrowprops=dict(facecolor='gray', shrink=0.01),
            horizontalalignment='left',
            verticalalignment='bottom')
#     axin1.set_xlabel(r'$j$')
#     axin1.set_title(r'$k$')
#     axin1.grid()
    axin2 = ax_a.inset_axes([0.65,.32, 0.31, 0.27])
    inset2 = axin2.imshow(flow_results['optimally_flowed_H'][-1], cmap='RdBu')

    divider2 = make_axes_locatable(axin2)
    div_ax2 = divider2.append_axes("right", size="10%", pad=0.05)
    cbar2 = plt.colorbar(inset2, cax = div_ax2 )
    ax_a.annotate(' ',
        xy=(x_axis[-1], 11.4),  # theta, radius
        xytext=(.95, .3),    # fraction, fraction
        textcoords='axes fraction',
        arrowprops=dict(facecolor='gray', shrink=0.05),
        horizontalalignment='left',
        verticalalignment='bottom')
    
    axin3 = ax_a.inset_axes([0.65,.7, 0.31, 0.27])
    inset3 = axin3.imshow(flow_results['optimally_flowed_H'][2], cmap='RdBu')

    divider3 = make_axes_locatable(axin3)
    div_ax3 = divider3.append_axes("right", size="10%", pad=0.05)
    cbar2 = plt.colorbar(inset3, cax = div_ax3 )
    ax_a.annotate(' ',
        xy=(x_axis[2]+.01, norms[2]+.6),  # theta, radius
        xytext=(0.65, 0.67),    # fraction, fraction
        textcoords='axes fraction',
        arrowprops=dict(facecolor='gray', shrink=0.05),
        horizontalalignment='left',
        verticalalignment='bottom')
    axin2.set_yticks(range(2**L))  
    axin2.set_xticklabels([1]+['']*(2**L-2)+[2**L])
    axin2.set_yticklabels([1]+['']*(2**L-2)+[2**L])
    axin2.set_xticks(range(2**L))    
    axin3.set_yticks(range(2**L))  
    axin3.set_xticklabels([1]+['']*(2**L-2)+[2**L])
    axin3.set_yticklabels([1]+['']*(2**L-2)+[2**L])
    axin3.set_xticks(range(2**L))
    chosen_steps = [1,2]
    plt.savefig( 'figs/mix_L_'+str(L)+'.pdf')
    
plot_iteration_results()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:104: UserWarning: FixedFormatter should only be used together with FixedLocator
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:108: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# #### Simple plot for debugging

# %%
H = flow.flow_outputs['final_flowed_H'][-1]

plt.figure()
plt.subplot(121)
plt.imshow(abs(H_TLFIM), cmap='RdBu')
plt.colorbar()
plt.subplot(122)
plt.imshow(abs(H), cmap='RdBu')
plt.colorbar()
plt.tight_layout()

# %% [markdown]
# This variable stores or strings that have been tested in each step

# %%
print(flow.flow_outputs['all_Z_names'])
# Out:
# ['ZZZZZZZ', 'ZZZZZZ1', 'ZZZZZ1Z', 'ZZZZZ11', 'ZZZZ1ZZ', 'ZZZZ1Z1', 'ZZZZ11Z', 'ZZZZ111', 'ZZZ1ZZZ', 'ZZZ1ZZ1', 'ZZZ1Z1Z', 'ZZZ1Z11', 'ZZZ11ZZ', 'ZZZ11Z1', 'ZZZ111Z', 'ZZZ1111', 'ZZ1ZZZZ', 'ZZ1ZZZ1', 'ZZ1ZZ1Z', 'ZZ1ZZ11', 'ZZ1Z1ZZ', 'ZZ1Z1Z1', 'ZZ1Z11Z', 'ZZ1Z111', 'ZZ11ZZZ', 'ZZ11ZZ1', 'ZZ11Z1Z', 'ZZ11Z11', 'ZZ111ZZ', 'ZZ111Z1', 'ZZ1111Z', 'ZZ11111', 'Z1ZZZZZ', 'Z1ZZZZ1', 'Z1ZZZ1Z', 'Z1ZZZ11', 'Z1ZZ1ZZ', 'Z1ZZ1Z1', 'Z1ZZ11Z', 'Z1ZZ111', 'Z1Z1ZZZ', 'Z1Z1ZZ1', 'Z1Z1Z1Z', 'Z1Z1Z11', 'Z1Z11ZZ', 'Z1Z11Z1', 'Z1Z111Z', 'Z1Z1111', 'Z11ZZZZ', 'Z11ZZZ1', 'Z11ZZ1Z', 'Z11ZZ11', 'Z11Z1ZZ', 'Z11Z1Z1', 'Z11Z11Z', 'Z11Z111', 'Z111ZZZ', 'Z111ZZ1', 'Z111Z1Z', 'Z111Z11', 'Z1111ZZ', 'Z1111Z1', 'Z11111Z', 'Z111111', '1ZZZZZZ', '1ZZZZZ1', '1ZZZZ1Z', '1ZZZZ11', '1ZZZ1ZZ', '1ZZZ1Z1', '1ZZZ11Z', '1ZZZ111', '1ZZ1ZZZ', '1ZZ1ZZ1', '1ZZ1Z1Z', '1ZZ1Z11', '1ZZ11ZZ', '1ZZ11Z1', '1ZZ111Z', '1ZZ1111', '1Z1ZZZZ', '1Z1ZZZ1', '1Z1ZZ1Z', '1Z1ZZ11', '1Z1Z1ZZ', '1Z1Z1Z1', '1Z1Z11Z', '1Z1Z111', '1Z11ZZZ', '1Z11ZZ1', '1Z11Z1Z', '1Z11Z11', '1Z111ZZ', '1Z111Z1', '1Z1111Z', '1Z11111', '11ZZZZZ', '11ZZZZ1', '11ZZZ1Z', '11ZZZ11', '11ZZ1ZZ', '11ZZ1Z1', '11ZZ11Z', '11ZZ111', '11Z1ZZZ', '11Z1ZZ1', '11Z1Z1Z', '11Z1Z11', '11Z11ZZ', '11Z11Z1', '11Z111Z', '11Z1111', '111ZZZZ', '111ZZZ1', '111ZZ1Z', '111ZZ11', '111Z1ZZ', '111Z1Z1', '111Z11Z', '111Z111', '1111ZZZ', '1111ZZ1', '1111Z1Z', '1111Z11', '11111ZZ', '11111Z1', '111111Z', '1111111']

# %% [markdown]
# and these are the strings that gave the optimal generator to decrease the norm of the off-diagonal restriction

# %%
flow.flow_outputs['strs_of_minimizer_Z']
# Out:
# ['Canonical',
#  'Canonical',
#  'Canonical',
#  'Canonical',
#  'Canonical',
#  'Z1Z1Z1Z',
#  'Canonical',
#  'ZZZZZZZ',
#  'Z1Z1Z1Z',
#  'Canonical']
